# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import gc

from scipy.stats import skew,kurtosis
import datetime

# %%
# %matplotlib inline
# to view all columns
pd.set_option('display.max_columns',500)
plt.style.use('seaborn')

# %%
def summary_object(arg_df):
    
    object_list=[]
    category_list=[]
    bool_list=[]
    unilabel_list=[]
    missing_list=[]
    
    for c in arg_df.columns:
        if arg_df[c].dtypes==object:
            object_list.append(c)
        elif str(arg_df[c].dtypes)=='category':
            category_list.append(c)
        elif arg_df[c].dtypes==bool:
            bool_list.append(c)
    if len(object_list)+len(category_list)+len(bool_list)>0:    
        index_list=['Count','Unique','Missing (%)','Top','Top (%)','Bottom','Bottom (%)']
        df_summary=pd.DataFrame(data=np.zeros((len(index_list),len(object_list))),index=index_list,columns=object_list)

        for col in object_list+category_list+bool_list:
            vc=arg_df[col].value_counts().reset_index()
            df_summary.loc['Count',col]=(arg_df[col].count())
            df_summary.loc['Unique',col]=len(arg_df[col].unique())
            df_summary.loc['Missing (%)',col]=arg_df[col].isna().mean()*100
            df_summary.loc['Top',col]=vc.iloc[0,0]
            df_summary.loc['Top (%)',col]=vc.iloc[0,1]/len(arg_df)*100
            if len(arg_df[col].unique())>2:
                df_summary.loc['Bottom',col]=vc.iloc[-1,0]
                df_summary.loc['Bottom (%)',col]=vc.iloc[-1,1]/len(arg_df)*100
            elif (len(arg_df[col].unique())==2) & (df_summary.loc['Missing (%)',col]==0):
                df_summary.loc['Bottom',col]=vc.iloc[-1,0]
                df_summary.loc['Bottom (%)',col]=vc.iloc[-1,1]/len(arg_df)*100
            else:
                unilabel_list.append(col)
            if df_summary.loc['Missing (%)',col]==100:
                missing_list.append(col)
                
        df_summary=df_summary.T.sort_values(['Missing (%)','Unique'],ascending=False)
        df_summary=df_summary[(df_summary['Unique']>1) & (df_summary['Missing (%)']!=100)]
        df_summary.reset_index(inplace=True)
        df_summary.index=df_summary.index+1
        df_summary.columns=['Attribute']+index_list
        
        print('SUMMARY OF {} NON-NUMERICAL ATTRIBUTES:\n'.format(
            len(object_list)+len(category_list)+len(bool_list)))
        if len(object_list)>0:
            print('{} Object Columns'.format(len(object_list)))
        if len(category_list)>0:
            print('{} Categorical Columns'.format(len(category_list)))
        if len(bool_list)>0:
            print('{} Bool Columns'.format(len(bool_list)))
        if len(unilabel_list)>0:
            print('\n{} Columns with Single Label : \n{}'.format(len(unilabel_list),unilabel_list))
        if len(missing_list)>0:
            print('\n{} Empty Columns: \n{}'.format(len(missing_list),missing_list))   
            
        del arg_df,object_list,vc,index_list,unilabel_list,missing_list
        gc.collect()
        return df_summary
    else:
        print('No Non-Numerical Attributes')
'============================================================='        
def summary_numerical(arg_df):

    target_list=[]
    missing_list=[]
    zero_skew_list=[]
    
    for c in arg_df.columns:
        datatype=arg_df[c].dtypes
        if datatype != object and datatype != bool and str(datatype) != 'category' and str(datatype) !='datetime64[ns]':
            target_list.append(c)
    if len(target_list)>0:
        from scipy.stats import skew,kurtosis
        
        index_list=['Count','Missing (%)','Mean','Median','Min','Max','Skewness','Kurtosis']
        df_summary=pd.DataFrame(data=np.zeros((len(index_list),len(target_list))),
                                index=index_list,columns=target_list)
        for col in target_list:
            df_summary.loc['Count',col]=arg_df[col].count()
            df_summary.loc['Missing (%)',col]=arg_df[col].isna().mean()*100
            if df_summary.loc['Missing (%)',col]!=100:
                df_summary.loc['Mean',col]=arg_df[col].mean()
                df_summary.loc['Median',col]=arg_df[col].median()
                df_summary.loc['Min',col]=arg_df[col].min()
                df_summary.loc['Max',col]=arg_df[col].max()
                df_summary.loc['Skewness',col]=skew(arg_df[col])
                if df_summary.loc['Skewness',col]==0:
                    zero_skew_list.append(col)
                df_summary.loc['Kurtosis',col]=kurtosis(arg_df[col])
            else:
                missing_list.append(col)
                
        df_summary=df_summary.T.sort_values(['Missing (%)','Skewness'],ascending=False)
        df_summary=df_summary[(df_summary['Skewness']!=0) & (df_summary['Missing (%)']!=100)]
        df_summary.reset_index(inplace=True)
        df_summary.index=df_summary.index+1
        df_summary.columns=['Attribute']+index_list
        
        print('SUMMARY OF {} NUMERICAL ATTRIBUTES:'.format(len(target_list)))
        if len(zero_skew_list)>0:
            print('\n{} Columns with Single Value: \n{}'.format(len(zero_skew_list),zero_skew_list))
        if len(missing_list)>0:
            print('\n{} Empty Columns: \n{}'.format(len(missing_list),missing_list))
        del arg_df,target_list,index_list
        gc.collect()

        return df_summary
    else:
        print('No Numerical Attributes')
'==================================================================='        
def drop_unilable_column(arg_df):
    
    target_list=[]
    object_list=[]
    number_list=[]
    for c in arg_df.columns:
        if (arg_df[c].dtypes==object) | (str(arg_df[c].dtypes)=='category') | (arg_df[c].dtypes==bool):
            object_list.append(c)
        elif str(arg_df[c].dtypes)!='datetime64[ns]':
            number_list.append(c)
    if len(object_list)>0:    
        for c in object_list:
            if len(arg_df[c].unique())==1:
                target_list.append(c)
            elif (len(arg_df[c].unique())==2) & (arg_df[c].isna().mean()>0):
                target_list.append(c)
    
    if len(number_list)>0:   
        from scipy.stats import skew
        for c in number_list:
            if skew(arg_df[c])==0:
                target_list.append(c)
                
    if len(target_list)>0:
        arg_df.drop(columns=target_list,axis='columns',inplace=True)
        print('Drop {} Columns with Single Label:\n{}'.format(len(target_list),target_list))
    else: 
        print('No Columns with Single Label/Value')

    del target_list,object_list
'===================================================================' 
def drop_empty_column(arg_df):
    target_list=[]
    for c in arg_df.columns:
        if arg_df[c].count()==0:
            target_list.append(c)
    if len(target_list)>0:
        arg_df.drop(columns=target_list,axis=1,inplace=True)
        print('Delete {} Empty Column : \n{}'.format(len(target_list),target_list))
    else:
        print('No Empty Column')
'==================================================================='        
def drop_columns(arg_df,column_names):
    arg_df.drop(columns=column_names,axis='columns',inplace=True)
    print('Drop {} columns : \n{}'.format(len(column_names),column_names))
'============================================================='        
def extract_room_row(arg_df,col_position):
    '''To return unique Room-Row from standard Room-Row-Column-Height position data'''
    roomrow=[]
    roomrow=arg_df[col_position].apply(lambda x :x.split('-')[0]+'-'+x.split('-')[1] if '-' in x else x)
    roomrow=roomrow.unique().tolist()
    roomrow=pd.DataFrame(roomrow,columns=['Unique_Row']).sort_values(by='Unique_Row')
    return roomrow['Unique_Row'].values
'============================================================='  
def generate_dif_columns(arg_df,left_column,left_sffx,right_sffx):
    common_title=[]
    for idx,c in enumerate(left_column):
        common_title.append(left_column[idx].split(left_sffx)[0])
    print('There are {} common columns : \n{}'.format(len(left_column),common_title))

    for idx,c in enumerate(common_title):
        compare_col=common_title[idx].replace(' ','')
        arg_df['dif_'+compare_col]=(arg_df[c+left_sffx]!=arg_df[c+right_sffx]) & (arg_df[c+right_sffx].notna())
    print('\nColumns Generated : {}'.format(len(common_title)))
'==================================================================='        
def find_time_dif_hour(arg_df,ref_date,proc_date):
    new_date_attribute=[c.replace(' ','_') for c in proc_date]
    for idx,c in enumerate(proc_date):
        arg_df[new_date_attribute[idx]+'_hour']=arg_df[c]-arg_df[ref_date]
        arg_df[new_date_attribute[idx]+'_hour']=arg_df[new_date_attribute[idx]+'_hour'].astype('timedelta64[h]')

# %% [markdown]
# def extract_room_row(arg_df,col_position):
#     '''To return unique Room-Row from standard Room-Row-Column-Height position data'''
#     roomrow=[]
#     roomrow=arg_df[col_position].apply(lambda x :x.split('-')[0]+'-'+x.split('-')[1] if '-' in x else x)
#     roomrow=roomrow.unique().tolist()
#     roomrow=pd.DataFrame(roomrow,columns=['Unique_Row']).sort_values(by='Unique_Row')
#     return roomrow['Unique_Row'].values

# %%
file_1='/home/nan/Desktop/GitHub_Data/p_transaction.csv'
file_2='/home/nan/Desktop/GitHub_Data/p_dispatched.csv'
filename_1=file_1.rstrip('.csv')
filename_2=file_2.rstrip('.csv')

sffx_transaction='_Trsc'
sffx_dispatched='_Dptch'
target_process='SPQI'

# %%
trans=pd.read_csv(filename_1)
disp=pd.read_csv(filename_2)
# Out:
# /home/nan/miniconda3/envs/tf36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
trans.shape
# Out:
# (207259, 42)

# %%
trans.head(2)
# Out:
#   Transaction Date Time Customer Label Code Dry Matter Code Fruit Size Code  \
# 0   2019-07-01 00:00:10                   N               Y              42
# 1   2019-07-01 00:00:15                   N               Y              36
#
#   Labelling Indicator Code Location Mission Request Destination Marketer Code  \
# 0                       LG                                   na           ZIL
# 1                       LG                                   na           ZIL
#
#   Material Number        Ok Until Date  Pack Code            Pack Date  \
# 0           62853  2019-07-21 00:00:00      41236  2019-06-06 00:00:00
# 1           62809  2019-07-21 00:00:00      41717  2019-06-05 00:00:00
#
#   Packhouse Code Pack Label Code Pack Make Code  Pallet Number  \
# 0           3TPP               N            KC1       59717008
# 1           3TPP               N            KC1       59708334
#
#    Pallet Rework Count  Plant Code Previous Value Protocol Code  \
# 0                    0        1103     Q02-03-3-1             N
# 1                    0        1103    Q14-02-10-1             N
#
#   Purchase Pool Code Quality Inspection Indicator Code Storage Method Code  \
# 0                 01                                 A                  CN
# 1                 01                                 A                  CN
#
#       Transaction Date Transaction Sub Type Code Username Variety Code  \
# 0  2019-07-01 00:00:10                       MLA    agubs           HW
# 1  2019-07-01 00:00:15                       MTA   jaspsi           HW
#
#    Ok_Until_Date_day  Pack_Date_day  isDOINumber Pack Style Code Pack_Base  \
# 0               19.0          -26.0        False              MB         E
# 1               19.0          -27.0        False              IT         E
#
#   Stacking Configuration Code  isDayShift  Shift_Hour Day_of_week  isWeekend  \
# 0                           N       False           0         Sun       True
# 1                           3       False           0         Sun       True
#
#    isActualMovement  isPackedFruitequalFruit Previous_RoomRow Previous_Column  \
# 0              True                     True           Q02-03               3
# 1              True                     True           Q14-02              10
#
#   Previous_Height distance_to_driveway
# 0               1                   10
# 1               1                    3

# %%
disp.shape
# Out:
# (32251, 67)

# %% [markdown]
# ## Data Processing so that common columns have same set of data label
#     -change to string:Fruit Size Code_Trsc
#     -truncate 0 at first position:Purchase Pool Code_Trsc
#     -incorrect calculation as referring to dif,should remain in datetime: date columns(incl Ok_Until_Date_day,Pack_Date_day)

# %%
trans['Fruit Size Code']=trans['Fruit Size Code'].astype('str')
disp['Fruit Size Code']=disp['Fruit Size Code'].astype('str')

# %%
trans['Purchase Pool Code']=trans['Purchase Pool Code'].apply(lambda x:x.split('0')[1] if x[0]=='0' else x)
disp['Purchase Pool Code']=disp['Purchase Pool Code'].apply(lambda x:x.split('0')[1] if x[0]=='0' else x)

# %%
drop_columns(disp,['Pack_Date_day', 'Ok_Until_Date_day'])
# Out:
# Drop 2 columns :
# ['Pack_Date_day', 'Ok_Until_Date_day']

# %% [markdown]
# ## Filter Process

# %%
before_drop=trans.shape
df=trans[trans['Location Mission Request Destination']==target_process]
print('Total number of rows deleted :{} ({:.2f} %)'.format(
    (before_drop[0]-df.shape[0]),
    (before_drop[0]-df.shape[0])/before_drop[0]*100))
# Out:
# Total number of rows deleted :178492 (86.12 %)

# %%
df=df.merge(disp,how='left',on='Pallet Number',suffixes=(sffx_transaction, sffx_dispatched))

# %%
print('There are {} pallets went through {}.'.format(len(df['Pallet Number'].unique()),target_process))
print('Container order : {} '.format(len(df['Container Number'].unique())-1))
print('Envelope Number : {} '.format(len(df['Envelope Number'].unique())))
#print('Chartered order : {} '.format(len(df[df['Container Number']=='na'])))
# Out:
# There are 4101 pallets went through SPQI.
# Container order : 230
# Envelope Number : 299

# %%
df['Transaction Date']=pd.to_datetime(df['Transaction Date'],format='%Y-%m-%d %H:%M:%S')

# %% [markdown]
# ## Extract Process Completion Time

# %%
process=pd.DataFrame()
process['start_day']=df.groupby('Pallet Number')['Transaction Date Time'].first()
process['end_day']=df.groupby('Pallet Number')['Transaction Date Time'].last()

# %%
process['start_day']=pd.to_datetime(process['start_day'],format='%Y-%m-%d %H:%M:%S')
process['end_day']=pd.to_datetime(process['end_day'],format='%Y-%m-%d %H:%M:%S')

# %%
process['duration_hr']=process['end_day']-process['start_day']

# %%
process['duration_hr']=process['duration_hr'].astype('timedelta64[s]')

# %%
process['duration_hr']=process['duration_hr']/(60*60)

# %%
#process['duration_hr'].plot(kind='hist',cumulative=True,normed=True)

# %%
process['First_move']=True

# %%
process=process.drop(columns='end_day',axis='columns').reset_index()
process.head(3)
# Out:
#    Pallet Number           start_day  duration_hr  First_move
# 0       53188620 2019-07-27 09:55:21     0.001389        True
# 1       53188675 2019-07-04 20:33:04   180.518056        True
# 2       53189382 2019-07-01 23:46:32     8.263889        True

# %% [markdown]
# ## Retrive First Move

# %%
df_pallet=df.merge(process,how='left',left_on=['Pallet Number','Transaction Date'],right_on=['Pallet Number','start_day'])

# %%
df_pallet['First_move'].fillna(False,inplace=True)

# %%
before_drop=df_pallet.shape
df_pallet=df_pallet[df_pallet['First_move']]
print('Total number of rows deleted :{} ({:.2f} %)'.format(
    (before_drop[0]-df_pallet.shape[0]),
    (before_drop[0]-df_pallet.shape[0])/before_drop[0]*100))
# Out:
# Total number of rows deleted :24666 (85.74 %)

# %%
df_pallet.reset_index(inplace=True,drop=True)

# %%
# delete 'start_day' which is duplicate of Transaction Date
drop_columns(df_pallet,['start_day'])
# Out:
# Drop 1 columns :
# ['start_day']

# %%
df_pallet.head(3)
# Out:
#   Transaction Date Time Customer Label Code_Trsc Dry Matter Code_Trsc  \
# 0   2019-07-01 00:00:39                        N                    Y
# 1   2019-07-01 00:01:20                        N                    Y
# 2   2019-07-01 00:02:20                        N                    Y
#
#   Fruit Size Code_Trsc Labelling Indicator Code_Trsc  \
# 0                   33                            GR
# 1                   39                            LG
# 2                   33                            GR
#
#   Location Mission Request Destination Marketer Code_Trsc  \
# 0                                 SPQI                ZIL
# 1                                 SPQI                ZIL
# 2                                 SPQI                ZIL
#
#   Material Number_Trsc   Ok Until Date_Trsc  Pack Code_Trsc  \
# 0                61554  2019-07-07 00:00:00           10193
# 1                62846  2019-07-14 00:00:00           41716
# 2                61555  2019-07-07 00:00:00           10192
#
#         Pack Date_Trsc Packhouse Code_Trsc Pack Label Code_Trsc  \
# 0  2019-05-25 00:00:00                3TPP                    N
# 1  2019-05-28 00:00:00                3TPP                    N
# 2  2019-05-22 00:00:00                3TPP                    N
#
#   Pack Make Code_Trsc  Pallet Number  Pallet Rework Count  Plant Code_Trsc  \
# 0                 KC1       59669482                    0             1103
# 1                 KC1       59685451                    0             1103
# 2                 KC1       59431225                    0             1103
#
#   Previous Value Protocol Code Purchase Pool Code_Trsc  \
# 0           ALLO             N                       1
# 1     Q01-02-5-1             N                       1
# 2           ALLO             N                       1
#
#   Quality Inspection Indicator Code_Trsc Storage Method Code  \
# 0                                      A                  CN
# 1                                      A                  CN
# 2                                      A                  CN
#
#      Transaction Date Transaction Sub Type Code Username Variety Code_Trsc  \
# 0 2019-07-01 00:00:39                       MLA    teaio                HW
# 1 2019-07-01 00:01:20                       MTA    yasms                HW
# 2 2019-07-01 00:02:20                       MLA    teaio                HW
#
#    Ok_Until_Date_day  Pack_Date_day  isDOINumber Pack Style Code_Trsc  \
# 0                5.0          -38.0        False                   P1
# 1               12.0          -35.0        False                   MB
# 2                5.0          -41.0        False                   IT
#
#   Pack_Base_Trsc Stacking Configuration Code_Trsc  isDayShift  Shift_Hour  \
# 0              E                                N       False           0
# 1              E                                N       False           0
# 2              E                                N       False           0
#
#   Day_of_week  isWeekend  isActualMovement  isPackedFruitequalFruit  \
# 0         Sun       True              True                     True
# 1         Sun       True              True                     True
# 2         Sun       True              True                     True
#
#   Previous_RoomRow Previous_Column Previous_Height distance_to_driveway  \
# 0             ALLO              na              na                   na
# 1           Q01-02               5               1                    8
# 2             ALLO              na              na                   na
#
#   Location Room Code Location Row Code Location Column Location Height  \
# 0            UNKNOWN                na              na             0.0
# 1            UNKNOWN                na              na             0.0
# 2              CONTR                na              na             1.0
#
#   Location Request Number Storage Source Code Pack Label Code_Dptch  \
# 0                      na                  CN                     N
# 1                      na                  CN                     N
# 2                      na                  CN                     N
#
#   Pack Indicator Code Clearance Protocol Code Customer Label Code_Dptch  \
# 0                   N                       N                         N
# 1                   N                       N                         I
# 2                   N                       N                         N
#
#   Dry Matter Code_Dptch      Pack Date_Dptch Storing Characteristic Code  \
# 0                     Y  2019-05-25 00:00:00                           N
# 1                     Y  2019-05-24 00:00:00                           N
# 2                     Y  2019-05-22 00:00:00                           N
#
#   CCKPassed Failed Quality Inspection Indicator Code_Dptch  \
# 0             True                                       A
# 1             True                                       A
# 2             True                                       A
#
#   Japan Sub Brand Code Trial Packing Indicator Code Marketer Code_Dptch  \
# 0                    N                            N                 ZIL
# 1                    N                            N                 ZIL
# 2                    N                            N                 ZIL
#
#    Loadout Priority Material Number_Dptch Material Group Code Brand Code  \
# 0               6.0                 61554              Zespri          Z
# 1               6.0                 62846              Zespri          Z
# 2               6.0                 61556              Zespri          Z
#
#   Variety Code_Dptch  Fruit Class Code Fruit Size Code_Dptch  \
# 0                 HW               1.0                    33
# 1                 HW               1.0                    39
# 2                 HW               1.0                    33
#
#   Labelling Indicator Code_Dptch Purchase Pool Code_Dptch  Pack Code_Dptch  \
# 0                             GR                        1          10193.0
# 1                             LG                        1          41716.0
# 2                             GR                        1          10192.0
#
#   Growing Method Maturity Indicator Code  Ok Until Date_Dptch  \
# 0             CK                       N  2019-07-21 23:59:00
# 1             CK                       N  2019-08-11 23:59:00
# 2             CK                       N  2019-08-04 23:59:00
#
#    Plant Code_Dptch Ignore Psr Packhouse Code_Dptch Pallet Card Reference  \
# 0            1103.0      False                 3TPP             2216NIGHT
# 1            1103.0      False                 3TPP             3222NIGHT
# 2            1103.0      False                 3TPP                  3213
#
#    Order Number  Order Line Number         Loadout Date  Shipment Type Code  \
# 0     5334502.0               70.0  2019-07-17 11:00:00                18.0
# 1     5332701.0               30.0  2019-07-31 12:15:00                 4.0
# 2     5340902.0               40.0  2019-07-29 13:30:00                18.0
#
#   Destination Port Code Trucking Company Code  Full  \
# 0                 BEZEE                  OMOK  True
# 1                 INMAA                  RAYT  True
# 2                 CNSHG                  K&ST  True
#
#                                   Market Holds  \
# 0   ID, IL, IN, JP, KR, MX, RE, TH, TW, Z7, Z9
# 1                                           Z1
# 2                                   IL, TH, Z1
#
#   Stacking Configuration Code_Dptch Pack Style Code_Dptch  \
# 0                                 N                    P1
# 1                                 N                    MB
# 2                                 3                    IT
#
#   Pack Make Code_Dptch      Load Start Date  Envelope Number Container  \
# 0                  KC1  2019-07-17 00:00:00         199054.0    8328.0
# 1                  KC1  2019-07-29 00:00:00         199154.0     529.0
# 2                  KC1  2019-07-29 00:00:00         199236.0    8542.0
#
#   Container Number isDoi_Number isInternal_Holds isTemporary_Seal_Number  \
# 0      TTNU8962992        False             True                    True
# 1      TRIU8970380        False             True                    True
# 2      TEMU9001169        False             True                    True
#
#   isTemperature_Recorder_Number isLocation_Mission_Request_Destination  \
# 0                          True                                  False
# 1                          True                                  False
# 2                          True                                  False
#
#   isRf_Id_Tag1 isPermanentSeal Pallet Note  Repack_Date_day  \
# 0         True           False       False              NaN
# 1         True           False       False              NaN
# 2         True           False       False              NaN
#
#    Last_Spqi_Date_day  Doi_Clearance_Date_day  Tkl_Email_Date_day  \
# 0               -13.0                     NaN                -2.0
# 1               -27.0                     NaN                -3.0
# 2               -11.0                     NaN                -5.0
#
#    Load_Start_Date_hour Pack_Base_Dptch  duration_hr  First_move
# 0                 -11.0               E   335.496667        True
# 1                 -61.0               E   266.217778        True
# 2                 -14.0               E   443.263056        True

# %% [markdown]
# ## Generate Differences Column from Common Columns

# %%
left_col=[c for c in df_pallet if sffx_transaction in c ]
right_col=[c for c in df_pallet if sffx_dispatched in c ]

# %%
generate_dif_columns(df_pallet,left_col,sffx_transaction,sffx_dispatched)
# Out:
# There are 19 common columns :
# ['Customer Label Code', 'Dry Matter Code', 'Fruit Size Code', 'Labelling Indicator Code', 'Marketer Code', 'Material Number', 'Ok Until Date', 'Pack Code', 'Pack Date', 'Packhouse Code', 'Pack Label Code', 'Pack Make Code', 'Plant Code', 'Purchase Pool Code', 'Quality Inspection Indicator Code', 'Variety Code', 'Pack Style Code', 'Pack_Base', 'Stacking Configuration Code']
#
# Columns Generated : 19

# %% [markdown]
# ### Drop Unilabel Column

# %%
drop_unilable_column(df_pallet)
# Out:
# Drop 11 Columns with Single Label:
# ['Location Mission Request Destination', 'Pack Indicator Code', 'Storing Characteristic Code', 'Maturity Indicator Code', 'Full', 'isRf_Id_Tag1', 'First_move', 'dif_FruitSizeCode', 'dif_PackhouseCode', 'dif_PurchasePoolCode', 'dif_VarietyCode']

# %%
df_pallet.head(2)
# Out:
#   Transaction Date Time Customer Label Code_Trsc Dry Matter Code_Trsc  \
# 0   2019-07-01 00:00:39                        N                    Y
# 1   2019-07-01 00:01:20                        N                    Y
#
#   Fruit Size Code_Trsc Labelling Indicator Code_Trsc Marketer Code_Trsc  \
# 0                   33                            GR                ZIL
# 1                   39                            LG                ZIL
#
#   Material Number_Trsc   Ok Until Date_Trsc  Pack Code_Trsc  \
# 0                61554  2019-07-07 00:00:00           10193
# 1                62846  2019-07-14 00:00:00           41716
#
#         Pack Date_Trsc Packhouse Code_Trsc Pack Label Code_Trsc  \
# 0  2019-05-25 00:00:00                3TPP                    N
# 1  2019-05-28 00:00:00                3TPP                    N
#
#   Pack Make Code_Trsc  Pallet Number  Pallet Rework Count  Plant Code_Trsc  \
# 0                 KC1       59669482                    0             1103
# 1                 KC1       59685451                    0             1103
#
#   Previous Value Protocol Code Purchase Pool Code_Trsc  \
# 0           ALLO             N                       1
# 1     Q01-02-5-1             N                       1
#
#   Quality Inspection Indicator Code_Trsc Storage Method Code  \
# 0                                      A                  CN
# 1                                      A                  CN
#
#      Transaction Date Transaction Sub Type Code Username Variety Code_Trsc  \
# 0 2019-07-01 00:00:39                       MLA    teaio                HW
# 1 2019-07-01 00:01:20                       MTA    yasms                HW
#
#    Ok_Until_Date_day  Pack_Date_day  isDOINumber Pack Style Code_Trsc  \
# 0                5.0          -38.0        False                   P1
# 1               12.0          -35.0        False                   MB
#
#   Pack_Base_Trsc Stacking Configuration Code_Trsc  isDayShift  Shift_Hour  \
# 0              E                                N       False           0
# 1              E                                N       False           0
#
#   Day_of_week  isWeekend  isActualMovement  isPackedFruitequalFruit  \
# 0         Sun       True              True                     True
# 1         Sun       True              True                     True
#
#   Previous_RoomRow Previous_Column Previous_Height distance_to_driveway  \
# 0             ALLO              na              na                   na
# 1           Q01-02               5               1                    8
#
#   Location Room Code Location Row Code Location Column Location Height  \
# 0            UNKNOWN                na              na             0.0
# 1            UNKNOWN                na              na             0.0
#
#   Location Request Number Storage Source Code Pack Label Code_Dptch  \
# 0                      na                  CN                     N
# 1                      na                  CN                     N
#
#   Clearance Protocol Code Customer Label Code_Dptch Dry Matter Code_Dptch  \
# 0                       N                         N                     Y
# 1                       N                         I                     Y
#
#        Pack Date_Dptch CCKPassed Failed  \
# 0  2019-05-25 00:00:00             True
# 1  2019-05-24 00:00:00             True
#
#   Quality Inspection Indicator Code_Dptch Japan Sub Brand Code  \
# 0                                       A                    N
# 1                                       A                    N
#
#   Trial Packing Indicator Code Marketer Code_Dptch  Loadout Priority  \
# 0                            N                 ZIL               6.0
# 1                            N                 ZIL               6.0
#
#   Material Number_Dptch Material Group Code Brand Code Variety Code_Dptch  \
# 0                 61554              Zespri          Z                 HW
# 1                 62846              Zespri          Z                 HW
#
#    Fruit Class Code Fruit Size Code_Dptch Labelling Indicator Code_Dptch  \
# 0               1.0                    33                             GR
# 1               1.0                    39                             LG
#
#   Purchase Pool Code_Dptch  Pack Code_Dptch Growing Method  \
# 0                        1          10193.0             CK
# 1                        1          41716.0             CK
#
#    Ok Until Date_Dptch  Plant Code_Dptch Ignore Psr Packhouse Code_Dptch  \
# 0  2019-07-21 23:59:00            1103.0      False                 3TPP
# 1  2019-08-11 23:59:00            1103.0      False                 3TPP
#
#   Pallet Card Reference  Order Number  Order Line Number         Loadout Date  \
# 0             2216NIGHT     5334502.0               70.0  2019-07-17 11:00:00
# 1             3222NIGHT     5332701.0               30.0  2019-07-31 12:15:00
#
#    Shipment Type Code Destination Port Code Trucking Company Code  \
# 0                18.0                 BEZEE                  OMOK
# 1                 4.0                 INMAA                  RAYT
#
#                                   Market Holds  \
# 0   ID, IL, IN, JP, KR, MX, RE, TH, TW, Z7, Z9
# 1                                           Z1
#
#   Stacking Configuration Code_Dptch Pack Style Code_Dptch  \
# 0                                 N                    P1
# 1                                 N                    MB
#
#   Pack Make Code_Dptch      Load Start Date  Envelope Number Container  \
# 0                  KC1  2019-07-17 00:00:00         199054.0    8328.0
# 1                  KC1  2019-07-29 00:00:00         199154.0     529.0
#
#   Container Number isDoi_Number isInternal_Holds isTemporary_Seal_Number  \
# 0      TTNU8962992        False             True                    True
# 1      TRIU8970380        False             True                    True
#
#   isTemperature_Recorder_Number isLocation_Mission_Request_Destination  \
# 0                          True                                  False
# 1                          True                                  False
#
#   isPermanentSeal Pallet Note  Repack_Date_day  Last_Spqi_Date_day  \
# 0           False       False              NaN               -13.0
# 1           False       False              NaN               -27.0
#
#    Doi_Clearance_Date_day  Tkl_Email_Date_day  Load_Start_Date_hour  \
# 0                     NaN                -2.0                 -11.0
# 1                     NaN                -3.0                 -61.0
#
#   Pack_Base_Dptch  duration_hr  dif_CustomerLabelCode  dif_DryMatterCode  \
# 0               E   335.496667                  False              False
# 1               E   266.217778                   True              False
#
#    dif_LabellingIndicatorCode  dif_MarketerCode  dif_MaterialNumber  \
# 0                       False             False               False
# 1                       False             False               False
#
#    dif_OkUntilDate  dif_PackCode  dif_PackDate  dif_PackLabelCode  \
# 0             True         False         False              False
# 1             True         False          True              False
#
#    dif_PackMakeCode  dif_PlantCode  dif_QualityInspectionIndicatorCode  \
# 0             False          False                               False
# 1             False          False                               False
#
#    dif_PackStyleCode  dif_Pack_Base  dif_StackingConfigurationCode
# 0              False          False                          False
# 1              False          False                          False

# %% [markdown]
# ### check
# common_title=[]
# for idx,c in enumerate(left_col):
#     common_title.append(left_col[idx].split(sffx_transaction)[0])
#
# temp_list=[c for c in df_pallet.columns if common_title[8] in c]
# temp='dif_PackDate'
# temp_list.append(temp)
# df_pallet.loc[df_pallet[temp]==True,temp_list]

# %% [markdown]
# ## Select Important of particular process
#     - dif_CustomerLabelCode : True means labelling or delabelling needed, 181 rows are True
#     - dif_LabellingIndicatorCode: True means change in labelling indicator,83 rows True, cannot find description
#     - dif_PackCode : cannot find description, there are 103 rows are True
#     - dif_PackMakeCode : True means change in pack make,64 rows are True
#     - dif_PackStyleCode : True means change in pack box, 7 rows are True
#     - dif_Pack_Base : True means change in pallet base, 57 rows are True
#     - dif_StackingConfigurationCode : True means change in pallet height, 1461 rows are True

# %%
list_process=['dif_CustomerLabelCode','dif_LabellingIndicatorCode','dif_PackCode','dif_PackMakeCode','dif_PackStyleCode','dif_Pack_Base','dif_StackingConfigurationCode']

# %% [markdown]
# ## Drop Columns

# %%
temp_list=[]
for idx,c in enumerate(left_col):
    temp_list.append(left_col[idx].split(sffx_transaction)[0])

# %%
temp_list.extend(c for c in df_pallet if 'dif_' in c)

# %%
for c in list_process:
    temp_list.remove(c)

# %%
for c in temp_list:
    drop_columns(df_pallet,[l for l in df_pallet.columns if c in l])
# Out:
# Drop 2 columns :
# ['Customer Label Code_Trsc', 'Customer Label Code_Dptch']
# Drop 2 columns :
# ['Dry Matter Code_Trsc', 'Dry Matter Code_Dptch']
# Drop 2 columns :
# ['Fruit Size Code_Trsc', 'Fruit Size Code_Dptch']
# Drop 2 columns :
# ['Labelling Indicator Code_Trsc', 'Labelling Indicator Code_Dptch']
# Drop 2 columns :
# ['Marketer Code_Trsc', 'Marketer Code_Dptch']
# Drop 2 columns :
# ['Material Number_Trsc', 'Material Number_Dptch']
# Drop 2 columns :
# ['Ok Until Date_Trsc', 'Ok Until Date_Dptch']
# Drop 2 columns :
# ['Pack Code_Trsc', 'Pack Code_Dptch']
# Drop 2 columns :
# ['Pack Date_Trsc', 'Pack Date_Dptch']
# Drop 2 columns :
# ['Packhouse Code_Trsc', 'Packhouse Code_Dptch']
# Drop 2 columns :
# ['Pack Label Code_Trsc', 'Pack Label Code_Dptch']
# Drop 2 columns :
# ['Pack Make Code_Trsc', 'Pack Make Code_Dptch']
# Drop 2 columns :
# ['Plant Code_Trsc', 'Plant Code_Dptch']
# Drop 2 columns :
# ['Purchase Pool Code_Trsc', 'Purchase Pool Code_Dptch']
# Drop 2 columns :
# ['Quality Inspection Indicator Code_Trsc', 'Quality Inspection Indicator Code_Dptch']
# Drop 2 columns :
# ['Variety Code_Trsc', 'Variety Code_Dptch']
# Drop 2 columns :
# ['Pack Style Code_Trsc', 'Pack Style Code_Dptch']
# Drop 3 columns :
# ['Pack_Base_Trsc', 'Pack_Base_Dptch', 'dif_Pack_Base']
# Drop 2 columns :
# ['Stacking Configuration Code_Trsc', 'Stacking Configuration Code_Dptch']
# Drop 1 columns :
# ['dif_DryMatterCode']
# Drop 1 columns :
# ['dif_MarketerCode']
# Drop 1 columns :
# ['dif_MaterialNumber']
# Drop 1 columns :
# ['dif_OkUntilDate']
# Drop 1 columns :
# ['dif_PackDate']
# Drop 1 columns :
# ['dif_PackLabelCode']
# Drop 1 columns :
# ['dif_PlantCode']
# Drop 1 columns :
# ['dif_QualityInspectionIndicatorCode']

# %%
temp=df_pallet[df_pallet['Order Number'].isna()]['Pallet Number'].count()
print('Pallet that went through {} but are not dispatched : {} ({:.4f} %)'.format(target_process,temp,temp/len(df_pallet)))
# Out:
# Pallet that went through SPQI but are not dispatched : 1484 (0.3619 %)

# %% [markdown]
# ### Drop unrelated date time columns from Dispatched

# %%
temp_list=['Repack_Date_day','Last_Spqi_Date_day','Doi_Clearance_Date_day','Tkl_Email_Date_day','Load_Start_Date_hour']
drop_columns(df_pallet,temp_list)
# Out:
# Drop 5 columns :
# ['Repack_Date_day', 'Last_Spqi_Date_day', 'Doi_Clearance_Date_day', 'Tkl_Email_Date_day', 'Load_Start_Date_hour']

# %% [markdown]
# ### Drop position columns from Dispatched

# %%
temp_list=['Location Room Code','Location Row Code','Location Column','Location Height']
drop_columns(df_pallet,temp_list)
# Out:
# Drop 4 columns :
# ['Location Room Code', 'Location Row Code', 'Location Column', 'Location Height']

# %%
# 'Storage Method Code' and 'Storage Source Code' are same except for 11 rows, thus delete
#df_pallet[(df_pallet['Storage Method Code']!=df_pallet['Storage Source Code']) & (df_pallet['Storage Source Code'].notna())][['Storage Method Code','Storage Source Code','Loadout Date']]
drop_columns(df_pallet,['Storage Method Code','Storage Source Code'])
# Out:
# Drop 2 columns :
# ['Storage Method Code', 'Storage Source Code']

# %%
# 'Protocol Code' and 'Clearance Protocol Code' are same except for 94 rows, these columns are deleted because protocol change is not associate with order
df_pallet[(df_pallet['Protocol Code']!=df_pallet['Clearance Protocol Code']) & (df_pallet['Clearance Protocol Code'].notna())][['Protocol Code','Clearance Protocol Code','Loadout Date']]
drop_columns(df_pallet,['Protocol Code','Clearance Protocol Code'])
# Out:
# Drop 2 columns :
# ['Protocol Code', 'Clearance Protocol Code']

# %%
# drop unilabel columns with missing data
drop_unilable_column(df_pallet)
# Out:
# No Columns with Single Label/Value

# %%
# drop duplication : 'Material Group Code' is identical to 'Fruit Class Code' (1 order is class 2)
drop_columns(df_pallet,['Material Group Code','Previous Value'])
# Out:
# Drop 2 columns :
# ['Material Group Code', 'Previous Value']

# %%
# drop columns unlikely linked to process
temp_list=['Username','Loadout Date','Order Line Number','Ignore Psr','Transaction Sub Type Code','CCKPassed Failed']
drop_columns(df_pallet,temp_list)
# Out:
# Drop 6 columns :
# ['Username', 'Loadout Date', 'Order Line Number', 'Ignore Psr', 'Transaction Sub Type Code', 'CCKPassed Failed']

# %%
# 'Japan Sub Brand Code'(4),'Trial Packing Indicator Code'(3),'Fruit Class Code'(19),'Growing Method'(4)
temp_list=['Japan Sub Brand Code','Trial Packing Indicator Code','Brand Code','Fruit Class Code','Growing Method']
drop_columns(df_pallet,temp_list)
# Out:
# Drop 5 columns :
# ['Japan Sub Brand Code', 'Trial Packing Indicator Code', 'Brand Code', 'Fruit Class Code', 'Growing Method']

# %% [markdown]
# ### Derive Load Start hour

# %%
df_pallet['Load Start Date']=pd.to_datetime(df_pallet['Load Start Date'],format='%Y-%m-%d %H:%M:%S')

# %%
df_pallet['Load Start Date'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
find_time_dif_hour(df_pallet,'Transaction Date',['Load Start Date'])

# %%
drop_columns(df_pallet,['Transaction Date','Load Start Date'])
# Out:
# Drop 2 columns :
# ['Transaction Date', 'Load Start Date']

# %% [markdown]
# ### Derive Quantity of Pallet with same Order/Envelope Number in same process

# %%
df_pallet['Order Number'].value_counts()
# Out:
# 5337606.0    104
# 5329401.0     79
# 5311401.0     62
# 5330101.0     60
# 5329402.0     60
# 5348601.0     59
# 5169502.0     54
# 5311301.0     49
# 5210901.0     48
# 5351201.0     48
# 5164502.0     46
# 5156802.0     43
# 5210801.0     42
# 5156402.0     42
# 5351301.0     40
# 5337801.0     40
# 5349004.0     39
# 5349001.0     38
# 5329302.0     38
# 5169601.0     34
# 5313301.0     34
# 5316101.0     34
# 5303802.0     33
# 5331602.0     32
# 5156901.0     32
# 5287403.0     30
# 5164501.0     29
# 5340902.0     28
# 5148501.0     24
# 5330310.0     24
#             ...
# 5299901.0      4
# 5324001.0      4
# 5156702.0      3
# 5321202.0      3
# 5337802.0      3
# 5307202.0      3
# 5326701.0      3
# 5312401.0      3
# 5309601.0      3
# 5320502.0      3
# 5307203.0      2
# 5340402.0      2
# 5285803.0      2
# 5156401.0      1
# 5330402.0      1
# 5312901.0      1
# 5297301.0      1
# 5286002.0      1
# 5297201.0      1
# 5306803.0      1
# 5249401.0      1
# 5287204.0      1
# 5287404.0      1
# 5280303.0      1
# 5320501.0      1
# 5322401.0      1
# 5210701.0      1
# 5275904.0      1
# 5330312.0      1
# 5286001.0      1
# Name: Order Number, Length: 153, dtype: int64

# %%
temp_df=df_pallet.groupby('Order Number')['Pallet Number'].count().reset_index()

# %%
temp_df.rename(index=str,columns={'Pallet Number':'qty_same_order_process'},inplace=True)

# %%
df_pallet.merge(temp_df,how='left',on='Order Number')
# Out:
#      Transaction Date Time  Pallet Number  Pallet Rework Count  \
# 0      2019-07-01 00:00:39       59669482                    0
# 1      2019-07-01 00:01:20       59685451                    0
# 2      2019-07-01 00:02:20       59431225                    0
# 3      2019-07-01 00:03:09       59445246                    0
# 4      2019-07-01 00:04:46       59330290                    0
# 5      2019-07-01 00:05:16       59442689                    0
# 6      2019-07-01 00:05:37       59338296                    0
# 7      2019-07-01 00:05:46       59443235                    0
# 8      2019-07-01 00:09:46       59445550                    0
# 9      2019-07-01 00:53:21       59620339                    1
# 10     2019-07-01 00:53:38       59171510                    0
# 11     2019-07-01 00:54:00       59444973                    0
# 12     2019-07-01 00:54:10       59625617                    0
# 13     2019-07-01 00:55:30       59625327                    0
# 14     2019-07-01 00:55:48       58507907                    0
# 15     2019-07-01 00:55:53       59620308                    0
# 16     2019-07-01 00:59:30       59622555                    0
# 17     2019-07-01 01:03:04       59433687                    0
# 18     2019-07-01 01:03:24       59617810                    0
# 19     2019-07-01 01:04:24       57129766                    0
# 20     2019-07-01 01:04:44       59669277                    0
# 21     2019-07-01 01:05:59       57134791                    0
# 22     2019-07-01 01:06:04       59621855                    0
# 23     2019-07-01 01:06:19       59685796                    0
# 24     2019-07-01 01:06:27       59437746                    0
# 25     2019-07-01 01:08:26       57000317                    0
# 26     2019-07-01 01:08:52       59625600                    0
# 27     2019-07-01 01:09:05       59669215                    0
# 28     2019-07-01 01:09:09       59624474                    2
# 29     2019-07-01 01:09:38       59685956                    0
# ...                    ...            ...                  ...
# 4071   2019-07-30 23:13:45       58504340                    2
# 4072   2019-07-30 23:14:47       57427800                    0
# 4073   2019-07-30 23:16:57       58510013                    0
# 4074   2019-07-30 23:17:09       58504494                    2
# 4075   2019-07-30 23:19:27       58507693                    0
# 4076   2019-07-30 23:20:13       58505729                    0
# 4077   2019-07-30 23:21:30       57438561                    0
# 4078   2019-07-30 23:22:38       57437892                    0
# 4079   2019-07-30 23:24:19       57436567                    0
# 4080   2019-07-30 23:28:19       57439018                    0
# 4081   2019-07-30 23:30:19       57426667                    0
# 4082   2019-07-30 23:31:44       58504166                    0
# 4083   2019-07-30 23:31:52       57426544                    0
# 4084   2019-07-30 23:33:31       57426858                    0
# 4085   2019-07-30 23:33:54       58505811                    0
# 4086   2019-07-30 23:35:41       57436680                    0
# 4087   2019-07-30 23:37:21       57427091                    2
# 4088   2019-07-30 23:38:46       57415708                    0
# 4089   2019-07-30 23:41:21       57429026                    0
# 4090   2019-07-30 23:42:27       57438325                    0
# 4091   2019-07-30 23:45:33       57432545                    2
# 4092   2019-07-30 23:46:08       57435904                    2
# 4093   2019-07-30 23:48:43       57390609                    0
# 4094   2019-07-30 23:50:10       57426339                    0
# 4095   2019-07-30 23:51:23       57427343                    2
# 4096   2019-07-30 23:52:33       57430725                    1
# 4097   2019-07-30 23:53:01       57391217                    0
# 4098   2019-07-30 23:53:46       57432002                    0
# 4099   2019-07-30 23:56:44       57435393                    2
# 4100   2019-07-30 23:59:04       57435843                    0
#
#       Ok_Until_Date_day  Pack_Date_day  isDOINumber  isDayShift  Shift_Hour  \
# 0                   5.0          -38.0        False       False           0
# 1                  12.0          -35.0        False       False           0
# 2                   5.0          -41.0        False       False           0
# 3                   5.0          -39.0        False       False           0
# 4                   5.0          -40.0        False       False           0
# 5                   5.0          -39.0        False       False           0
# 6                   5.0          -39.0        False       False           0
# 7                   5.0          -39.0        False       False           0
# 8                   5.0          -39.0        False       False           0
# 9                   5.0          -37.0        False       False           0
# 10                  5.0          -43.0        False       False           0
# 11                  5.0          -39.0        False       False           0
# 12                  5.0          -37.0        False       False           0
# 13                  5.0          -37.0        False       False           0
# 14                 -9.0          -56.0        False       False           0
# 15                  5.0          -37.0        False       False           0
# 16                  5.0          -37.0        False       False           0
# 17                  5.0          -41.0        False       False           1
# 18                  5.0          -38.0        False       False           1
# 19                -23.0          -71.0         True       False           1
# 20                  5.0          -38.0        False       False           1
# 21                -23.0          -70.0         True       False           1
# 22                  5.0          -37.0        False       False           1
# 23                 12.0          -35.0        False       False           1
# 24                  5.0          -40.0        False       False           1
# 25                -30.0          -75.0         True       False           1
# 26                  5.0          -37.0        False       False           1
# 27                  5.0          -38.0        False       False           1
# 28                  5.0          -37.0        False       False           1
# 29                 12.0          -35.0        False       False           1
# ...                 ...            ...          ...         ...         ...
# 4071              -38.0          -86.0        False       False          23
# 4072              -45.0          -89.0        False       False          23
# 4073              -38.0          -85.0        False       False          23
# 4074              -38.0          -86.0        False       False          23
# 4075              -38.0          -85.0        False       False          23
# 4076              -38.0          -85.0        False       False          23
# 4077              -38.0          -86.0        False       False          23
# 4078              -45.0          -87.0        False       False          23
# 4079              -45.0          -87.0        False       False          23
# 4080              -38.0          -86.0        False       False          23
# 4081              -45.0          -88.0        False       False          23
# 4082              -38.0          -86.0        False       False          23
# 4083              -45.0          -88.0        False       False          23
# 4084              -45.0          -88.0        False       False          23
# 4085              -38.0          -85.0        False       False          23
# 4086              -45.0          -87.0        False       False          23
# 4087              -45.0          -88.0        False       False          23
# 4088              -45.0          -89.0        False       False          23
# 4089              -45.0          -88.0        False       False          23
# 4090              -45.0          -87.0        False       False          23
# 4091              -45.0          -87.0        False       False          23
# 4092              -45.0          -87.0        False       False          23
# 4093              -45.0          -93.0        False       False          23
# 4094              -45.0          -88.0        False       False          23
# 4095              -45.0          -88.0        False       False          23
# 4096              -45.0          -87.0        False       False          23
# 4097              -45.0          -93.0        False       False          23
# 4098              -45.0          -87.0        False       False          23
# 4099              -45.0          -87.0        False       False          23
# 4100              -45.0          -87.0        False       False          23
#
#      Day_of_week  isWeekend  isActualMovement  isPackedFruitequalFruit  \
# 0            Sun       True              True                     True
# 1            Sun       True              True                     True
# 2            Sun       True              True                     True
# 3            Sun       True              True                     True
# 4            Sun       True              True                     True
# 5            Sun       True              True                     True
# 6            Sun       True              True                     True
# 7            Sun       True              True                     True
# 8            Sun       True              True                     True
# 9            Sun       True              True                     True
# 10           Sun       True              True                     True
# 11           Sun       True              True                     True
# 12           Sun       True              True                     True
# 13           Sun       True              True                     True
# 14           Sun       True              True                    False
# 15           Sun       True              True                     True
# 16           Sun       True              True                     True
# 17           Sun       True              True                     True
# 18           Sun       True              True                     True
# 19           Sun       True              True                    False
# 20           Sun       True              True                     True
# 21           Sun       True              True                    False
# 22           Sun       True              True                     True
# 23           Sun       True              True                     True
# 24           Sun       True              True                     True
# 25           Sun       True              True                    False
# 26           Sun       True              True                     True
# 27           Sun       True              True                     True
# 28           Sun       True              True                     True
# 29           Sun       True              True                     True
# ...          ...        ...               ...                      ...
# 4071         Tue      False              True                     True
# 4072         Tue      False              True                     True
# 4073         Tue      False              True                     True
# 4074         Tue      False              True                     True
# 4075         Tue      False              True                     True
# 4076         Tue      False              True                     True
# 4077         Tue      False              True                     True
# 4078         Tue      False              True                     True
# 4079         Tue      False              True                     True
# 4080         Tue      False              True                     True
# 4081         Tue      False              True                     True
# 4082         Tue      False              True                     True
# 4083         Tue      False              True                     True
# 4084         Tue      False              True                     True
# 4085         Tue      False              True                     True
# 4086         Tue      False              True                     True
# 4087         Tue      False              True                     True
# 4088         Tue      False              True                     True
# 4089         Tue      False              True                     True
# 4090         Tue      False              True                     True
# 4091         Tue      False              True                     True
# 4092         Tue      False              True                     True
# 4093         Tue      False              True                     True
# 4094         Tue      False              True                     True
# 4095         Tue      False              True                     True
# 4096         Tue      False              True                     True
# 4097         Tue      False              True                     True
# 4098         Tue      False              True                     True
# 4099         Tue      False              True                     True
# 4100         Tue      False              True                     True
#
#      Previous_RoomRow Previous_Column Previous_Height distance_to_driveway  \
# 0                ALLO              na              na                   na
# 1              Q01-02               5               1                    8
# 2                ALLO              na              na                   na
# 3              Q02-03               2               1                   11
# 4              Q28-02              12               2                    1
# 5              Q01-01              10               1                    3
# 6              Q28-02              12               1                    1
# 7              Q02-03               1               1                   12
# 8              Q02-12              13               2                    0
# 9              Q30-23              12               1                    1
# 10             Q02-12              13               1                    0
# 11             Q16-14              11               2                    2
# 12             Q30-24              12               2                    1
# 13             Q30-22              12               1                    1
# 14             Q07-14               7               2                    6
# 15             Q30-22              11               2                    2
# 16             Q28-05              10               2                    3
# 17             Q16-13               5               1                    8
# 18             Q28-05               9               1                    4
# 19             Q12-19               2               2                   11
# 20              Q02-A              12               1                    1
# 21             Q12-19               1               2                   12
# 22             Q28-05               8               1                    5
# 23             Q16-12              12               2                    1
# 24             Q01-16               1               1                   12
# 25             Q12-16               7               2                    6
# 26             Q28-05               7               1                    6
# 27             Q16-12              12               1                    1
# 28             Q28-05               6               2                    7
# 29             Q01-23              12               2                    1
# ...               ...             ...             ...                  ...
# 4071           P03-10               5               2                    8
# 4072           Q10-04              10               2                    3
# 4073           Q10-05               5               2                    8
# 4074           P03-10               2               2                   11
# 4075           Q10-05               5               1                    8
# 4076           P03-04               7               2                    6
# 4077           Q10-05               4               2                    9
# 4078           Q10-05               4               1                    9
# 4079           Q10-05               3               2                   10
# 4080           P03-04               3               1                   10
# 4081           Q10-04               9               2                    4
# 4082           P03-03               4               2                    9
# 4083           Q10-04               9               1                    4
# 4084           Q10-04              11               1                    2
# 4085           P03-03               2               2                   11
# 4086           Q10-04               8               1                    5
# 4087           Q10-04               7               2                    6
# 4088           Q10-14               8               2                    5
# 4089           Q10-14               7               2                    6
# 4090           Q10-14               6               2                    7
# 4091           Q10-16               7               2                    6
# 4092           Q10-16               7               1                    6
# 4093           P02-14               7               2                    6
# 4094           Q10-03              10               2                    3
# 4095           Q10-03              10               1                    3
# 4096           Q10-03               9               1                    4
# 4097           P02-08               1               2                   12
# 4098           Q10-03               8               2                    5
# 4099           Q10-03               6               2                    7
# 4100           Q10-02              10               2                    3
#
#      Location Request Number  Loadout Priority Pallet Card Reference  \
# 0                         na               6.0             2216NIGHT
# 1                         na               6.0             3222NIGHT
# 2                         na               6.0                  3213
# 3                        NaN               NaN                   NaN
# 4                        NaN               NaN                   NaN
# 5                        NaN               NaN                   NaN
# 6                        NaN               NaN                   NaN
# 7                         na               6.0                  3215
# 8                        NaN               NaN                   NaN
# 9                        NaN               NaN                   NaN
# 10                        na               6.0             3211NIGHT
# 11                       NaN               NaN                   NaN
# 12                       NaN               NaN                   NaN
# 13                       NaN               NaN                   NaN
# 14                       NaN               NaN                   NaN
# 15                       NaN               NaN                   NaN
# 16                       NaN               NaN                   NaN
# 17                       NaN               NaN                   NaN
# 18                       NaN               NaN                   NaN
# 19                        na               3.0                  3171
# 20                        na               6.0             2216NIGHT
# 21                        na               3.0                    na
# 22                       NaN               NaN                   NaN
# 23                        na               4.0             3222NIGHT
# 24                       NaN               NaN                   NaN
# 25                        na               3.0               1165DAY
# 26                       NaN               NaN                   NaN
# 27                       NaN               NaN                   NaN
# 28                       NaN               NaN                   NaN
# 29                        na               4.0                    na
# ...                      ...               ...                   ...
# 4071                     NaN               NaN                   NaN
# 4072                     NaN               NaN                   NaN
# 4073                     NaN               NaN                   NaN
# 4074                     NaN               NaN                   NaN
# 4075                     NaN               NaN                   NaN
# 4076                     NaN               NaN                   NaN
# 4077                     NaN               NaN                   NaN
# 4078                     NaN               NaN                   NaN
# 4079                     NaN               NaN                   NaN
# 4080                     NaN               NaN                   NaN
# 4081                     NaN               NaN                   NaN
# 4082                     NaN               NaN                   NaN
# 4083                     NaN               NaN                   NaN
# 4084                     NaN               NaN                   NaN
# 4085                     NaN               NaN                   NaN
# 4086                     NaN               NaN                   NaN
# 4087                     NaN               NaN                   NaN
# 4088                     NaN               NaN                   NaN
# 4089                     NaN               NaN                   NaN
# 4090                     NaN               NaN                   NaN
# 4091                     NaN               NaN                   NaN
# 4092                     NaN               NaN                   NaN
# 4093                     NaN               NaN                   NaN
# 4094                     NaN               NaN                   NaN
# 4095                     NaN               NaN                   NaN
# 4096                     NaN               NaN                   NaN
# 4097                     NaN               NaN                   NaN
# 4098                     NaN               NaN                   NaN
# 4099                     NaN               NaN                   NaN
# 4100                     NaN               NaN                   NaN
#
#       Order Number  Shipment Type Code Destination Port Code  \
# 0        5334502.0                18.0                 BEZEE
# 1        5332701.0                 4.0                 INMAA
# 2        5340902.0                18.0                 CNSHG
# 3              NaN                 NaN                   NaN
# 4              NaN                 NaN                   NaN
# 5              NaN                 NaN                   NaN
# 6              NaN                 NaN                   NaN
# 7        5334601.0                18.0                 BEZEE
# 8              NaN                 NaN                   NaN
# 9              NaN                 NaN                   NaN
# 10       5337801.0                18.0                 BEZEE
# 11             NaN                 NaN                   NaN
# 12             NaN                 NaN                   NaN
# 13             NaN                 NaN                   NaN
# 14             NaN                 NaN                   NaN
# 15             NaN                 NaN                   NaN
# 16             NaN                 NaN                   NaN
# 17             NaN                 NaN                   NaN
# 18             NaN                 NaN                   NaN
# 19       5277502.0                18.0                 AUSYD
# 20       5164502.0                 1.0                 ESTAR
# 21       5277502.0                18.0                 AUSYD
# 22             NaN                 NaN                   NaN
# 23       5329304.0                18.0                 CNSHG
# 24             NaN                 NaN                   NaN
# 25       5277502.0                18.0                 AUSYD
# 26             NaN                 NaN                   NaN
# 27             NaN                 NaN                   NaN
# 28             NaN                 NaN                   NaN
# 29       5340905.0                18.0                 CNSHG
# ...            ...                 ...                   ...
# 4071           NaN                 NaN                   NaN
# 4072           NaN                 NaN                   NaN
# 4073           NaN                 NaN                   NaN
# 4074           NaN                 NaN                   NaN
# 4075           NaN                 NaN                   NaN
# 4076           NaN                 NaN                   NaN
# 4077           NaN                 NaN                   NaN
# 4078           NaN                 NaN                   NaN
# 4079           NaN                 NaN                   NaN
# 4080           NaN                 NaN                   NaN
# 4081           NaN                 NaN                   NaN
# 4082           NaN                 NaN                   NaN
# 4083           NaN                 NaN                   NaN
# 4084           NaN                 NaN                   NaN
# 4085           NaN                 NaN                   NaN
# 4086           NaN                 NaN                   NaN
# 4087           NaN                 NaN                   NaN
# 4088           NaN                 NaN                   NaN
# 4089           NaN                 NaN                   NaN
# 4090           NaN                 NaN                   NaN
# 4091           NaN                 NaN                   NaN
# 4092           NaN                 NaN                   NaN
# 4093           NaN                 NaN                   NaN
# 4094           NaN                 NaN                   NaN
# 4095           NaN                 NaN                   NaN
# 4096           NaN                 NaN                   NaN
# 4097           NaN                 NaN                   NaN
# 4098           NaN                 NaN                   NaN
# 4099           NaN                 NaN                   NaN
# 4100           NaN                 NaN                   NaN
#
#      Trucking Company Code                                       Market Holds  \
# 0                     OMOK         ID, IL, IN, JP, KR, MX, RE, TH, TW, Z7, Z9
# 1                     RAYT                                                 Z1
# 2                     K&ST                                         IL, TH, Z1
# 3                      NaN                                                NaN
# 4                      NaN                                                NaN
# 5                      NaN                                                NaN
# 6                      NaN                                                NaN
# 7                     K&ST                                                 na
# 8                      NaN                                                NaN
# 9                      NaN                                                NaN
# 10                    JCKL   AU, CN, ID, IL, IN, JP, KR, MX, RE, TH, TW, U...
# 11                     NaN                                                NaN
# 12                     NaN                                                NaN
# 13                     NaN                                                NaN
# 14                     NaN                                                NaN
# 15                     NaN                                                NaN
# 16                     NaN                                                NaN
# 17                     NaN                                                NaN
# 18                     NaN                                                NaN
# 19                    TRAZ                                         IL, TH, Z1
# 20                    PRIO                 ID, IN, JP, KR, MX, RE, TW, Z7, Z9
# 21                    TRAZ                                         IL, TH, Z1
# 22                     NaN                                                NaN
# 23                    TOLL   ID, IL, IN, JP, KR, MX, RE, TH, TW, US, Z1, Z...
# 24                     NaN                                                NaN
# 25                    TRAZ                                             IL, TH
# 26                     NaN                                                NaN
# 27                     NaN                                                NaN
# 28                     NaN                                                NaN
# 29                    K&ST                                                 Z1
# ...                    ...                                                ...
# 4071                   NaN                                                NaN
# 4072                   NaN                                                NaN
# 4073                   NaN                                                NaN
# 4074                   NaN                                                NaN
# 4075                   NaN                                                NaN
# 4076                   NaN                                                NaN
# 4077                   NaN                                                NaN
# 4078                   NaN                                                NaN
# 4079                   NaN                                                NaN
# 4080                   NaN                                                NaN
# 4081                   NaN                                                NaN
# 4082                   NaN                                                NaN
# 4083                   NaN                                                NaN
# 4084                   NaN                                                NaN
# 4085                   NaN                                                NaN
# 4086                   NaN                                                NaN
# 4087                   NaN                                                NaN
# 4088                   NaN                                                NaN
# 4089                   NaN                                                NaN
# 4090                   NaN                                                NaN
# 4091                   NaN                                                NaN
# 4092                   NaN                                                NaN
# 4093                   NaN                                                NaN
# 4094                   NaN                                                NaN
# 4095                   NaN                                                NaN
# 4096                   NaN                                                NaN
# 4097                   NaN                                                NaN
# 4098                   NaN                                                NaN
# 4099                   NaN                                                NaN
# 4100                   NaN                                                NaN
#
#       Envelope Number Container Container Number isDoi_Number  \
# 0            199054.0    8328.0      TTNU8962992        False
# 1            199154.0     529.0      TRIU8970380        False
# 2            199236.0    8542.0      TEMU9001169        False
# 3                 NaN       NaN              NaN          NaN
# 4                 NaN       NaN              NaN          NaN
# 5                 NaN       NaN              NaN          NaN
# 6                 NaN       NaN              NaN          NaN
# 7            199078.0    8319.0      TTNU8956773        False
# 8                 NaN       NaN              NaN          NaN
# 9                 NaN       NaN              NaN          NaN
# 10           199189.0    8459.0      BMOU9617905        False
# 11                NaN       NaN              NaN          NaN
# 12                NaN       NaN              NaN          NaN
# 13                NaN       NaN              NaN          NaN
# 14                NaN       NaN              NaN          NaN
# 15                NaN       NaN              NaN          NaN
# 16                NaN       NaN              NaN          NaN
# 17                NaN       NaN              NaN          NaN
# 18                NaN       NaN              NaN          NaN
# 19           197442.0    8164.0      CGMU5102420         True
# 20           199065.0        na               na        False
# 21           197442.0    8164.0      CGMU5102420         True
# 22                NaN       NaN              NaN          NaN
# 23           199131.0    8348.0      DFOU6133798        False
# 24                NaN       NaN              NaN          NaN
# 25           197442.0    8164.0      CGMU5102420         True
# 26                NaN       NaN              NaN          NaN
# 27                NaN       NaN              NaN          NaN
# 28                NaN       NaN              NaN          NaN
# 29           199231.0    8531.0      OERU4049327        False
# ...               ...       ...              ...          ...
# 4071              NaN       NaN              NaN          NaN
# 4072              NaN       NaN              NaN          NaN
# 4073              NaN       NaN              NaN          NaN
# 4074              NaN       NaN              NaN          NaN
# 4075              NaN       NaN              NaN          NaN
# 4076              NaN       NaN              NaN          NaN
# 4077              NaN       NaN              NaN          NaN
# 4078              NaN       NaN              NaN          NaN
# 4079              NaN       NaN              NaN          NaN
# 4080              NaN       NaN              NaN          NaN
# 4081              NaN       NaN              NaN          NaN
# 4082              NaN       NaN              NaN          NaN
# 4083              NaN       NaN              NaN          NaN
# 4084              NaN       NaN              NaN          NaN
# 4085              NaN       NaN              NaN          NaN
# 4086              NaN       NaN              NaN          NaN
# 4087              NaN       NaN              NaN          NaN
# 4088              NaN       NaN              NaN          NaN
# 4089              NaN       NaN              NaN          NaN
# 4090              NaN       NaN              NaN          NaN
# 4091              NaN       NaN              NaN          NaN
# 4092              NaN       NaN              NaN          NaN
# 4093              NaN       NaN              NaN          NaN
# 4094              NaN       NaN              NaN          NaN
# 4095              NaN       NaN              NaN          NaN
# 4096              NaN       NaN              NaN          NaN
# 4097              NaN       NaN              NaN          NaN
# 4098              NaN       NaN              NaN          NaN
# 4099              NaN       NaN              NaN          NaN
# 4100              NaN       NaN              NaN          NaN
#
#      isInternal_Holds isTemporary_Seal_Number isTemperature_Recorder_Number  \
# 0                True                    True                          True
# 1                True                    True                          True
# 2                True                    True                          True
# 3                 NaN                     NaN                           NaN
# 4                 NaN                     NaN                           NaN
# 5                 NaN                     NaN                           NaN
# 6                 NaN                     NaN                           NaN
# 7                True                    True                          True
# 8                 NaN                     NaN                           NaN
# 9                 NaN                     NaN                           NaN
# 10               True                    True                          True
# 11                NaN                     NaN                           NaN
# 12                NaN                     NaN                           NaN
# 13                NaN                     NaN                           NaN
# 14                NaN                     NaN                           NaN
# 15                NaN                     NaN                           NaN
# 16                NaN                     NaN                           NaN
# 17                NaN                     NaN                           NaN
# 18                NaN                     NaN                           NaN
# 19              False                    True                          True
# 20               True                   False                         False
# 21              False                    True                          True
# 22                NaN                     NaN                           NaN
# 23               True                    True                          True
# 24                NaN                     NaN                           NaN
# 25              False                    True                          True
# 26                NaN                     NaN                           NaN
# 27                NaN                     NaN                           NaN
# 28                NaN                     NaN                           NaN
# 29               True                    True                          True
# ...               ...                     ...                           ...
# 4071              NaN                     NaN                           NaN
# 4072              NaN                     NaN                           NaN
# 4073              NaN                     NaN                           NaN
# 4074              NaN                     NaN                           NaN
# 4075              NaN                     NaN                           NaN
# 4076              NaN                     NaN                           NaN
# 4077              NaN                     NaN                           NaN
# 4078              NaN                     NaN                           NaN
# 4079              NaN                     NaN                           NaN
# 4080              NaN                     NaN                           NaN
# 4081              NaN                     NaN                           NaN
# 4082              NaN                     NaN                           NaN
# 4083              NaN                     NaN                           NaN
# 4084              NaN                     NaN                           NaN
# 4085              NaN                     NaN                           NaN
# 4086              NaN                     NaN                           NaN
# 4087              NaN                     NaN                           NaN
# 4088              NaN                     NaN                           NaN
# 4089              NaN                     NaN                           NaN
# 4090              NaN                     NaN                           NaN
# 4091              NaN                     NaN                           NaN
# 4092              NaN                     NaN                           NaN
# 4093              NaN                     NaN                           NaN
# 4094              NaN                     NaN                           NaN
# 4095              NaN                     NaN                           NaN
# 4096              NaN                     NaN                           NaN
# 4097              NaN                     NaN                           NaN
# 4098              NaN                     NaN                           NaN
# 4099              NaN                     NaN                           NaN
# 4100              NaN                     NaN                           NaN
#
#      isLocation_Mission_Request_Destination isPermanentSeal Pallet Note  \
# 0                                     False           False       False
# 1                                     False           False       False
# 2                                     False           False       False
# 3                                       NaN             NaN         NaN
# 4                                       NaN             NaN         NaN
# 5                                       NaN             NaN         NaN
# 6                                       NaN             NaN         NaN
# 7                                     False           False       False
# 8                                       NaN             NaN         NaN
# 9                                       NaN             NaN         NaN
# 10                                    False           False       False
# 11                                      NaN             NaN         NaN
# 12                                      NaN             NaN         NaN
# 13                                      NaN             NaN         NaN
# 14                                      NaN             NaN         NaN
# 15                                      NaN             NaN         NaN
# 16                                      NaN             NaN         NaN
# 17                                      NaN             NaN         NaN
# 18                                      NaN             NaN         NaN
# 19                                    False           False       False
# 20                                    False           False       False
# 21                                    False           False       False
# 22                                      NaN             NaN         NaN
# 23                                    False           False       False
# 24                                      NaN             NaN         NaN
# 25                                    False           False       False
# 26                                      NaN             NaN         NaN
# 27                                      NaN             NaN         NaN
# 28                                      NaN             NaN         NaN
# 29                                    False           False       False
# ...                                     ...             ...         ...
# 4071                                    NaN             NaN         NaN
# 4072                                    NaN             NaN         NaN
# 4073                                    NaN             NaN         NaN
# 4074                                    NaN             NaN         NaN
# 4075                                    NaN             NaN         NaN
# 4076                                    NaN             NaN         NaN
# 4077                                    NaN             NaN         NaN
# 4078                                    NaN             NaN         NaN
# 4079                                    NaN             NaN         NaN
# 4080                                    NaN             NaN         NaN
# 4081                                    NaN             NaN         NaN
# 4082                                    NaN             NaN         NaN
# 4083                                    NaN             NaN         NaN
# 4084                                    NaN             NaN         NaN
# 4085                                    NaN             NaN         NaN
# 4086                                    NaN             NaN         NaN
# 4087                                    NaN             NaN         NaN
# 4088                                    NaN             NaN         NaN
# 4089                                    NaN             NaN         NaN
# 4090                                    NaN             NaN         NaN
# 4091                                    NaN             NaN         NaN
# 4092                                    NaN             NaN         NaN
# 4093                                    NaN             NaN         NaN
# 4094                                    NaN             NaN         NaN
# 4095                                    NaN             NaN         NaN
# 4096                                    NaN             NaN         NaN
# 4097                                    NaN             NaN         NaN
# 4098                                    NaN             NaN         NaN
# 4099                                    NaN             NaN         NaN
# 4100                                    NaN             NaN         NaN
#
#       duration_hr  dif_CustomerLabelCode  dif_LabellingIndicatorCode  \
# 0      335.496667                  False                       False
# 1      266.217778                   True                       False
# 2      443.263056                  False                       False
# 3      286.965833                  False                       False
# 4      333.211944                  False                       False
# 5      266.170556                  False                       False
# 6      166.326111                  False                       False
# 7      217.253611                  False                       False
# 8      309.177778                  False                       False
# 9      555.381389                  False                       False
# 10     217.755556                  False                       False
# 11     107.320556                  False                       False
# 12     165.531111                  False                       False
# 13     186.292222                  False                       False
# 14      34.616389                  False                       False
# 15     285.965278                  False                       False
# 16     291.758333                  False                       False
# 17     285.959444                  False                       False
# 18     337.091111                  False                       False
# 19      12.927500                  False                       False
# 20     103.963889                  False                       False
# 21      14.313889                  False                       False
# 22     310.308611                  False                       False
# 23     336.416944                  False                       False
# 24     308.251667                  False                       False
# 25      12.820833                  False                       False
# 26     186.098056                  False                       False
# 27     265.150000                  False                       False
# 28     168.570556                  False                       False
# 29     217.149444                  False                       False
# ...           ...                    ...                         ...
# 4071     0.000000                  False                       False
# 4072     0.000000                  False                       False
# 4073     0.020556                  False                       False
# 4074     0.015833                  False                       False
# 4075     0.000000                  False                       False
# 4076     0.010278                  False                       False
# 4077     0.000000                  False                       False
# 4078     0.000000                  False                       False
# 4079     0.000000                  False                       False
# 4080     0.000000                  False                       False
# 4081     0.018056                  False                       False
# 4082     0.010000                  False                       False
# 4083     0.009167                  False                       False
# 4084     0.027500                  False                       False
# 4085     0.008611                  False                       False
# 4086     0.009444                  False                       False
# 4087     0.000000                  False                       False
# 4088     0.011389                  False                       False
# 4089     0.000000                  False                       False
# 4090     0.012778                  False                       False
# 4091     0.000000                  False                       False
# 4092     0.010833                  False                       False
# 4093     0.016389                  False                       False
# 4094     0.000000                  False                       False
# 4095     0.000000                  False                       False
# 4096     0.012222                  False                       False
# 4097     0.020556                  False                       False
# 4098     0.013333                  False                       False
# 4099     0.013056                  False                       False
# 4100     0.000000                  False                       False
#
#       dif_PackCode  dif_PackMakeCode  dif_PackStyleCode  \
# 0            False             False              False
# 1            False             False              False
# 2            False             False              False
# 3            False             False              False
# 4            False             False              False
# 5            False             False              False
# 6            False             False              False
# 7            False              True              False
# 8            False             False              False
# 9            False             False              False
# 10           False              True              False
# 11           False             False              False
# 12           False             False              False
# 13           False             False              False
# 14           False             False              False
# 15           False             False              False
# 16           False             False              False
# 17           False             False              False
# 18           False             False              False
# 19           False             False              False
# 20           False             False              False
# 21           False             False              False
# 22           False             False              False
# 23           False             False              False
# 24           False             False              False
# 25           False             False              False
# 26           False             False              False
# 27           False             False              False
# 28           False             False              False
# 29           False             False              False
# ...            ...               ...                ...
# 4071         False             False              False
# 4072         False             False              False
# 4073         False             False              False
# 4074         False             False              False
# 4075         False             False              False
# 4076         False             False              False
# 4077         False             False              False
# 4078         False             False              False
# 4079         False             False              False
# 4080         False             False              False
# 4081         False             False              False
# 4082         False             False              False
# 4083         False             False              False
# 4084         False             False              False
# 4085         False             False              False
# 4086         False             False              False
# 4087         False             False              False
# 4088         False             False              False
# 4089         False             False              False
# 4090         False             False              False
# 4091         False             False              False
# 4092         False             False              False
# 4093         False             False              False
# 4094         False             False              False
# 4095         False             False              False
# 4096         False             False              False
# 4097         False             False              False
# 4098         False             False              False
# 4099         False             False              False
# 4100         False             False              False
#
#       dif_StackingConfigurationCode  Load_Start_Date_hour  \
# 0                             False                 383.0
# 1                             False                 671.0
# 2                              True                 671.0
# 3                             False                   NaN
# 4                             False                   NaN
# 5                             False                   NaN
# 6                             False                   NaN
# 7                              True                 383.0
# 8                             False                   NaN
# 9                             False                   NaN
# 10                             True                 551.0
# 11                            False                   NaN
# 12                            False                   NaN
# 13                            False                   NaN
# 14                            False                   NaN
# 15                            False                   NaN
# 16                            False                   NaN
# 17                            False                   NaN
# 18                            False                   NaN
# 19                            False                 166.0
# 20                            False                 358.0
# 21                            False                 166.0
# 22                            False                   NaN
# 23                             True                 502.0
# 24                            False                   NaN
# 25                            False                 166.0
# 26                            False                   NaN
# 27                            False                   NaN
# 28                            False                   NaN
# 29                             True                 670.0
# ...                             ...                   ...
# 4071                          False                   NaN
# 4072                          False                   NaN
# 4073                          False                   NaN
# 4074                          False                   NaN
# 4075                          False                   NaN
# 4076                          False                   NaN
# 4077                          False                   NaN
# 4078                          False                   NaN
# 4079                          False                   NaN
# 4080                          False                   NaN
# 4081                          False                   NaN
# 4082                          False                   NaN
# 4083                          False                   NaN
# 4084                          False                   NaN
# 4085                          False                   NaN
# 4086                          False                   NaN
# 4087                          False                   NaN
# 4088                          False                   NaN
# 4089                          False                   NaN
# 4090                          False                   NaN
# 4091                          False                   NaN
# 4092                          False                   NaN
# 4093                          False                   NaN
# 4094                          False                   NaN
# 4095                          False                   NaN
# 4096                          False                   NaN
# 4097                          False                   NaN
# 4098                          False                   NaN
# 4099                          False                   NaN
# 4100                          False                   NaN
#
#       qty_same_order_process
# 0                       24.0
# 1                        4.0
# 2                       28.0
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        8.0
# 8                        NaN
# 9                        NaN
# 10                      40.0
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                      12.0
# 20                      46.0
# 21                      12.0
# 22                       NaN
# 23                      22.0
# 24                       NaN
# 25                      12.0
# 26                       NaN
# 27                       NaN
# 28                       NaN
# 29                      14.0
# ...                      ...
# 4071                     NaN
# 4072                     NaN
# 4073                     NaN
# 4074                     NaN
# 4075                     NaN
# 4076                     NaN
# 4077                     NaN
# 4078                     NaN
# 4079                     NaN
# 4080                     NaN
# 4081                     NaN
# 4082                     NaN
# 4083                     NaN
# 4084                     NaN
# 4085                     NaN
# 4086                     NaN
# 4087                     NaN
# 4088                     NaN
# 4089                     NaN
# 4090                     NaN
# 4091                     NaN
# 4092                     NaN
# 4093                     NaN
# 4094                     NaN
# 4095                     NaN
# 4096                     NaN
# 4097                     NaN
# 4098                     NaN
# 4099                     NaN
# 4100                     NaN
#
# [4101 rows x 43 columns]

# %% [markdown]
# ### Derive Quantity of Pallet with same order (incl pallet in other status)

# %% [markdown]
# ### Derive Quantity of Pallet ald sitting in Process Preparation Room - need to define the Room

# %% [markdown]
# ### Derive quantity of pallet tagged with process as per transaction time

# %% [markdown]
# ### Derive forklift driver on duty in that shift (incl all rows in transaction)

# %% [markdown]
# ### Derive pallet process per day ( as an estimation of number of process worker)

# %%
df_pallet.head(3)
# Out:
#   Transaction Date Time  Pallet Number  Pallet Rework Count  \
# 0   2019-07-01 00:00:39       59669482                    0
# 1   2019-07-01 00:01:20       59685451                    0
# 2   2019-07-01 00:02:20       59431225                    0
#
#    Ok_Until_Date_day  Pack_Date_day  isDOINumber  isDayShift  Shift_Hour  \
# 0                5.0          -38.0        False       False           0
# 1               12.0          -35.0        False       False           0
# 2                5.0          -41.0        False       False           0
#
#   Day_of_week  isWeekend  isActualMovement  isPackedFruitequalFruit  \
# 0         Sun       True              True                     True
# 1         Sun       True              True                     True
# 2         Sun       True              True                     True
#
#   Previous_RoomRow Previous_Column Previous_Height distance_to_driveway  \
# 0             ALLO              na              na                   na
# 1           Q01-02               5               1                    8
# 2             ALLO              na              na                   na
#
#   Location Request Number CCKPassed Failed  Loadout Priority  \
# 0                      na             True               6.0
# 1                      na             True               6.0
# 2                      na             True               6.0
#
#   Pallet Card Reference  Order Number  Shipment Type Code  \
# 0             2216NIGHT     5334502.0                18.0
# 1             3222NIGHT     5332701.0                 4.0
# 2                  3213     5340902.0                18.0
#
#   Destination Port Code Trucking Company Code  \
# 0                 BEZEE                  OMOK
# 1                 INMAA                  RAYT
# 2                 CNSHG                  K&ST
#
#                                   Market Holds  Envelope Number Container  \
# 0   ID, IL, IN, JP, KR, MX, RE, TH, TW, Z7, Z9         199054.0    8328.0
# 1                                           Z1         199154.0     529.0
# 2                                   IL, TH, Z1         199236.0    8542.0
#
#   Container Number isDoi_Number isInternal_Holds isTemporary_Seal_Number  \
# 0      TTNU8962992        False             True                    True
# 1      TRIU8970380        False             True                    True
# 2      TEMU9001169        False             True                    True
#
#   isTemperature_Recorder_Number isLocation_Mission_Request_Destination  \
# 0                          True                                  False
# 1                          True                                  False
# 2                          True                                  False
#
#   isPermanentSeal Pallet Note  duration_hr  dif_CustomerLabelCode  \
# 0           False       False   335.496667                  False
# 1           False       False   266.217778                   True
# 2           False       False   443.263056                  False
#
#    dif_LabellingIndicatorCode  dif_PackCode  dif_PackMakeCode  \
# 0                       False         False             False
# 1                       False         False             False
# 2                       False         False             False
#
#    dif_PackStyleCode  dif_StackingConfigurationCode  Load_Start_Date_hour
# 0              False                          False                 383.0
# 1              False                          False                 671.0
# 2              False                           True                 671.0

# %%
df_pallet.shape
# Out:
# (4101, 42)

# %%
['Japan Sub Brand Code','Trial Packing Indicator Code','Brand Code','Fruit Class Code','Growing Method']

# %%
df_pallet['CCKPassed Failed'].value_counts(dropna=False)
# Out:
# True     2267
# NaN      1484
# False     280
# na         70
# Name: CCKPassed Failed, dtype: int64

# %%
df_pallet[df_pallet['Growing Method']=='OB']['Japan Sub Brand Code']
# Out:
# 1504    N
# 2657    N
# 2659    N
# 2662    N
# Name: Japan Sub Brand Code, dtype: object

# %%
summary_object(df_pallet)
# Out:
# SUMMARY OF 31 NON-NUMERICAL ATTRIBUTES:
#
# 20 Object Columns
# 11 Bool Columns
#                                  Attribute Count Unique Missing (%)  \
# 1                    Pallet Card Reference  2617    281     36.1863
# 2                                Container  2617    231     36.1863
# 3                         Container Number  2617    231     36.1863
# 4                             Market Holds  2617    170     36.1863
# 5                    Destination Port Code  2617     39     36.1863
# 6                  Location Request Number  2617     26     36.1863
# 7                    Trucking Company Code  2617     21     36.1863
# 8                             isDoi_Number  2617      3     36.1863
# 9                         isInternal_Holds  2617      3     36.1863
# 10                 isTemporary_Seal_Number  2617      3     36.1863
# 11           isTemperature_Recorder_Number  2617      3     36.1863
# 12  isLocation_Mission_Request_Destination  2617      3     36.1863
# 13                         isPermanentSeal  2617      3     36.1863
# 14                             Pallet Note  2617      3     36.1863
# 15                   Transaction Date Time  4101   4097           0
# 16                        Previous_RoomRow  4101    816           0
# 17                         Previous_Column  4101     14           0
# 18                    distance_to_driveway  4101     14           0
# 19                             Day_of_week  4101      7           0
# 20                         Previous_Height  4101      3           0
# 21                             isDOINumber  4101      2           0
# 22                              isDayShift  4101      2           0
# 23                               isWeekend  4101      2           0
# 24                        isActualMovement  4101      2           0
# 25                 isPackedFruitequalFruit  4101      2           0
# 26                   dif_CustomerLabelCode  4101      2           0
# 27              dif_LabellingIndicatorCode  4101      2           0
# 28                            dif_PackCode  4101      2           0
# 29                        dif_PackMakeCode  4101      2           0
# 30                       dif_PackStyleCode  4101      2           0
# 31           dif_StackingConfigurationCode  4101      2           0
#
#                     Top    Top (%)                               Bottom  \
# 1                    na    9.90002                              2167DAY
# 2                    na    10.6559                               8247.0
# 3                    na    10.6559                          BMOU9615190
# 4                    na    13.3382   AU, ID, IN, KR, MX, RE, TW, Z1, Z7
# 5                 CNSHG    20.3365                                BRSSZ
# 6                    na    60.2536                               1835.0
# 7                  BUKL    10.8998                                 FMBT
# 8                 False    60.5706                                 True
# 9                  True    35.1622                                False
# 10                 True    52.6945                                False
# 11                 True    53.1578                                False
# 12                False    60.2536                                 True
# 13                False    63.3504                                 True
# 14                False    61.5703                                 True
# 15  2019-07-05 20:02:36  0.0487686                  2019-07-13 19:44:49
# 16             Q51-RACK    4.70617                               Q30-15
# 17                    1    18.4101                                   13
# 18                   12    18.4101                                    0
# 19                  Sat    23.3114                                  Wed
# 20                    1    51.1826                                   na
# 21                False    96.6594                                 True
# 22                False    75.1524                                 True
# 23                False    57.3762                                 True
# 24                 True    99.9756                                False
# 25                 True    88.3931                                False
# 26                False    95.5864                                 True
# 27                False    97.9761                                 True
# 28                False    97.4884                                 True
# 29                False    98.4394                                 True
# 30                False    99.8293                                 True
# 31                False    64.3745                                 True
#
#    Bottom (%)
# 1   0.0243843
# 2   0.0243843
# 3   0.0243843
# 4   0.0243843
# 5   0.0243843
# 6   0.0243843
# 7     0.17069
# 8     3.24311
# 9     28.6515
# 10    11.1192
# 11    10.6559
# 12    3.56011
# 13   0.463302
# 14    2.24336
# 15  0.0243843
# 16  0.0243843
# 17    0.17069
# 18    0.17069
# 19    7.46159
# 20     1.2436
# 21    3.34065
# 22    24.8476
# 23    42.6238
# 24  0.0243843
# 25    11.6069
# 26    4.41356
# 27     2.0239
# 28    2.51158
# 29    1.56059
# 30    0.17069
# 31    35.6255

# %%
summary_numerical(df_pallet)
# Out:
# SUMMARY OF 12 NUMERICAL ATTRIBUTES:
#               Attribute   Count  Missing (%)          Mean        Median  \
# 1      Loadout Priority  2617.0    36.186296  4.976691e+00  5.000000e+00
# 2      Fruit Class Code  2617.0    36.186296  1.007260e+00  1.000000e+00
# 3          Order Number  2617.0    36.186296  5.268613e+06  5.316303e+06
# 4     Order Line Number  2617.0    36.186296  4.093198e+01  3.000000e+01
# 5    Shipment Type Code  2617.0    36.186296  1.365533e+01  1.800000e+01
# 6       Envelope Number  2617.0    36.186296  1.989988e+05  1.991520e+05
# 7         Pallet Number  4101.0     0.000000  5.838087e+07  5.743471e+07
# 8   Pallet Rework Count  4101.0     0.000000  1.663009e-01  0.000000e+00
# 9           duration_hr  4101.0     0.000000  8.174529e+01  2.841778e+01
# 10        Pack_Date_day  4101.0     0.000000 -6.583663e+01 -6.700000e+01
# 11           Shift_Hour  4101.0     0.000000  1.175055e+01  1.100000e+01
# 12    Ok_Until_Date_day  4101.0     0.000000 -2.951536e+02 -2.100000e+01
#
#            Min           Max  Skewness   Kurtosis
# 1          1.0  3.000000e+01       NaN        NaN
# 2          1.0  2.000000e+00       NaN        NaN
# 3    1905900.0  5.353901e+06       NaN        NaN
# 4         10.0  2.900000e+02       NaN        NaN
# 5          1.0  1.800000e+01       NaN        NaN
# 6     193026.0  1.993310e+05       NaN        NaN
# 7   53188620.0  8.050098e+07  6.863408  75.559917
# 8          0.0  5.000000e+00  4.402782  19.420978
# 9          0.0  7.073836e+02  2.266328   4.567369
# 10      -112.0 -2.000000e+00  0.243254  -0.707320
# 11         0.0  2.300000e+01 -0.006605  -1.651768
# 12    -10796.0  4.200000e+01 -6.005782  34.074367

# %%
df_pallet[df_pallet['Load Start Date'].isna()]['Pallet Number'].count()
# Out:
# 1484

# %%
df_pallet[df_pallet['Order Number'].isna()]['Pallet Number'].count()
# Out:
# 1484

# %%
df_pallet.shape
# Out:
# (4101, 75)
