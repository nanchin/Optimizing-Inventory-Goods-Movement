# %% [markdown]
# ## 1) Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import gc

from scipy.stats import skew,kurtosis
import datetime

# %%
# %matplotlib inline
# to view all columns
pd.set_option('display.max_columns',500)
plt.style.use('seaborn')

# %% [markdown]
# ## 2) Read Dataset

# %%
filepath='/home/nan/Desktop/GitHub_Data/Dispatched.csv'

# %%
filename=filepath.rstrip('.csv')
df=pd.read_csv(filepath)
# Out:
# /home/nan/miniconda3/envs/tf36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (9,22,23,53,65,70,96,97,121,122,123,125,132) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## 3) User Defined Function

# %%
def get_datatype(arg_df):
    
    col_bool=[]
    col_object=[]
    col_number=[]
    col_catogory=[]
    
    for col in arg_df.columns:
        datatype=arg_df[col].dtypes
        if datatype==bool:
            col_bool.append(col)
        elif datatype==object :
            col_object.append(col)
        elif str(datatype)=='category':
            col_catogory.append(col)
        else:
            col_number.append(col)
    print('This dataset has {} Columns\nbool\t:{} \nobject\t:{}  \ncategory:{} \nnumeric\t:{} '
          .format(len(arg_df.columns),len(col_bool),len(col_object),len(col_catogory),len(col_number)))
    
    del arg_df
    gc.collect()
    
    return col_bool,col_object,col_catogory,col_number

'==================================================================='
def summary_object(arg_df):
    
    object_list=[]
    category_list=[]
    bool_list=[]
    unilabel_list=[]
    missing_list=[]
    
    for c in arg_df.columns:
        if arg_df[c].dtypes==object:
            object_list.append(c)
        elif str(arg_df[c].dtypes)=='category':
            category_list.append(c)
        elif arg_df[c].dtypes==bool:
            bool_list.append(c)
    if len(object_list)+len(category_list)+len(bool_list)>0:    
        index_list=['Count','Unique','Missing (%)','Top','Top (%)','Bottom','Bottom (%)']
        df_summary=pd.DataFrame(data=np.zeros((len(index_list),len(object_list))),index=index_list,columns=object_list)

        for col in object_list+category_list+bool_list:
            vc=arg_df[col].value_counts().reset_index()
            df_summary.loc['Count',col]=(arg_df[col].count())
            df_summary.loc['Unique',col]=len(arg_df[col].unique())
            df_summary.loc['Missing (%)',col]=arg_df[col].isna().mean()*100
            df_summary.loc['Top',col]=vc.iloc[0,0]
            df_summary.loc['Top (%)',col]=vc.iloc[0,1]/len(arg_df)*100
            if len(arg_df[col].unique())>1:
                df_summary.loc['Bottom',col]=vc.iloc[-1,0]
                df_summary.loc['Bottom (%)',col]=vc.iloc[-1,1]/len(arg_df)*100
            else:
                unilabel_list.append(col)
            if df_summary.loc['Missing (%)',col]==100:
                missing_list.append(col)
                
        df_summary=df_summary.T.sort_values(['Missing (%)','Unique'],ascending=False)
        df_summary=df_summary[(df_summary['Unique']>1) & (df_summary['Missing (%)']!=100)]
        df_summary.reset_index(inplace=True)
        df_summary.index=df_summary.index+1
        df_summary.columns=['Attribute']+index_list
        
        print('SUMMARY OF {} NON-NUMERICAL ATTRIBUTES:\n'.format(
            len(object_list)+len(category_list)+len(bool_list)))
        if len(object_list)>0:
            print('{} Object Columns'.format(len(object_list)))
        if len(category_list)>0:
            print('{} Categorical Columns'.format(len(category_list)))
        if len(bool_list)>0:
            print('{} Bool Columns'.format(len(bool_list)))
        if len(unilabel_list)>0:
            print('\n{} Columns with Single Label : \n{}'.format(len(unilabel_list),unilabel_list))
        if len(missing_list)>0:
            print('\n{} Empty Columns: \n{}'.format(len(missing_list),missing_list))   
            
        del arg_df,object_list,vc,index_list,unilabel_list,missing_list
        gc.collect()
        return df_summary
    else:
        print('No Non-Numerical Attributes')
'==================================================================='        
def summary_numerical(arg_df):

    target_list=[]
    missing_list=[]
    zero_skew_list=[]
    
    for c in arg_df.columns:
        datatype=arg_df[c].dtypes
        if datatype != object and datatype != bool and str(datatype) != 'category' and str(datatype)!='datetime64[ns]':
            target_list.append(c)
    if len(target_list)>0:
        from scipy.stats import skew,kurtosis
        
        index_list=['Count','Missing (%)','Mean','Median','Min','Max','Skewness','Kurtosis']
        df_summary=pd.DataFrame(data=np.zeros((len(index_list),len(target_list))),
                                index=index_list,columns=target_list)
        for col in target_list:
            df_summary.loc['Count',col]=arg_df[col].count()
            df_summary.loc['Missing (%)',col]=arg_df[col].isna().mean()*100
            if df_summary.loc['Missing (%)',col]!=100:
                df_summary.loc['Mean',col]=arg_df[col].mean()
                df_summary.loc['Median',col]=arg_df[col].median()
                df_summary.loc['Min',col]=arg_df[col].min()
                df_summary.loc['Max',col]=arg_df[col].max()
                df_summary.loc['Skewness',col]=skew(arg_df[col])
                if df_summary.loc['Skewness',col]==0:
                    zero_skew_list.append(col)
                df_summary.loc['Kurtosis',col]=kurtosis(arg_df[col])
            else:
                missing_list.append(col)
                
        df_summary=df_summary.T.sort_values(['Missing (%)','Skewness'],ascending=False)
        df_summary=df_summary[(df_summary['Skewness']!=0) & (df_summary['Missing (%)']!=100)]
        df_summary.reset_index(inplace=True)
        df_summary.index=df_summary.index+1
        df_summary.columns=['Attribute']+index_list
        
        print('SUMMARY OF {} NUMERICAL ATTRIBUTES:'.format(len(target_list)))
        if len(zero_skew_list)>0:
            print('\n{} Columns with Single Value: \n{}'.format(len(zero_skew_list),zero_skew_list))
        if len(missing_list)>0:
            print('\n{} Empty Columns: \n{}'.format(len(missing_list),missing_list))
        del arg_df,target_list,index_list
        gc.collect()

        return df_summary
    else:
        print('No Numerical Attributes')
'==================================================================='        
def export_Data_Description(arg_df,**kwarg):
    from scipy.stats import skew
    data_description=pd.DataFrame()
    for c in arg_df.columns:
        data_description.loc[c,'Datatype']=arg_df[c].dtypes
        data_description.loc[c,'Missing%']='{:.3f}'.format((len(arg_df[c])-arg_df[c].count())/len(arg_df[c])*100)
        if (len(arg_df[c])-arg_df[c].count())/len(arg_df[c])*100!=100:
            if arg_df[c].dtypes==object:
                data_description.loc[c,'Unique']=len(arg_df[c].unique())
                if len(arg_df[c].unique())==1:
                    data_description.loc[c,'Remark']='Dropped because this column has only single lable'
                else:
                    data_description.loc[c,'Remark']='Frequent: {} ({:.3f} %)'.format(
                        arg_df[c].mode()[0],arg_df[arg_df[c]==arg_df[c].mode()[0]][c].count()/len(arg_df[c])*100)
            else:
                if skew(arg_df[c])==0:
                    data_description.loc[c,'Unique']=1
                    data_description.loc[c,'Remark']='Dropped because this column has only single value'
                else:
                    data_description.loc[c,'Remark']='MAX: {:.3f} MIN: {:.3f} MEAN: {:.3f} STD: {:.3f}'.format(
                        arg_df[c].max(),arg_df[c].min(),arg_df[c].mean(),arg_df[c].std())
        else:
            data_description.loc[c,'Remark']='Dropped because this column is empty'
    data_description.reset_index(inplace=True)
    data_description.index=data_description.index+1
    data_description=data_description.rename(columns={'index':'Attribute'})
    if ('surfix' in kwarg):
        data_description.to_excel('data_description_{}.xlsx'.format(kwarg['surfix']))
    else:
        import datetime
        currentDT = datetime.datetime.now()
        time=str(currentDT.year)+'-'+str(currentDT.month)+'-'+str(currentDT.day)+' '+str(currentDT.hour)+str(currentDT.minute)+str(currentDT.second)
        data_description.to_excel('data_description_{}.xlsx'.format(time))
'==================================================================='        
def rectify_to_object(arg_df,col_list):

    if len(col_list)>0:
        for columns in col_list:
            arg_df[columns]=arg_df[columns].astype('object',inplace=True)
        print('Change Datatype of {} Column to Object : \n{}'.format(len(col_list),col_list))
'==================================================================='        
def drop_unilable_column(arg_df):
    
    target_list=[]
    object_list=[]
    number_list=[]
    for c in arg_df.columns:
        if (arg_df[c].dtypes==object) | (str(arg_df[c].dtypes)=='category') | (arg_df[c].dtypes==bool):
            object_list.append(c)
        else:
            number_list.append(c)
    if len(object_list)>0:    
        for c in object_list:
            if len(arg_df[c].unique())==1:
                target_list.append(c)
    
    if len(number_list)>0:   
        from scipy.stats import skew
        for c in number_list:
            if skew(arg_df[c])==0:
                target_list.append(c)
                
    if len(target_list)>0:
        arg_df.drop(columns=target_list,axis='columns',inplace=True)
        print('Drop {} Columns with Single Label:\n{}'.format(len(target_list),target_list))
    else: 
        print('No Columns with Single Label/Value')

    del target_list,object_list
def drop_empty_column(arg_df):
    target_list=[]
    for c in arg_df.columns:
        if arg_df[c].count()==0:
            target_list.append(c)
    if len(target_list)>0:
        arg_df.drop(columns=target_list,axis=1,inplace=True)
        print('Delete {} Empty Column : \n{}'.format(len(target_list),target_list))
    else:
        print('No Empty Column')
'==================================================================='        
def export_description(arg_df,str_1,str_2):
    arg_df.groupby(str_1)[str_2].value_counts(dropna=False,
                                              ascending=False).to_frame().to_csv('{}.csv'.format(str_2))
'==================================================================='        
def find_time_dif_day(arg_df,ref_date,proc_date):
    new_date_attribute=[c.replace(' ','_') for c in proc_date]
    for idx,c in enumerate(proc_date):
        arg_df[new_date_attribute[idx]+'_day']=arg_df[c]-arg_df[ref_date]
        arg_df[new_date_attribute[idx]+'_day']=arg_df[new_date_attribute[idx]+'_day'].astype('timedelta64[D]')
'==================================================================='        
def find_time_dif_hour(arg_df,ref_date,proc_date):
    new_date_attribute=[c.replace(' ','_') for c in proc_date]
    for idx,c in enumerate(proc_date):
        arg_df[new_date_attribute[idx]+'_hour']=arg_df[c]-arg_df[ref_date]
        arg_df[new_date_attribute[idx]+'_hour']=arg_df[new_date_attribute[idx]+'_hour'].astype('timedelta64[h]')
'==================================================================='        
def drop_columns(arg_df,column_names):
    arg_df.drop(columns=column_names,axis='columns',inplace=True)
    print('Drop {} columns : \n{}'.format(len(column_names),column_names))
'===================================================================' 
def extract_room_row(arg_df,col_position):
    '''To return unique Room-Row from standard Room-Row-Column-Height position data'''
    roomrow=[]
    roomrow=arg_df[col_position].apply(lambda x :x.split('-')[0]+'-'+x.split('-')[1] if '-' in x else x)
    #roomrow=roomrow.unique().tolist()
    #roomrow=pd.DataFrame(roomrow,columns=['Unique_Row']).sort_values(by='Unique_Row')
    return roomrow

# %% [markdown]
# ## 4) Basic Checks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32257 entries, 0 to 32256
# Columns: 133 entries, Pallet Number to Permanent Seal Number
# dtypes: bool(3), float64(15), int64(22), object(93)
# memory usage: 32.1+ MB

# %%
bool_list,object_list,cat_list,num_list=get_datatype(df)
# Out:
# This dataset has 133 Columns
# bool	:3
# object	:93
# category:0
# numeric	:37

# %%
df.head(3)
# Out:
#    Pallet Number Coolstore Code Coolstore Description Location Room Code  \
# 0       54510208           3TPK  EastPack Quarry Road                Q27
# 1       54510260           3TPK  EastPack Quarry Road            UNKNOWN
# 2       54510253           3TPK  EastPack Quarry Road               ALLO
#
#   Location Room Description Location Row Code  Location Column  \
# 0              Coolstore 27                 A             11.0
# 1          Unknown Location               NaN              NaN
# 2               Allocations               NaN              NaN
#
#    Location Height  Location Request Number  \
# 0              1.0                      NaN
# 1              0.0                      NaN
# 2              1.0                      NaN
#
#   Location Mission Request Destination Storage Source Code  \
# 0                                  NaN                  CN
# 1                                  NaN                  CN
# 2                                  NaN                  CN
#
#   Storage Source Description Storage Method Code Storage Method Description  \
# 0               Conventional                  CN               Conventional
# 1               Conventional                  CN               Conventional
# 2               Conventional                  CN               Conventional
#
#   Pack Label Code Pack Label Description Pack Indicator Code  \
# 0               N                   None                   N
# 1               N                   None                   N
# 2               N                   None                   N
#
#   Pack Indicator Description Clearance Protocol Code  \
# 0                      None                        A
# 1                      None                        A
# 2                      None                        A
#
#   Clearance Protocol Description Customer Label Code  \
# 0                     Protocol A                   N
# 1                     Protocol A                   N
# 2                     Protocol A                   N
#
#   Customer Label Description Last Ppqi Date Ppqi Passed Repack Date  \
# 0                       None            NaN         NaN         NaN
# 1                       None            NaN         NaN         NaN
# 2                       None            NaN         NaN         NaN
#
#   Last Spqi Date Dry Matter Code Dry Matter Description        Pack Date  \
# 0            NaN               Y            Extra Taste  18/03/2019 0:00
# 1            NaN               Y            Extra Taste  18/03/2019 0:00
# 2            NaN               Y            Extra Taste  18/03/2019 0:00
#
#   Pest Indicator Code Pest Indicator Description Storing Characteristic Code  \
# 0                   N             Not Applicable                           P
# 1                   N             Not Applicable                           P
# 2                   N             Not Applicable                           P
#
#                   Storing Characteristic Description  \
# 0  KiwiStart Submit any Wk ? Ship by Wk 21 Mainpa...
# 1  KiwiStart Submit any Wk ? Ship by Wk 21 Mainpa...
# 2  KiwiStart Submit any Wk ? Ship by Wk 21 Mainpa...
#
#   Conditioning Indicator Code Conditioning Indicator Description  \
# 0                           N                     Not Applicable
# 1                           N                     Not Applicable
# 2                           N                     Not Applicable
#
#   CCKPassed Failed Fruit Indicator Code Fruit Indicator Description  \
# 0              NaN                    N              Not Applicable
# 1              NaN                    N              Not Applicable
# 2              NaN                    N              Not Applicable
#
#   Quality Inspection Indicator Code Quality Inspection Indicator Description  \
# 0                                 A     Zespri Australia\Argentina Inspected
# 1                                 A     Zespri Australia\Argentina Inspected
# 2                                 A     Zespri Australia\Argentina Inspected
#
#    Disorder Indicator Code  Disorder Indicator Description  \
# 0                      NaN                             NaN
# 1                      NaN                             NaN
# 2                      NaN                             NaN
#
#    Global Gap Brc Indicator Code Global Gap Brc Indicator Description  \
# 0                              1                  GlobalGAP Compliant
# 1                              1                  GlobalGAP Compliant
# 2                              1                  GlobalGAP Compliant
#
#   Japan Sub Brand Code Japan Sub Brand Description  \
# 0                    N              Not applicable
# 1                    N              Not applicable
# 2                    N              Not applicable
#
#   Trial Packing Indicator Code Trial Packing Indicator Description  \
# 0                            N                                None
# 1                            N                                None
# 2                            N                                None
#
#    Marketer Description Marketer Code  Loadout Priority  \
# 0  Zespri International           ZIL                20
# 1  Zespri International           ZIL                20
# 2  Zespri International           ZIL                20
#
#    Online Sequence Number  Batch Sequence Number Material Number  \
# 0                       0                      0           61600
# 1                       0                      0           61577
# 2                       0                      0           61579
#
#    Material Mnemonic Material Group Code Nir Indicator Code Origin Code  \
# 0  ENIJ22CK1GAZNZJB0              Zespri                  N          NZ
# 1  ENML25CK1GAZNZGR0              Zespri                  N          NZ
# 2  ENML27CK1GAZNZGR0              Zespri                  N          NZ
#
#   Brand Code Origin Description Brand Description Variety Code  \
# 0          Z        New Zealand           Zespri?           GA
# 1          Z        New Zealand           Zespri?           GA
# 2          Z        New Zealand           Zespri?           GA
#
#   Variety Description  Fruit Class Code Fruit Class Description  \
# 0     ZESY002 SunGold                 1                 Class 1
# 1     ZESY002 SunGold                 1                 Class 1
# 2     ZESY002 SunGold                 1                 Class 1
#
#   Fruit Size Code Fruit Size Description  Pack Category Description  \
# 0              22                Size 22     EN International Jumbo
# 1              25                Size 25  Euro Normal Modular Loose
# 2              27                Size 27  Euro Normal Modular Loose
#
#   Pack Category Code Labelling Indicator Code Purchase Pool Code  \
# 0               ENIJ                       JB                 16
# 1               ENML                       GR                 16
# 2               ENML                       GR                 16
#
#   Purchase Pool Description  Pack Code Growing Method  Packs Per Pallet  \
# 0        NZ Class 1 Sungold      10168             CK               200
# 1        NZ Class 1 Sungold      10182             CK               160
# 2        NZ Class 1 Sungold      10181             CK               160
#
#   Ean Indicator Code Ean Indicator Description Maturity Indicator Code  \
# 0                  E             EAN Compliant                       C
# 1                  E             EAN Compliant                       C
# 2                  E             EAN Compliant                       A
#
#   Maturity Indicator Description  Ok Until Date  Supplier Code  \
# 0                     Protocol C  5/5/2019 0:00            434
# 1                     Protocol C  5/5/2019 0:00            434
# 2                     Protocol A  5/5/2019 0:00            434
#
#   Supplier Description  Plant Code Plant Description  Ignore Psr  \
# 0            Southlink        1103          Tauranga       False
# 1            Southlink        1103          Tauranga       False
# 2            Southlink        1103          Tauranga       False
#
#   Pack Type Code  Packed Fruit  Packed Trays  Pallet Rework Count  \
# 0        ENIJKC3          4400    200.000000                    0
# 1        ENMLKC6          6560    262.400000                    0
# 2        ENMLKC6          7040    260.740741                    0
#
#    Rework Description Packhouse Code Zespri Li Number Pallet Card Reference  \
# 0                 NaN           3TPP        LI1015327               3121DAY
# 1                 NaN           3TPP        LI1015327               3121DAY
# 2                 NaN           3TPP        LI1015327               3121DAY
#
#   Pallet Status Description  Pallet Card Note1  Pallet Card Note2  \
# 0                Despatched                NaN                NaN
# 1                Despatched                NaN                NaN
# 2                Despatched                NaN                NaN
#
#   Pallet Note Type Pallet Note Text  Fruit  Order Number  Order Line Number  \
# 0              NaN              NaN   4400       5146501                 20
# 1              NaN              NaN   6560       5166002                 20
# 2              NaN              NaN   7040       5147801                130
#
#        Loadout Date  Shipment Type Code Destination Port Code  \
# 0  28/03/2019 13:00                   1                 JPTYO
# 1    3/4/2019 16:00                  18                 SGSIN
# 2   30/03/2019 8:45                   1                 BEZEE
#
#   Trucking Company Code  Packs  Tray Equivalent      Kg  Full Market Holds  \
# 0                  PRHA    200       200.000000  715.00  True   KR, RE, Z7
# 1                  TOLL    160       262.400000  931.52  True   KR, RE, Z7
# 2                  OMOK    160       260.740741  922.24  True   KR, RE, Z7
#
#    Blocked Holds Internal Holds Stacking Configuration Code Pack Style Code  \
# 0            NaN            NaN                           N              IJ
# 1            NaN            NaN                           N              ML
# 2            NaN            NaN                           N              ML
#
#   Pack Make Code  Pack Iso  OKUntil ISODate  Pack Week  Rf Id Tag1  \
# 0            KC3       121              187         12         NaN
# 1            KC6       121              187         12         NaN
# 2            KC6       121              187         12         NaN
#
#    Pre Cooled  Load Start Date Australian Inspection Reference Doi Number  \
# 0       False  27/03/2019 0:00                             NaN        NaN
# 1       False    2/4/2019 0:00                             NaN        NaN
# 2       False  29/03/2019 0:00                             NaN        NaN
#
#   Doi Clearance Date  Envelope Number Tkl Email Date  Pallets  \
# 0                NaN           193017            NaN        1
# 1                NaN           193074            NaN        1
# 2                NaN           193042            NaN        1
#
#    Pallet Equivalents  Container Container Number Temperature Recorder Number  \
# 0                 1.0        NaN              NaN                         NaN
# 1                 1.0     7839.0      PCIU6069215                  FH1812C2K0
# 2                 1.0        NaN              NaN                         NaN
#
#   Temporary Seal Number Permanent Seal Number
# 0                   NaN                   NaN
# 1               T164297                   NaN
# 2                   NaN                   NaN

# %%
summary_object(df)
# Out:
# SUMMARY OF 96 NON-NUMERICAL ATTRIBUTES:
#
# 93 Object Columns
# 3 Bool Columns
#
# 19 Columns with Single Label :
# ['Coolstore Code', 'Coolstore Description', 'Storage Method Code', 'Storage Method Description', 'Pest Indicator Code', 'Pest Indicator Description', 'Conditioning Indicator Code', 'Conditioning Indicator Description', 'Fruit Indicator Code', 'Fruit Indicator Description', 'Global Gap Brc Indicator Description', 'Nir Indicator Code', 'Origin Code', 'Origin Description', 'Ean Indicator Code', 'Ean Indicator Description', 'Supplier Description', 'Pallet Status Description', 'Pre Cooled']
#                                    Attribute  Count Unique Missing (%)  \
# 1                             Last Ppqi Date      2      3     99.9938
# 2                                Ppqi Passed      2      2     99.9938
# 3                      Permanent Seal Number    176     14     99.4544
# 4                           Pallet Note Text    192     52     99.4048
# 5                           Pallet Note Type    192      3     99.4048
# 6       Location Mission Request Destination    257      4     99.2033
# 7            Australian Inspection Reference    488      7     98.4872
# 8                                 Doi Number    488      7     98.4872
# 9                         Doi Clearance Date    488      7     98.4872
# 10                               Repack Date    717    694     97.7772
# 11                         Location Row Code   1157     28     96.4132
# 12                            Internal Holds   3347     22      89.624
# 13                          CCKPassed Failed   4854      3     84.9521
# 14                            Last Spqi Date   4879   3688     84.8746
# 15                            Tkl Email Date   7057    288     78.1226
# 16                     Temporary Seal Number  19677   1042     38.9993
# 17               Temperature Recorder Number  19710   1030      38.897
# 18                          Container Number  19853   1050     38.4537
# 19                              Market Holds  23415    404     27.4111
# 20                     Pallet Card Reference  28425    648     11.8796
# 21                        Location Room Code  32250     44   0.0217007
# 22                 Location Room Description  32250     44   0.0217007
# 23                              Loadout Date  32257   1475           0
# 24                           Material Number  32257    391           0
# 25                         Material Mnemonic  32257    322           0
# 26                           Load Start Date  32257    107           0
# 27                                 Pack Date  32257    103           0
# 28                            Pack Type Code  32257     78           0
# 29                     Destination Port Code  32257     71           0
# 30                             Ok Until Date  32257     42           0
# ..                                       ...    ...    ...         ...
# 48                   Clearance Protocol Code  32257      6           0
# 49            Clearance Protocol Description  32257      6           0
# 50               Storing Characteristic Code  32257      6           0
# 51                   Fruit Class Description  32257      6           0
# 52                            Packhouse Code  32257      6           0
# 53                          Zespri Li Number  32257      6           0
# 54              Trial Packing Indicator Code  32257      5           0
# 55       Trial Packing Indicator Description  32257      5           0
# 56               Stacking Configuration Code  32257      5           0
# 57                       Pack Indicator Code  32257      4           0
# 58                Pack Indicator Description  32257      4           0
# 59                           Dry Matter Code  32257      4           0
# 60                    Dry Matter Description  32257      4           0
# 61                      Japan Sub Brand Code  32257      4           0
# 62               Japan Sub Brand Description  32257      4           0
# 63                       Material Group Code  32257      4           0
# 64                              Variety Code  32257      4           0
# 65                       Variety Description  32257      4           0
# 66                   Maturity Indicator Code  32257      4           0
# 67            Maturity Indicator Description  32257      4           0
# 68                       Storage Source Code  32257      3           0
# 69                Storage Source Description  32257      3           0
# 70         Quality Inspection Indicator Code  32257      3           0
# 71  Quality Inspection Indicator Description  32257      3           0
# 72                           Pack Label Code  32257      2           0
# 73                    Pack Label Description  32257      2           0
# 74                            Growing Method  32257      2           0
# 75                         Plant Description  32257      2           0
# 76                                Ignore Psr  32257      2           0
# 77                                      Full  32257      2           0
#
#                                      Top     Top (%)  \
# 1                         7/5/2019 15:34   0.0031001
# 2                                  False   0.0062002
# 3                               Z2810704    0.062002
# 4                            mast damage    0.089903
# 5                                GENERAL    0.589019
# 6                                  CONTR    0.771925
# 7                                 20-Jun    0.368912
# 8                                  MF030    0.368912
# 9                       20/06/2019 12:40    0.368912
# 10                         4/7/2019 9:56  0.00930031
# 11                                    16    0.319311
# 12                                    ID     5.61119
# 13                                  True     13.1537
# 14                        11/7/2019 0:00   0.0589019
# 15                       22/07/2019 7:31    0.331711
# 16                               T176892   0.0713024
# 17                                     0    0.260409
# 18                           TTNU8955756    0.124004
# 19                                    Z1     8.40128
# 20                                  3164    0.858728
# 21                               UNKNOWN     53.1916
# 22                      Unknown Location     53.1916
# 23                       20/04/2019 6:30    0.210807
# 24                                 62845     5.42518
# 25                     ENMB36CK1HWZNZLG0     5.42518
# 26                       31/07/2019 0:00     3.62712
# 27                       17/04/2019 0:00     3.78833
# 28                               ENMBKC1     16.0678
# 29                                 BEZEE      26.509
# 30                       19/05/2019 0:00     11.2658
# ..                                   ...         ...
# 48                                     N      79.096
# 49                            Protocol N      79.096
# 50                                     N     62.0175
# 51                               Class 1     97.7555
# 52                                  3TPP     98.1554
# 53                             LI1015327     98.1554
# 54                                     N     98.9863
# 55                                  None     98.9863
# 56                                     N     62.0206
# 57                                     N     99.5381
# 58                                 None      99.5381
# 59                                     Y     74.8985
# 60                           Extra Taste     74.8985
# 61                                     N     95.8459
# 62                        Not applicable     95.8459
# 63                                Zespri     98.2546
# 64                                    HW     49.2854
# 65                         Hayward Green     49.2854
# 66                                     N     90.2378
# 67                            Protocol N     90.2378
# 68                                    CN      93.217
# 69                          Conventional      93.217
# 70                                     A     98.5151
# 71  Zespri Australia\Argentina Inspected     98.5151
# 72                                     N     88.3467
# 73                                  None     88.3467
# 74                                    CK     97.1107
# 75                              Tauranga     97.0704
# 76                                 False     96.8348
# 77                                  True     99.7675
#
#                                              Bottom Bottom (%)
# 1                                    7/5/2019 15:37  0.0031001
# 2                                             False  0.0062002
# 3                                          z2810709  0.0155005
# 4                                            Base\n  0.0031001
# 5                                            IEHOLD  0.0062002
# 6                                              SPQI  0.0031001
# 7                                            15-Jul   0.114704
# 8                                             RT034   0.114704
# 9                                  25/06/2019 13:19   0.114704
# 10                                    8/7/2019 9:18  0.0031001
# 11                                           REJECT  0.0031001
# 12                                               IJ  0.0031001
# 13                                            False    1.89416
# 14                                   9/6/2019 16:51  0.0031001
# 15                                  15/07/2019 6:07  0.0031001
# 16                                          T169620  0.0031001
# 17                                       FH1812BJ00  0.0031001
# 18                                      cgmu5288952  0.0031001
# 19   AU, ID, IL, IN, JP, KR, RE, TH, TW, Z1, Z7, Z9  0.0031001
# 20                                          3171DAY  0.0031001
# 21                                             CA12  0.0031001
# 22                                            CA 12  0.0031001
# 23                                 23/07/2019 15:45  0.0031001
# 24                                            64101  0.0031001
# 25                                ENML30CK1GA6NZGR0  0.0031001
# 26                                  15/06/2019 0:00  0.0031001
# 27                                  18/07/2019 0:00  0.0031001
# 28                                          E1MBKE4  0.0031001
# 29                                            USLAX  0.0031001
# 30                                    1/6/2019 0:00  0.0031001
# ..                                              ...        ...
# 48                                                D   0.514617
# 49                                       Protocol D   0.514617
# 50                                                M   0.275909
# 51                               Class 2 Non Zespri  0.0155005
# 52                                             3CVF  0.0217007
# 53                                        LI1006412  0.0217007
# 54                                                I  0.0062002
# 55                               IT Packaging Trial  0.0062002
# 56                                                L   0.350312
# 57                                                R  0.0403013
# 58                       New Variety Research/Trial  0.0403013
# 59                                                R    1.67406
# 60                                   Reserved Taste    1.67406
# 61                                                9   0.486716
# 62                                             PINK   0.486716
# 63                                      LOCALMARKET   0.350312
# 64                                               HH   0.784326
# 65                                         Green 11   0.784326
# 66                                                A   0.942431
# 67                                       Protocol A   0.942431
# 68                                               BS    1.27414
# 69                                     Bulk Storage    1.27414
# 70                                                N  0.0031001
# 71                                  Not Applicable   0.0031001
# 72                                                T    11.6533
# 73                  RFID Temperature Monitoring Tag    11.6533
# 74                                               OB     2.8893
# 75                                    Collaborative     2.9296
# 76                                             True     3.1652
# 77                                            False   0.232508
#
# [77 rows x 8 columns]

# %%
summary_numerical(df)
# Out:
# SUMMARY OF 37 NUMERICAL ATTRIBUTES:
#
# 6 Columns with Single Value:
# ['Global Gap Brc Indicator Code', 'Online Sequence Number', 'Batch Sequence Number', 'Supplier Code', 'Pallet Rework Count', 'Pallets']
#
# 6 Empty Columns:
# ['Disorder Indicator Code', 'Disorder Indicator Description', 'Rework Description', 'Pallet Card Note1', 'Pallet Card Note2', 'Blocked Holds']
#                   Attribute    Count  Missing (%)          Mean        Median  \
# 1   Location Request Number    257.0    99.203274  1.925529e+03  1.922000e+03
# 2           Location Column   1157.0    96.413182  6.375108e+00  6.000000e+00
# 3                Rf Id Tag1   4073.0    87.373283  5.366427e+06  5.385446e+06
# 4                 Container  19853.0    38.453669  6.624575e+03  7.985000e+03
# 5           Location Height  32231.0     0.080603  4.809966e-01  0.000000e+00
# 6          Fruit Class Code  32257.0     0.000000  1.025793e+00  1.000000e+00
# 7             Pallet Number  32257.0     0.000000  5.773858e+07  5.713359e+07
# 8         Order Line Number  32257.0     0.000000  6.062321e+01  5.000000e+01
# 9          Loadout Priority  32257.0     0.000000  1.386986e+01  7.000000e+00
# 10                Pack Code  32257.0     0.000000  2.122341e+04  1.030900e+04
# 11                Pack Week  32257.0     0.000000  1.731528e+01  1.600000e+01
# 12                 Pack Iso  32257.0     0.000000  1.771352e+02  1.660000e+02
# 13          Envelope Number  32257.0     0.000000  1.955239e+05  1.938990e+05
# 14                    Fruit  32257.0     0.000000  8.434936e+03  8.320000e+03
# 15          OKUntil ISODate  32257.0     0.000000  2.498687e+02  2.470000e+02
# 16         Packs Per Pallet  32257.0     0.000000  1.647785e+02  1.600000e+02
# 17                    Packs  32257.0     0.000000  1.645630e+02  1.600000e+02
# 18             Packed Fruit  32257.0     0.000000  8.107314e+03  7.800000e+03
# 19       Shipment Type Code  32257.0     0.000000  9.587314e+00  4.000000e+00
# 20          Tray Equivalent  32257.0     0.000000  2.680445e+02  2.666667e+02
# 21                       Kg  32257.0     0.000000  9.501391e+02  9.377280e+02
# 22             Packed Trays  32257.0     0.000000  2.573974e+02  2.577778e+02
# 23               Plant Code  32257.0     0.000000  1.099983e+03  1.103000e+03
# 24             Order Number  32257.0     0.000000  5.133895e+06  5.208701e+06
# 25       Pallet Equivalents  32257.0     0.000000  9.986747e-01  1.000000e+00
#
#              Min           Max   Skewness    Kurtosis
# 1   1.815000e+03  2.065000e+03        NaN         NaN
# 2   1.000000e+00  1.300000e+01        NaN         NaN
# 3   5.079720e+05  5.417305e+06        NaN         NaN
# 4   1.000000e+02  9.979000e+03        NaN         NaN
# 5   0.000000e+00  2.000000e+00        NaN         NaN
# 6   1.000000e+00  3.000000e+00   7.645052   64.203954
# 7   5.317046e+07  9.850013e+07   6.468416   49.068727
# 8   1.000000e+01  4.160000e+02   1.868933    5.133527
# 9   1.000000e+00  5.000000e+01   1.493256    2.049571
# 10  0.000000e+00  7.633200e+04   1.370846    1.101559
# 11  1.200000e+01  3.100000e+01   1.212030    1.501738
# 12  1.210000e+02  3.110000e+02   1.210814    1.519880
# 13  1.930010e+05  1.993310e+05   0.400157   -1.535946
# 14  2.200000e+01  1.562000e+04   0.391869    0.110146
# 15  1.870000e+02  3.770000e+02   0.290579   -1.138056
# 16  2.000000e+01  2.560000e+02   0.211335   -1.221551
# 17  1.000000e+00  2.560000e+02   0.201154   -1.196556
# 18 -3.456000e+03  2.070000e+04   0.084030    0.940117
# 19  1.000000e+00  2.300000e+01   0.034426   -1.944122
# 20  1.000000e+00  3.404762e+02  -0.607518    2.720532
# 21  3.575000e+00  1.201597e+03  -0.935015    4.242600
# 22 -1.280000e+02  5.383333e+02  -1.898239   10.559757
# 23  1.000000e+03  1.103000e+03  -5.582524   29.164572
# 24  7.000100e+04  5.353901e+06  -7.270495   53.956324
# 25  5.000000e-03  1.000000e+00 -25.362973  681.485926

# %% [markdown]
# ## 5) Export Data Description

# %%
#export_Data_Description(transaction,surfix='transaction')

# %% [markdown]
# ## 6) Data Cleaning

# %% [markdown]
# ### Delete Columns

# %%
# drop empty columns
drop_empty_column(df)
# Out:
# Delete 6 Empty Column :
# ['Disorder Indicator Code', 'Disorder Indicator Description', 'Rework Description', 'Pallet Card Note1', 'Pallet Card Note2', 'Blocked Holds']

# %%
# drop unilabel/univalue columns
drop_unilable_column(df)
# Out:
# Drop 25 Columns with Single Label:
# ['Coolstore Code', 'Coolstore Description', 'Storage Method Code', 'Storage Method Description', 'Pest Indicator Code', 'Pest Indicator Description', 'Conditioning Indicator Code', 'Conditioning Indicator Description', 'Fruit Indicator Code', 'Fruit Indicator Description', 'Global Gap Brc Indicator Description', 'Nir Indicator Code', 'Origin Code', 'Origin Description', 'Ean Indicator Code', 'Ean Indicator Description', 'Supplier Description', 'Pallet Status Description', 'Pre Cooled', 'Global Gap Brc Indicator Code', 'Online Sequence Number', 'Batch Sequence Number', 'Supplier Code', 'Pallet Rework Count', 'Pallets']

# %% [markdown]
# ### Drop Duplicate Labels

# %%
before_drop=df.shape
df.drop_duplicates(inplace=True)
print('Total number of rows deleted :{} ({:.2f} %)'.format(
    (before_drop[0]-df.shape[0]),
    (before_drop[0]-df.shape[0])/before_drop[0]*100))
# Out:
# Total number of rows deleted :6 (0.02 %)

# %% [markdown]
# ### Export and Delete Descriptions

# %%
code=['Location Room Code','Storage Source Code','Pack Label Code','Pack Indicator Code','Clearance Protocol Code',
     'Customer Label Code','Dry Matter Code','Quality Inspection Indicator Code','Japan Sub Brand Code',
     'Trial Packing Indicator Code','Marketer Code','Brand Code','Variety Code','Fruit Size Code',
      'Pack Category Code','Purchase Pool Code','Maturity Indicator Code','Plant Code']

descrip=[x.replace('Code','Description') for x in code]

# %%
#for c,d in zip(code,descrip):
#    export_description(dispatched,c,d)

# %%
drop_columns(df,descrip)
# Out:
# Drop 18 columns :
# ['Location Room Description', 'Storage Source Description', 'Pack Label Description', 'Pack Indicator Description', 'Clearance Protocol Description', 'Customer Label Description', 'Dry Matter Description', 'Quality Inspection Indicator Description', 'Japan Sub Brand Description', 'Trial Packing Indicator Description', 'Marketer Description', 'Brand Description', 'Variety Description', 'Fruit Size Description', 'Pack Category Description', 'Purchase Pool Description', 'Maturity Indicator Description', 'Plant Description']

# %% [markdown]
# ### Drop 'OKUntil ISODate' because it is duplication of 'Ok Until Date'

# %%
drop_columns(df,['OKUntil ISODate'])
# Out:
# Drop 1 columns :
# ['OKUntil ISODate']

# %% [markdown]
# ### Drop 'Australian Inspection Reference' because it is duplication of 'DOI Number'

# %%
drop_columns(df,['Australian Inspection Reference'])
# Out:
# Drop 1 columns :
# ['Australian Inspection Reference']

# %% [markdown]
# ### Drop columns that have missing rate > 99.99%

# %%
drop_columns(df,['Last Ppqi Date','Ppqi Passed'])
# Out:
# Drop 2 columns :
# ['Last Ppqi Date', 'Ppqi Passed']

# %% [markdown]
# ### Drop columns that can be represented by Pack Type Code : 'Packs','Tray Equivalent','Fruit','Kg'

# %%
drop_columns(df,['Packs','Tray Equivalent','Fruit','Kg'])
# Out:
# Drop 4 columns :
# ['Packs', 'Tray Equivalent', 'Fruit', 'Kg']

# %% [markdown]
# ### Drop columns that can be represented by 'Full' : 'Packs Per Pallet','Packed Fruit','Packed Trays','Pallet Equivalents'
#     - Found 75 pallets that is not full

# %%
drop_columns(df,['Packs Per Pallet','Packed Fruit','Packed Trays','Pallet Equivalents'])
# Out:
# Drop 4 columns :
# ['Packs Per Pallet', 'Packed Fruit', 'Packed Trays', 'Pallet Equivalents']

# %% [markdown]
# ### Drop columns that can be represented by 'Pack Date' :'Pack Week','Pack ISO'

# %%
drop_columns(df,['Pack Week','Pack Iso'])
# Out:
# Drop 2 columns :
# ['Pack Week', 'Pack Iso']

# %% [markdown]
#     -'Zespri Li Number' duplicate of 'Packhouse Code'
#     -'Storing Characteristic Description' duplicate of 'Storing Characteristic Code'
#     -'Material Mnemonic' duplicate of 'Material Number'
#     -'Fruit Class Description' duplicates of 'Fruit Class Code'

# %%
drop_columns(df,['Zespri Li Number','Storing Characteristic Description','Material Mnemonic','Fruit Class Description'])
# Out:
# Drop 4 columns :
# ['Zespri Li Number', 'Storing Characteristic Description', 'Material Mnemonic', 'Fruit Class Description']

# %% [markdown]
# ## 7) Data Imputation

# %% [markdown]
# ### Replace Missing Data in Location Row Code, Column and Height,Location Mission Request Destination with 'na'

# %%
temp_list=['Location Row Code','Location Column','Location Height']

# %%
for c in temp_list:
    df.loc[df[c].isna(),c]='na'

# %% [markdown]
# ### Replace Missing Data in Location Room Code with 'UNKNOWN'

# %%
df.loc[df['Location Room Code'].isna(),'Location Room Code']='UNKNOWN'

# %% [markdown]
# ### Replace Missing Data with na

# %%
temp_list=['CCKPassed Failed','Container Number','Market Holds','Pallet Card Reference','Location Request Number','Rf Id Tag1','Container']

# %%
for c in temp_list:
    df.loc[df[c].isna(),c]='na'

# %% [markdown]
# ### Change to Boolean : Doi Number, Internal Holds,Temporary Seal Number, Temperature Recorder Number

# %%
temp_list=['Doi Number','Internal Holds','Temporary Seal Number','Temperature Recorder Number','Location Mission Request Destination','Rf Id Tag1']

# %%
for c in temp_list:
    new_c=c.replace(' ','_')
    new_c='is'+new_c
    df[new_c]=df[c].notnull()

# %%
drop_columns(df,temp_list)
# Out:
# Drop 6 columns :
# ['Doi Number', 'Internal Holds', 'Temporary Seal Number', 'Temperature Recorder Number', 'Location Mission Request Destination', 'Rf Id Tag1']

# %% [markdown]
# ### Permanent Seal Number: replace missing data with False, data with True since missing rate is 99.45%

# %%
df['isPermanentSeal']=df['Permanent Seal Number'].notnull()

# %%
drop_columns(df,['Permanent Seal Number'])
# Out:
# Drop 1 columns :
# ['Permanent Seal Number']

# %% [markdown]
# ### Pallet Note: combine Pallet Note Text and Type into Pallet Note (True/False)

# %%
df['Pallet Note']=(df['Pallet Note Text'].notnull()) & (df['Pallet Note Type'].notnull())

# %%
drop_columns(df,['Pallet Note Type','Pallet Note Text'])
# Out:
# Drop 2 columns :
# ['Pallet Note Type', 'Pallet Note Text']

# %% [markdown]
# ## 8) Derive Attributes

# %% [markdown]
# ### Derive Time Difference from Date Columns

# %%
date_attribute=[c for c in df.columns if 'Date' in c]
date_attribute
# Out:
# ['Repack Date',
#  'Last Spqi Date',
#  'Pack Date',
#  'Ok Until Date',
#  'Loadout Date',
#  'Load Start Date',
#  'Doi Clearance Date',
#  'Tkl Email Date']

# %%
for c in date_attribute:
    df[c]=pd.to_datetime(df[c],format='%d/%m/%Y %H:%M')

# %%
date_attribute.remove('Loadout Date')
date_attribute.remove('Load Start Date')

# %%
find_time_dif_day(df,'Loadout Date',date_attribute)

# %%
find_time_dif_hour(df,'Loadout Date',['Load Start Date'])

# %%
drop_columns(df,date_attribute)
# Out:
# Drop 6 columns :
# ['Repack Date', 'Last Spqi Date', 'Pack Date', 'Ok Until Date', 'Doi Clearance Date', 'Tkl Email Date']

# %% [markdown]
# ### Convert Numeric Category Attributes back to object datatype

# %%
temp_list=['Fruit Class Code','Pallet Number','Order Line Number','Loadout Priority','Pack Code','Envelope Number','Shipment Type Code','Plant Code','Order Number']

# %%
rectify_to_object(df,temp_list)
# Out:
# Change Datatype of 9 Column to Object :
# ['Fruit Class Code', 'Pallet Number', 'Order Line Number', 'Loadout Priority', 'Pack Code', 'Envelope Number', 'Shipment Type Code', 'Plant Code', 'Order Number']

# %%
summary_numerical(df)
# Out:
# SUMMARY OF 7 NUMERICAL ATTRIBUTES:
#                 Attribute    Count  Missing (%)       Mean  Median    Min  \
# 1  Doi_Clearance_Date_day    488.0    98.486869 -21.639344   -20.0  -62.0
# 2         Repack_Date_day    717.0    97.776813  -5.856346    -5.0  -38.0
# 3      Last_Spqi_Date_day   4874.0    84.887290  -9.365819    -9.0  -66.0
# 4      Tkl_Email_Date_day   7052.0    78.134011  -3.370959    -3.0   -9.0
# 5       Ok_Until_Date_day  32251.0     0.000000  21.564727    23.0   -2.0
# 6           Pack_Date_day  32251.0     0.000000 -30.462993   -20.0 -116.0
# 7    Load_Start_Date_hour  32251.0     0.000000 -27.584230   -31.0 -456.0
#
#     Max  Skewness   Kurtosis
# 1  -3.0       NaN        NaN
# 2  -1.0       NaN        NaN
# 3  -1.0       NaN        NaN
# 4  -1.0       NaN        NaN
# 5  46.0 -0.006213  -1.317638
# 6  -1.0 -1.198677   0.381977
# 7  87.0 -2.078956  23.745020

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32251 entries, 0 to 32256
# Data columns (total 66 columns):
# Pallet Number                             32251 non-null object
# Location Room Code                        32251 non-null object
# Location Row Code                         32251 non-null object
# Location Column                           32251 non-null object
# Location Height                           32251 non-null object
# Location Request Number                   32251 non-null object
# Storage Source Code                       32251 non-null object
# Pack Label Code                           32251 non-null object
# Pack Indicator Code                       32251 non-null object
# Clearance Protocol Code                   32251 non-null object
# Customer Label Code                       32251 non-null object
# Dry Matter Code                           32251 non-null object
# Storing Characteristic Code               32251 non-null object
# CCKPassed Failed                          32251 non-null object
# Quality Inspection Indicator Code         32251 non-null object
# Japan Sub Brand Code                      32251 non-null object
# Trial Packing Indicator Code              32251 non-null object
# Marketer Code                             32251 non-null object
# Loadout Priority                          32251 non-null object
# Material Number                           32251 non-null object
# Material Group Code                       32251 non-null object
# Brand Code                                32251 non-null object
# Variety Code                              32251 non-null object
# Fruit Class Code                          32251 non-null object
# Fruit Size Code                           32251 non-null object
# Pack Category Code                        32251 non-null object
# Labelling Indicator Code                  32251 non-null object
# Purchase Pool Code                        32251 non-null object
# Pack Code                                 32251 non-null object
# Growing Method                            32251 non-null object
# Maturity Indicator Code                   32251 non-null object
# Plant Code                                32251 non-null object
# Ignore Psr                                32251 non-null bool
# Pack Type Code                            32251 non-null object
# Packhouse Code                            32251 non-null object
# Pallet Card Reference                     32251 non-null object
# Order Number                              32251 non-null object
# Order Line Number                         32251 non-null object
# Loadout Date                              32251 non-null datetime64[ns]
# Shipment Type Code                        32251 non-null object
# Destination Port Code                     32251 non-null object
# Trucking Company Code                     32251 non-null object
# Full                                      32251 non-null bool
# Market Holds                              32251 non-null object
# Stacking Configuration Code               32251 non-null object
# Pack Style Code                           32251 non-null object
# Pack Make Code                            32251 non-null object
# Load Start Date                           32251 non-null datetime64[ns]
# Envelope Number                           32251 non-null object
# Container                                 32251 non-null object
# Container Number                          32251 non-null object
# isDoi_Number                              32251 non-null bool
# isInternal_Holds                          32251 non-null bool
# isTemporary_Seal_Number                   32251 non-null bool
# isTemperature_Recorder_Number             32251 non-null bool
# isLocation_Mission_Request_Destination    32251 non-null bool
# isRf_Id_Tag1                              32251 non-null bool
# isPermanentSeal                           32251 non-null bool
# Pallet Note                               32251 non-null bool
# Repack_Date_day                           717 non-null float64
# Last_Spqi_Date_day                        4874 non-null float64
# Pack_Date_day                             32251 non-null float64
# Ok_Until_Date_day                         32251 non-null float64
# Doi_Clearance_Date_day                    488 non-null float64
# Tkl_Email_Date_day                        7052 non-null float64
# Load_Start_Date_hour                      32251 non-null float64
# dtypes: bool(10), datetime64[ns](2), float64(7), object(47)
# memory usage: 14.3+ MB

# %% [markdown]
# ## Export

# %%
df.to_csv('p_dispatched',index=False)
