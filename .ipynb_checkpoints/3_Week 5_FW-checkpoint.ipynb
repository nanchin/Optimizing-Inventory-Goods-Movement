# %% [markdown]
# Updates:
# - 11 oct: change input file from p_transaction to p_transaction_2 --> reduce transaction with no changes from 800->400
#
# - 12 Oct 2pm-3.30pm : completed extraction of Multiple Process per Pallet --> able to extract individual process duration for each pallet
# - 12 Oct 11pm-2.30pm : complete identifcation of packaging changes, done prepare process_multiple for merging with dispatched
#
# Next:
# merge with dispatched

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import gc

from scipy.stats import skew,kurtosis
import datetime
import re
import fnmatch

# %%
# %matplotlib inline
# to view all columns
pd.set_option('display.max_columns',500)
plt.style.use('seaborn')

# %%
def summary_object(arg_df):
    
    object_list=[]
    category_list=[]
    bool_list=[]
    unilabel_list=[]
    missing_list=[]
    
    for c in arg_df.columns:
        if arg_df[c].dtypes==object:
            object_list.append(c)
        elif str(arg_df[c].dtypes)=='category':
            category_list.append(c)
        elif arg_df[c].dtypes==bool:
            bool_list.append(c)
    if len(object_list)+len(category_list)+len(bool_list)>0:    
        index_list=['Count','Unique','Missing (%)','Top','Top (%)','Bottom','Bottom (%)']
        df_summary=pd.DataFrame(data=np.zeros((len(index_list),len(object_list))),index=index_list,columns=object_list)

        for col in object_list+category_list+bool_list:
            vc=arg_df[col].value_counts().reset_index()
            df_summary.loc['Count',col]=(arg_df[col].count())
            df_summary.loc['Unique',col]=len(arg_df[col].unique())
            df_summary.loc['Missing (%)',col]=arg_df[col].isna().mean()*100
            df_summary.loc['Top',col]=vc.iloc[0,0]
            df_summary.loc['Top (%)',col]=vc.iloc[0,1]/len(arg_df)*100
            if len(arg_df[col].unique())>2:
                df_summary.loc['Bottom',col]=vc.iloc[-1,0]
                df_summary.loc['Bottom (%)',col]=vc.iloc[-1,1]/len(arg_df)*100
            elif (len(arg_df[col].unique())==2) & (df_summary.loc['Missing (%)',col]==0):
                df_summary.loc['Bottom',col]=vc.iloc[-1,0]
                df_summary.loc['Bottom (%)',col]=vc.iloc[-1,1]/len(arg_df)*100
            else:
                unilabel_list.append(col)
            if df_summary.loc['Missing (%)',col]==100:
                missing_list.append(col)
                
        df_summary=df_summary.T.sort_values(['Missing (%)','Unique'],ascending=False)
        df_summary=df_summary[(df_summary['Unique']>1) & (df_summary['Missing (%)']!=100)]
        df_summary.reset_index(inplace=True)
        df_summary.index=df_summary.index+1
        df_summary.columns=['Attribute']+index_list
        
        print('SUMMARY OF {} NON-NUMERICAL ATTRIBUTES:\n'.format(
            len(object_list)+len(category_list)+len(bool_list)))
        if len(object_list)>0:
            print('{} Object Columns'.format(len(object_list)))
        if len(category_list)>0:
            print('{} Categorical Columns'.format(len(category_list)))
        if len(bool_list)>0:
            print('{} Bool Columns'.format(len(bool_list)))
        if len(unilabel_list)>0:
            print('\n{} Columns with Single Label : \n{}'.format(len(unilabel_list),unilabel_list))
        if len(missing_list)>0:
            print('\n{} Empty Columns: \n{}'.format(len(missing_list),missing_list))   
            
        del arg_df,object_list,vc,index_list,unilabel_list,missing_list
        gc.collect()
        return df_summary
    else:
        print('No Non-Numerical Attributes')
'============================================================='        
def summary_numerical(arg_df):

    target_list=[]
    missing_list=[]
    zero_skew_list=[]
    
    for c in arg_df.columns:
        datatype=arg_df[c].dtypes
        if datatype != object and datatype != bool and str(datatype) != 'category' and str(datatype) !='datetime64[ns]':
            target_list.append(c)
    if len(target_list)>0:
        from scipy.stats import skew,kurtosis
        
        index_list=['Count','Missing (%)','Mean','Median','Min','Max','Skewness','Kurtosis']
        df_summary=pd.DataFrame(data=np.zeros((len(index_list),len(target_list))),
                                index=index_list,columns=target_list)
        for col in target_list:
            df_summary.loc['Count',col]=arg_df[col].count()
            df_summary.loc['Missing (%)',col]=arg_df[col].isna().mean()*100
            if df_summary.loc['Missing (%)',col]!=100:
                df_summary.loc['Mean',col]=arg_df[col].mean()
                df_summary.loc['Median',col]=arg_df[col].median()
                df_summary.loc['Min',col]=arg_df[col].min()
                df_summary.loc['Max',col]=arg_df[col].max()
                df_summary.loc['Skewness',col]=skew(arg_df[col])
                if df_summary.loc['Skewness',col]==0:
                    zero_skew_list.append(col)
                df_summary.loc['Kurtosis',col]=kurtosis(arg_df[col])
            else:
                missing_list.append(col)
                
        df_summary=df_summary.T.sort_values(['Missing (%)','Skewness'],ascending=False)
        df_summary=df_summary[(df_summary['Skewness']!=0) & (df_summary['Missing (%)']!=100)]
        df_summary.reset_index(inplace=True)
        df_summary.index=df_summary.index+1
        df_summary.columns=['Attribute']+index_list
        
        print('SUMMARY OF {} NUMERICAL ATTRIBUTES:'.format(len(target_list)))
        if len(zero_skew_list)>0:
            print('\n{} Columns with Single Value: \n{}'.format(len(zero_skew_list),zero_skew_list))
        if len(missing_list)>0:
            print('\n{} Empty Columns: \n{}'.format(len(missing_list),missing_list))
        del arg_df,target_list,index_list
        gc.collect()

        return df_summary
    else:
        print('No Numerical Attributes')
'==================================================================='        
def drop_unilable_column(arg_df):
    
    target_list=[]
    object_list=[]
    number_list=[]
    for c in arg_df.columns:
        if (arg_df[c].dtypes==object) | (str(arg_df[c].dtypes)=='category') | (arg_df[c].dtypes==bool):
            object_list.append(c)
        elif str(arg_df[c].dtypes)!='datetime64[ns]':
            number_list.append(c)
    if len(object_list)>0:    
        for c in object_list:
            if len(arg_df[c].unique())==1:
                target_list.append(c)
            elif (len(arg_df[c].unique())==2) & (arg_df[c].isna().mean()>0):
                target_list.append(c)
    
    if len(number_list)>0:   
        from scipy.stats import skew
        for c in number_list:
            if skew(arg_df[c])==0:
                target_list.append(c)
                
    if len(target_list)>0:
        arg_df.drop(columns=target_list,axis='columns',inplace=True)
        print('Drop {} Columns with Single Label:\n{}'.format(len(target_list),target_list))
    else: 
        print('No Columns with Single Label/Value')

    del target_list,object_list
'===================================================================' 
def drop_empty_column(arg_df):
    target_list=[]
    for c in arg_df.columns:
        if arg_df[c].count()==0:
            target_list.append(c)
    if len(target_list)>0:
        arg_df.drop(columns=target_list,axis=1,inplace=True)
        print('Delete {} Empty Column : \n{}'.format(len(target_list),target_list))
    else:
        print('No Empty Column')
'==================================================================='        
def drop_columns(arg_df,column_names):
    arg_df.drop(columns=column_names,axis='columns',inplace=True)
    print('Drop {} columns : \n{}'.format(len(column_names),column_names))
'============================================================='        
def extract_room_row(arg_df,col_position):
    '''To return unique Room-Row from standard Room-Row-Column-Height position data'''
    roomrow=[]
    roomrow=arg_df[col_position].apply(lambda x :x.split('-')[0]+'-'+x.split('-')[1] if '-' in x else x)
    roomrow=roomrow.unique().tolist()
    roomrow=pd.DataFrame(roomrow,columns=['Unique_Row']).sort_values(by='Unique_Row')
    return roomrow['Unique_Row'].values
'============================================================='  
def generate_dif_columns(arg_df,left_column,left_sffx,right_sffx):
    common_title=[]
    for idx,c in enumerate(left_column):
        common_title.append(left_column[idx].split(left_sffx)[0])
    print('There are {} common columns : \n{}'.format(len(left_column),common_title))

    for idx,c in enumerate(common_title):
        compare_col=common_title[idx].replace(' ','')
        arg_df['dif_'+compare_col]=(arg_df[c+left_sffx]!=arg_df[c+right_sffx]) & (arg_df[c+right_sffx].notna())
    print('\nColumns Generated : {}'.format(len(common_title)))
'==================================================================='        
def find_time_dif_hour(arg_df,ref_date,proc_date):
    new_date_attribute=[c.replace(' ','_') for c in proc_date]
    for idx,c in enumerate(proc_date):
        arg_df[new_date_attribute[idx]+'_hour']=arg_df[c]-arg_df[ref_date]
        arg_df[new_date_attribute[idx]+'_hour']=arg_df[new_date_attribute[idx]+'_hour'].astype('timedelta64[h]')

# %% [markdown]
# # 1) Import 2 dataset : trans and disp

# %%
path='C:/Users/Nan/Documents/GitHub_Data/'
file_1=path+'p_transaction_2.csv'
file_2=path+'p_dispatched.csv'

filename_1=file_1
filename_2=file_2

sffx_transaction='_Trsc'
sffx_dispatched='_Dptch'
target_process='FW'

# %%
filename_1
# Out:
# 'C:/Users/Nan/Documents/GitHub_Data/p_transaction_2.csv'

# %%
trans=pd.read_csv(filename_1)
disp=pd.read_csv(filename_2)
# Out:
# C:\Users\Nan\AppData\Local\conda\conda\envs\env\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
trans.shape
# Out:
# (207259, 48)

# %%
trans.head(2)
# Out:
#   Transaction Date Time Customer Label Code Dry Matter Code  Fruit  \
# 0   2019-07-01 00:00:10                   N               Y  13000
# 1   2019-07-01 00:00:15                   N               Y   9216
#
#    Fruit Per Pack Fruit Size Code Labelling Indicator Code  \
# 0             130              42                       LG
# 1              36              36                       LG
#
#   Location Mission Request Destination Marketer Code Material Number  \
# 0                                   na           ZIL           62853
# 1                                   na           ZIL           62809
#
#     New Value        Ok Until Date  Pack Code            Pack Date  \
# 0  Q02-03-4-1  2019-07-21 00:00:00      41236  2019-06-06 00:00:00
# 1  Q14-15-9-2  2019-07-21 00:00:00      41717  2019-06-05 00:00:00
#
#    Packed Fruit Packhouse Code Pack Label Code Pack Make Code  Packs  \
# 0         13000           3TPP               N            KC1    100
# 1          9216           3TPP               N            KC1    256
#
#    Pallet Number  Pallet Rework Count  Plant Code Previous Value  \
# 0       59717008                    0        1103     Q02-03-3-1
# 1       59708334                    0        1103    Q14-02-10-1
#
#   Protocol Code Purchase Pool Code Quality Inspection Indicator Code  \
# 0             N                 01                                 A
# 1             N                 01                                 A
#
#   Storage Method Code     Transaction Date Transaction Sub Type Code  \
# 0                  CN  2019-07-01 00:00:10                       MLA
# 1                  CN  2019-07-01 00:00:15                       MTA
#
#        Trays Username Variety Code  Ok_Until_Date_day  Pack_Date_day  \
# 0  309.52381    agubs           HW               19.0          -26.0
# 1  256.00000   jaspsi           HW               19.0          -27.0
#
#    isDOINumber Pack Style Code Pack_Base Stacking Configuration Code  \
# 0        False              MB         E                           N
# 1        False              IT         E                           3
#
#    isDayShift  Shift_Hour Day_of_week  isWeekend  isActualMovement  \
# 0       False           0         Sun       True              True
# 1       False           0         Sun       True              True
#
#    isPackedFruitequalFruit Previous_RoomRow Previous_Column Previous_Height  \
# 0                     True           Q02-03               3               1
# 1                     True           Q14-02              10               1
#
#   distance_to_driveway
# 0                   10
# 1                    3

# %%
disp.shape
# Out:
# (32251, 71)

# %%
disp.head(2)
# Out:
#    Pallet Number Location Room Code Location Row Code Location Column  \
# 0       54510208                Q27                 A            11.0
# 1       54510260            UNKNOWN                na              na
#
#   Location Height Location Request Number Storage Source Code Pack Label Code  \
# 0             1.0                      na                  CN               N
# 1             0.0                      na                  CN               N
#
#   Pack Indicator Code Clearance Protocol Code Customer Label Code  \
# 0                   N                       A                   N
# 1                   N                       A                   N
#
#   Dry Matter Code Storing Characteristic Code CCKPassed Failed  \
# 0               Y                           P               na
# 1               Y                           P               na
#
#   Quality Inspection Indicator Code Japan Sub Brand Code  \
# 0                                 A                    N
# 1                                 A                    N
#
#   Trial Packing Indicator Code Marketer Code  Loadout Priority  \
# 0                            N           ZIL                20
# 1                            N           ZIL                20
#
#   Material Number Material Group Code Brand Code Variety Code  \
# 0           61600              Zespri          Z           GA
# 1           61577              Zespri          Z           GA
#
#    Fruit Class Code Fruit Size Code Pack Category Code  \
# 0                 1              22               ENIJ
# 1                 1              25               ENML
#
#   Labelling Indicator Code Purchase Pool Code  Pack Code Growing Method  \
# 0                       JB                 16      10168             CK
# 1                       GR                 16      10182             CK
#
#    Packs Per Pallet Maturity Indicator Code        Ok Until Date  Plant Code  \
# 0               200                       C  2019-05-05 00:00:00        1103
# 1               160                       C  2019-05-05 00:00:00        1103
#
#    Ignore Psr Pack Type Code  Packed Fruit  Packed Trays Packhouse Code  \
# 0       False        ENIJKC3          4400         200.0           3TPP
# 1       False        ENMLKC6          6560         262.4           3TPP
#
#   Pallet Card Reference  Fruit  Order Number  Order Line Number  \
# 0               3121DAY   4400       5146501                 20
# 1               3121DAY   6560       5166002                 20
#
#           Loadout Date  Shipment Type Code Destination Port Code  \
# 0  2019-03-28 13:00:00                   1                 JPTYO
# 1  2019-04-03 16:00:00                  18                 SGSIN
#
#   Trucking Company Code  Packs  Full Market Holds Stacking Configuration Code  \
# 0                  PRHA    200  True   KR, RE, Z7                           N
# 1                  TOLL    160  True   KR, RE, Z7                           N
#
#   Pack Style Code Pack Make Code      Load Start Date  Envelope Number  \
# 0              IJ            KC3  2019-03-27 00:00:00           193017
# 1              ML            KC6  2019-04-02 00:00:00           193074
#
#   Container Container Number  isDoi_Number  isInternal_Holds  \
# 0        na               na         False             False
# 1    7839.0      PCIU6069215         False             False
#
#    isTemporary_Seal_Number  isTemperature_Recorder_Number  \
# 0                    False                          False
# 1                     True                           True
#
#    isLocation_Mission_Request_Destination  isRf_Id_Tag1  isPermanentSeal  \
# 0                                   False          True            False
# 1                                   False          True            False
#
#    Pallet Note  Repack_Date_day  Last_Spqi_Date_day  Pack_Date_day  \
# 0        False              NaN                 NaN          -11.0
# 1        False              NaN                 NaN          -17.0
#
#    Doi_Clearance_Date_day  Tkl_Email_Date_day  Load_Start_Date_hour
# 0                     NaN                 NaN                 -37.0
# 1                     NaN                 NaN                 -40.0

# %% [markdown]
# ### Data Processing so that common columns have same set of data label
#     -change to string:Fruit Size Code_Trsc
#     -truncate 0 at first position:Purchase Pool Code_Trsc
#     -incorrect calculation as referring to dif,should remain in datetime: date columns(incl Ok_Until_Date_day,Pack_Date_day)

# %%
trans['Fruit Size Code']=trans['Fruit Size Code'].astype('str')
disp['Fruit Size Code']=disp['Fruit Size Code'].astype('str')

# %%
trans['Purchase Pool Code']=trans['Purchase Pool Code'].apply(lambda x:x.split('0')[1] if x[0]=='0' else x)
disp['Purchase Pool Code']=disp['Purchase Pool Code'].apply(lambda x:x.split('0')[1] if x[0]=='0' else x)

# %%
#drop_columns(disp,['Pack_Date_day', 'Ok_Until_Date_day'])
drop_columns(disp,['Pack_Date_day'])
# Out:
# Drop 1 columns :
# ['Pack_Date_day']

# %%
# to prevent OK Until Date with same date but dif time
trans['Ok Until Date']=pd.to_datetime(trans['Ok Until Date'],format='%Y-%m-%d %H:%M:%S')
disp['Ok Until Date']=pd.to_datetime(disp['Ok Until Date'],format='%Y-%m-%d %H:%M:%S')

# %%
trans['Ok Until Date']=trans['Ok Until Date'].dt.date
disp['Ok Until Date']=disp['Ok Until Date'].dt.date

# %%
## 12 Oct : comment out this bcs found out Packed Trays is 0 in disp
# disp.rename(index=str,columns={'Packed Trays':'Trays'},inplace=True)

# %%
trans['Transaction Date Time']=pd.to_datetime(trans['Transaction Date Time'],format='%Y-%m-%d %H:%M:%S')

# %% [markdown]
# ## 2) Preprocess transactional data

# %%
before_drop=trans.shape
temp_df=trans[trans['Location Mission Request Destination']==target_process]
print('Total number of rows deleted :{} ({:.2f} %)'.format(
    (before_drop[0]-temp_df.shape[0]),
    (before_drop[0]-temp_df.shape[0])/before_drop[0]*100))
print('Total number of rows remain : {} ({:.2f}%)'.format(
temp_df.shape[0],temp_df.shape[0]/before_drop[0]*100))
# Out:
# Total number of rows deleted :189147 (91.26 %)
# Total number of rows remain : 18112 (8.74%)

# %%
isAllocated_Process='is'+'Allocated_'+target_process
isAllocated_Process
# Out:
# 'isAllocated_FW'

# %%
temp_list=trans[trans['Location Mission Request Destination']==target_process]['Pallet Number'].unique()

# %%
trans[isAllocated_Process]=trans['Pallet Number'].apply(lambda x:True if x in temp_list else False)

# %%
trans.sample(3)
# Out:
#        Transaction Date Time Customer Label Code Dry Matter Code  Fruit  \
# 180109   2019-07-27 08:38:41                   N               Y   8640
# 102691   2019-07-16 00:59:09                   N               T  10440
# 28698    2019-07-05 09:29:09                   N               Y  12650
#
#         Fruit Per Pack Fruit Size Code Labelling Indicator Code  \
# 180109              48              30                       GR
# 102691              58              36                       UN
# 28698              115              39                       LG
#
#        Location Mission Request Destination Marketer Code Material Number  \
# 180109                                   na           ZIL           61582
# 102691                                   na           ZIL           65138
# 28698                                  SPQI           ZIL           62840
#
#          New Value Ok Until Date  Pack Code            Pack Date  \
# 180109  Q05-12-2-1    2019-08-11      10180  2019-04-18 00:00:00
# 102691  Q18-02-9-1    2019-06-16      72985  2019-05-05 00:00:00
# 28698          LAB    2019-07-07      41716  2019-05-23 00:00:00
#
#         Packed Fruit Packhouse Code Pack Label Code Pack Make Code  Packs  \
# 180109          7680           3TPP               T            KC6    180
# 102691         10440           3TPP               N            KC6    180
# 28698          12650           2FXP               N            KJ1    110
#
#         Pallet Number  Pallet Rework Count  Plant Code Previous Value  \
# 180109       57401404                    0        1103        UNKNOWN
# 102691       57430220                    0        1103     Q18-02-7-1
# 28698        59330016                    0        1103        UNKNOWN
#
#        Protocol Code Purchase Pool Code Quality Inspection Indicator Code  \
# 180109             N                 16                                 A
# 102691             N                 16                                 A
# 28698              N                  1                                 A
#
#        Storage Method Code     Transaction Date Transaction Sub Type Code  \
# 180109                  CN  2019-07-27 08:38:41                       MLA
# 102691                  CN  2019-07-16 00:59:09                       MLA
# 28698                   CN  2019-07-05 09:29:09                       MTA
#
#              Trays Username Variety Code  Ok_Until_Date_day  Pack_Date_day  \
# 180109  288.000000    tomin           GA               15.0         -101.0
# 102691  290.000000    teaio           GA              -31.0          -73.0
# 28698   324.358974   joslan           HW                1.0          -44.0
#
#         isDOINumber Pack Style Code Pack_Base Stacking Configuration Code  \
# 180109        False              ML         E                           2
# 102691        False              ML         H                           2
# 28698         False              MB         E                           1
#
#         isDayShift  Shift_Hour Day_of_week  isWeekend  isActualMovement  \
# 180109        True           8         Sat       True              True
# 102691       False           0         Mon      False              True
# 28698         True           9         Fri      False              True
#
#         isPackedFruitequalFruit Previous_RoomRow Previous_Column  \
# 180109                    False          UNKNOWN              na
# 102691                     True           Q18-02               7
# 28698                      True          UNKNOWN              na
#
#        Previous_Height distance_to_driveway  isAllocated_FW
# 180109              na                   na            True
# 102691               1                    6           False
# 28698               na                   na           False

# %%
target_process
# Out:
# 'FW'

# %%
isToFrm_Process='is'+'ToFrm_'+target_process
isToFrm_Process
# Out:
# 'isToFrm_FW'

# %%
trans[isToFrm_Process]=(trans['New Value']==target_process) | (trans['Previous Value']==target_process)

# %%
trans.sample(10)
# Out:
#        Transaction Date Time Customer Label Code Dry Matter Code  Fruit  \
# 194864   2019-07-29 12:16:27                   N               Y   7040
# 13837    2019-07-03 01:53:43                   N               Y   7150
# 123971   2019-07-18 15:29:34                   N               Y   5632
# 115112   2019-07-17 11:25:46                   V               Y   6660
# 153150   2019-07-23 09:16:37                   N               Y   6660
# 3102               N                  1                                 A
# 109521             N                 16                                 A
# 122356             N                  1                                 A
# 4854               N                 16                                 A
# 147951             N                  1                                 A
#
#        Storage Method Code     Transaction Date Transaction Sub Type Code  \
# 194864                  CN  2019-07-29 12:16:27                       MTA
# 13837                   CN  2019-07-03 01:53:43                       MTA
# 123971                  CN  2019-07-18 15:29:34                       MTA
# 115112                  CN  2019-07-17 11:25:46                       MTA
# 153150                  CN  2019-07-23 09:16:37                       MTA
# 3102                    CN  2019-07-01 10:19:01                       MLA
# 109521                  CN  2019-07-16 17:36:52                       MTA
# 122356                  CN  2019-07-18 12:14:47                       MLA
# 4854                    CN  2019-07-01 14:32:49                       MLA
# 147951                  CA  2019-07-22 12:12:49                       MTA
#
#              Trays Username Variety Code  Ok_Until_Date_day  Pack_Date_day  \
# 194864  260.740741   richpe           GA              -44.0          -87.0
# 13837   325.000000    kadwi           HW                3.0          -41.0
# 123971  256.000000    wadgi           HW               17.0          -56.0
# 115112  302.727273    bauko           GA               11.0          -74.0
# 153150  302.727273    joejo           GA              -38.0          -83.0
# 3102    324.358974    lucna           HW               19.0          -26.0
# 109521  256.000000    tjram           GA               19.0          -85.0
# 122356  325.000000    watro           HW               10.0          -54.0
# 4854    257.777778    artlc           GA              -16.0          -59.0
# 147951  324.358974    lucna           HW               19.0           -1.0
#
#         isDOINumber Pack Style Code Pack_Base Stacking Configuration Code  \
# 194864        False              ML         E                           N
# 13837         False              MB         E                           1
# 123971        False              IT         E                           3
# 115112        False              ML         E                           2
# 153150         True              ML         E                           2
# 3102          False              MB         E                           1
# 109521        False              IT         E                           3
# 122356        False              MB         E                           1
# 4854          False              ML         E                           N
# 147951        False              MB         E                           1
#
#         isDayShift  Shift_Hour Day_of_week  isWeekend  isActualMovement  \
# 194864        True          12         Mon      False              True
# 13837        False           1         Tue      False              True
# 123971        True          15         Thu      False              True
# 115112        True          11         Wed      False              True
# 153150        True           9         Tue      False              True
# 3102          True          10         Mon      False              True
# 109521        True          17         Tue      False              True
# 122356        True          12         Thu      False              True
# 4854          True          14         Mon      False              True
# 147951        True          12         Mon      False              True
#
#         isPackedFruitequalFruit Previous_RoomRow Previous_Column  \
# 194864                     True           Q29-10               1
# 13837                      True          UNKNOWN              na
# 123971                    False           Q08-14               1
# 115112                    False           Q06-07               5
# 153150                    False          UNKNOWN              na
# 3102                       True           Q15-05               8
# 109521                    False          UNKNOWN              na
# 122356                    False           Q03-14               5
# 4854                       True           Q29-19               8
# 147951                     True          UNKNOWN              na
#
#        Previous_Height distance_to_driveway  isAllocated_FW  isToFrm_FW
# 194864               2                   12           False       False
# 13837               na                   na           False       False
# 123971               1                   12           False       False
# 115112               1                    8            True       False
# 153150              na                   na           False       False
# 3102                 2                    5           False       False
# 109521              na                   na           False       False
# 122356               2                    8            True       False
# 4854                 1                    5           False       False
# 147951              na                   na           False       False

# %%
temp_list_2=trans[trans[isToFrm_Process]==True]['Pallet Number'].unique()

# %%
print('Quantity of Pallet Allocated for {} BUT dont have location information : {}'.format(
target_process,len([c for c in temp_list if c not in temp_list_2])))
# Out:
# Quantity of Pallet Allocated for FW BUT dont have location information : 522

# %%
print('Quantity of Pallet Allocated for {} AND have location information : {}'.format(
    target_process,len([c for c in temp_list if c in temp_list_2])))
# Out:
# Quantity of Pallet Allocated for FW AND have location information : 2910

# %% [markdown]
# ## Extract Transaction Data

# %%
before_drop=trans.shape
temp_df=trans[trans[isAllocated_Process]]
print('Total number of rows deleted :{} ({:.2f} %)'.format(
    (before_drop[0]-temp_df.shape[0]),
    (before_drop[0]-temp_df.shape[0])/before_drop[0]*100))
print('Total number of rows selected : {} ({:.2f} %)'.format(
temp_df.shape[0],temp_df.shape[0]/before_drop[0]*100))
# Out:
# Total number of rows deleted :139499 (67.31 %)
# Total number of rows selected : 67760 (32.69 %)

# %%
process_start_time=target_process+"_start_time"
process_end_time=target_process+"_end_time"
process=pd.DataFrame()

# %% [markdown]
# ### Extract Date_LstRqsDest_FW

# %%
temp_list=trans[trans['Location Mission Request Destination']==target_process].groupby('Pallet Number')['Transaction Date'].last()

# %%
temp_df=temp_list.to_frame().reset_index()

# %%
temp_df=temp_df.rename(index=str,columns={'Transaction Date':'Date_LstRqsDest_'+target_process})

# %% [markdown]
# ### Extract Date_FrstTo_FW

# %%
temp_df_2=trans[trans['New Value']==target_process].groupby('Pallet Number')['Transaction Date'].first()

# %%
temp_df_2=temp_df_2.to_frame().reset_index()

# %%
temp_df_2=temp_df_2.rename(index=str,columns={'Transaction Date':'Date_FrstTo_'+target_process})

# %%
process=pd.DataFrame()
process=temp_df.merge(temp_df_2,how='left',on='Pallet Number')

# %%
process['ActTo_'+target_process]=process['Date_LstRqsDest_'+target_process]==process['Date_FrstTo_'+target_process]

# %%
process['ActTo_'+target_process].value_counts()
# Out:
# True     2624
# False     808
# Name: ActTo_FW, dtype: int64

# %% [markdown]
# ### Extract Date_LstFrm_FW

# %%
temp_df=trans[trans['Previous Value']==target_process][['Pallet Number','Transaction Date']].groupby('Pallet Number').last()

# %%
temp_df=temp_df.reset_index()

# %%
temp_df=temp_df.rename(index=str,columns={'Transaction Date':'Date_LstFrm_'+target_process})

# %%
process=process.merge(temp_df,on='Pallet Number',how='left')

# %%
process.head()
# Out:
#    Pallet Number   Date_LstRqsDest_FW       Date_FrstTo_FW  ActTo_FW  \
# 0       53188057  2019-07-01 23:17:32                  NaN     False
# 1       53188552  2019-07-03 12:35:20                  NaN     False
# 2       53188613  2019-07-03 14:04:30                  NaN     False
# 3       53188620  2019-07-03 11:09:31                  NaN     False
# 4       53188675  2019-07-15 08:17:52  2019-07-08 09:10:18     False
#
#         Date_LstFrm_FW
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 
# 3332  2019-07-27 11:21:21
# 3334  2019-07-27 12:15:06
# 3335  2019-07-27 11:31:53
# 3336  2019-07-27 12:11:49
# 3338  2019-07-27 12:12:06
# 3341  2019-07-30 14:03:57
# 3342  2019-07-30 15:00:49
# 3343  2019-07-12 17:54:54
#
# [2624 rows x 5 columns]

# %%
process['Date_FrstTo_'+target_process]=pd.to_datetime(process['Date_FrstTo_'+target_process],format='%Y-%m-%d %H:%M:%S')

# %%
process['Date_LstFrm_'+target_process]=pd.to_datetime(process['Date_LstFrm_'+target_process],format='%Y-%m-%d %H:%M:%S')

# %%
process.dtypes
# Out:
# Pallet Number                  int64
# Date_LstRqsDest_FW            object
# Date_FrstTo_FW        datetime64[ns]
# ActTo_FW                        bool
# Date_LstFrm_FW        datetime64[ns]
# dtype: object

# %%
process['TimeDelta_FrsTLstF_'+target_process]=process['Date_LstFrm_'+target_process]-process['Date_FrstTo_'+target_process]

# %%
process['TimeDelta_FrsTLstF_Minute']=process['TimeDelta_FrsTLstF_'+target_process].astype('timedelta64[m]')

# %%
# quantity of process with duration is positive and less than 5 hours  
process[(process['TimeDelta_FrsTLstF_Minute']<300) & (process['TimeDelta_FrsTLstF_Minute']>0)]
# Out:
#       Pallet Number   Date_LstRqsDest_FW      Date_FrstTo_FW  ActTo_FW  \
# 6          53189481  2019-07-12 17:22:09 2019-07-12 17:22:09      True
# 7          53191170  2019-07-28 17:10:15 2019-07-01 16:22:21     False
# 8          53191729  2019-07-28 14:51:07 2019-07-28 14:51:07      True
# 9          53195161  2019-07-17 08:23:00 2019-07-17 08:23:00      True
# 14         53196946  2019-07-26 16:56:37 2019-07-26 16:56:37      True
# 16         53197455  2019-07-20 13:56:08 2019-07-20 13:56:08      True
# 18         53197479  2019-07-28 14:39:09 2019-07-28 14:39:09      True
# 19         53202081  2019-07-25 08:20:19 2019-07-25 08:20:19      True
# 20         53202166  2019-07-29 08:38:31 2019-07-29 08:38:31      True
# 22         56211875  2019-07-29 09:58:43 2019-07-29 09:58:43      True
# 23         56236342  2019-07-11 09:59:22 2019-07-11 09:59:22      True
# 24         56244651  2019-07-05 08:17:33 2019-07-05 08:17:33      True
# 25         56244699  2019-07-05 07:54:11 2019-07-05 07:54:11      True
# 26         56246471  2019-07-03 14:25:32 2019-07-03 14:25:32      True
# 27         56246594  2019-07-03 14:21:21 2019-07-03 14:21:21      True
# 28         56246624  2019-07-09 15:12:55 2019-07-09 15:12:55      True
# 29         56246662  2019-07-03 14:29:45 2019-07-03 14:29:45      True
# 30         56246693  2019-07-06 11:18:17 2019-07-06 11:18:17      True
# 31         56246808  2019-07-06 11:34:55 2019-07-06 11:34:55      True
# 32         56247065  2019-07-06 09:36:18 2019-07-06 09:36:18      True
# 34         56247188  2019-07-06 09:34:26 2019-07-06 09:34:26      True
# 35         56247201  2019-07-06 11:37:59 2019-07-06 11:37:59      True
# 36         56249311  2019-07-30 08:42:04 2019-07-30 08:42:04      True
# 38         56249434  2019-07-30 08:37:08 2019-07-30 08:37:08      True
# 3338 2019-07-27 12:12:06              00:38:55                       38.0
# 3339 2019-07-30 12:30:30              01:26:43                       86.0
# 3343 2019-07-12 17:54:54              00:45:09                       45.0
#
# [2531 rows x 7 columns]

# %% [markdown]
# ### Extract Multiple Process per Pallet

# %%
temp_df=trans[(trans['New Value']==target_process) | (trans['Previous Value']==target_process)]

# %%
temp_df['Transaction Date']=pd.to_datetime(temp_df['Transaction Date'],format='%Y-%m-%d %H:%M:%S')
# Out:
# C:\Users\Nan\AppData\Local\conda\conda\envs\env\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
temp_df['Transaction Date']=temp_df['Transaction Date'].dt.date
# Out:
# C:\Users\Nan\AppData\Local\conda\conda\envs\env\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# last transaction of the day from process 
temp_df_2=temp_df[(temp_df['New Value']==target_process)].groupby(['Pallet Number','Transaction Date'])['Transaction Date Time'].last()

# %%
temp_df_2=temp_df_2.to_frame().reset_index().rename(index=str,columns={'Transaction Date Time':'LstDailyTo_'+target_process})

# %%
temp_df_3=temp_df[(temp_df['Previous Value']==target_process)].groupby(['Pallet Number','Transaction Date'])['Transaction Date Time'].last()

# %%
temp_df_3=temp_df_3.to_frame().reset_index().rename(index=str,columns={'Transaction Date Time':'LstDailyFrm_'+target_process})

# %%
temp_df_3.head()
# Out:
#    Pallet Number Transaction Date      LstDailyFrm_FW
# 0       53188675       2019-07-08 2019-07-08 10:06:56
# 1       53188675       2019-07-10 2019-07-10 12:17:14
# 2       53188675       2019-07-15 2019-07-15 09:51:12
# 3       53189481       2019-07-12 2019-07-12 18:00:39
# 4       53191163       2019-07-26 2019-07-26 18:05:09

# %%
temp_df_2.head()
# Out:
#    Pallet Number Transaction Date       LstDailyTo_FW
# 0       53188675       2019-07-08 2019-07-08 09:10:18
# 1       53188675       2019-07-10 2019-07-10 11:15:04
# 2       53188675       2019-07-15 2019-07-15 08:17:52
# 3       53189481       2019-07-12 2019-07-12 17:22:09
# 4       53191163       2019-07-26 2019-07-26 17:15:52

# %%
temp_df_2=temp_df_2.merge(temp_df_3,on=['Pallet Number','Transaction Date'],how='inner')

# %%
temp_df_2['LstDailyTo_FW']=pd.to_datetime(temp_df_2['LstDailyTo_FW'],format='%Y-%m-%d %H:%M:%S')
temp_df_2['LstDailyFrm_FW']=pd.to_datetime(temp_df_2['LstDailyFrm_FW'],format='%Y-%m-%d %H:%M:%S')

# %%
temp_df_2['duration_'+target_process]=temp_df_2['LstDailyFrm_FW']-temp_df_2['LstDailyTo_FW']

# %%
temp_df_2['duration_FW']=temp_df_2['duration_FW'].astype('timedelta64[m]')

# %%
# cehck transaction with duration_FW < 0, these transaction will be omitted [3 transactions]
temp_df_2[temp_df_2['duration_FW']<0]
temp_df_2=temp_df_2.loc[temp_df_2['duration_FW']>0,:]

# %%
# check transaction with duration > 6 hours, seems to be valid [21 transactions]
len(temp_df_2[temp_df_2['duration_FW']>360])
# Out:
# 21

# %%
temp_df_2['duration_FW'].describe()
# Out:
# count    3428.000000
# mean       90.322345
# std        60.886527
# min         1.000000
# 25%        52.000000
# 50%        78.000000
# 75%       114.000000
# max       683.000000
# Name: duration_FW, dtype: float64

# %%
temp_df_2[temp_df_2['duration_FW']<10].head(3)
# Out:
#      Pallet Number Transaction Date       LstDailyTo_FW      LstDailyFrm_FW  \
# 93        56601508       2019-07-09 2019-07-09 15:03:39 2019-07-09 15:09:00
# 120       56603892       2019-07-09 2019-07-09 15:02:28 2019-07-09 15:10:47
# 146       56608934       2019-07-10 2019-07-10 16:40:37 2019-07-10 16:44:22
#
#      duration_FW
# 93           5.0
# 120          8.0
# 146          3.0

# %%
process_multiple=temp_df_2.copy()

# %%
temp_df[temp_df['Pallet Number']==53188675]
# Out:
#       Transaction Date Time Customer Label Code Dry Matter Code  Fruit  \
# 49378   2019-07-08 09:10:18                   N               Y   7656
# 49768   2019-07-08 10:06:56                   N               Y   4488
# 64148   2019-07-10 11:15:04                   N               Y   4488
# 64651   2019-07-10 12:17:14                   N               M   6600
# 97544   2019-07-15 08:17:52                   N               M   6600
# 98209   2019-07-15 09:51:12                   N               M   8448
#
#        Fruit Per Pack Fruit Size Code Labelling Indicator Code  \
# 49378              33              33                       GR
# 49768              33              33                       GR
# 64148              33              33                       GR
# 64651              33              33                       GR
# 97544              33              33                       GR
# 98209              33              33                       GR
#
#       Location Mission Request Destination Marketer Code Material Number  \
# 49378                                   FW           ZIL           61555
# 49768                                   na           ZIL           61555
# 64148                                   FW           ZIL           61555
# 64651                                   na           ZIL           61555
# 97544                                   FW           ZIL           61555
# 98209                                   na           ZIL           61556
#
#       New Value Ok Until Date  Pack Code            Pack Date  Packed Fruit  \
# 49378        FW    2019-07-21      10192  2019-05-22 00:00:00             0
# 49768   UNKNOWN    2019-07-21      10192  2019-05-22 00:00:00             0
# 64148        FW    2019-07-21      10192  2019-05-22 00:00:00             0
# 64651   UNKNOWN    2019-07-21      10192  2019-05-22 00:00:00             0
# 97544        FW    2019-07-28      10192  2019-05-22 00:00:00             0
# 98209   UNKNOWN    2019-07-28      10192  2019-05-22 00:00:00             0
#
#       Packhouse Code Pack Label Code Pack Make Code  Packs  Pallet Number  \
# 49378           3TPP               N            KC1    232       53188675
# 49768           3TPP               N            KC1    136       53188675
# 64148           3TPP               N            KC1    136       53188675
# 64651           3TPP               N            KC1    200       53188675
# 97544           3TPP               N            KC1    200       53188675
# 98209           3TPP               N            KC1    256       53188675
#
#        Pallet Rework Count  Plant Code Previous Value Protocol Code  \
# 49378                    0        1103        UNKNOWN             N
# 49768                    0        1103             FW             N
# 64148                    0        1103        UNKNOWN             N
# 64651                    0        1103             FW             N
# 97544                    0        1103        UNKNOWN             N
# 98209                    0        1103             FW             N
#
#       Purchase Pool Code Quality Inspection Indicator Code  \
# 49378                  1                                 A
# 49768                  1                                 A
# 64148                  1                                 A
# 64651                  1                                 A
# 97544                  1                                 A
# 98209                  1                                 A
#
#       Storage Method Code Transaction Date Transaction Sub Type Code  Trays  \
# 49378                  CN       2019-07-08                       MTA  232.0
# 49768                  CN       2019-07-08                       MLA  136.0
# 64148                  CN       2019-07-10                       MTA  136.0
# 64651                  CN       2019-07-10                       MLA  200.0
# 97544                  CN       2019-07-15                       MTA  200.0
# 98209                  CN       2019-07-15                       MLA  256.0
#
#       Username Variety Code  Ok_Until_Date_day  Pack_Date_day  isDOINumber  \
# 49378    lucna           HW               13.0          -48.0        False
# 49768    tjram           HW               13.0          -48.0        False
# 64148    canll           HW               11.0          -50.0        False
# 64651    tjram           HW               10.0          -50.0        False
# 97544    anpet           HW               13.0          -55.0        False
# 98209    navsi           HW               13.0          -55.0        False
#
#       Pack Style Code Pack_Base Stacking Configuration Code  isDayShift  \
# 49378              IT         E                           N        True
# 49768              IT         E                           N        True
# 64148              IT         E                           N        True
# 64651              IT         E                           N        True
# 97544              IT         E                           N        True
# 98209              IT         E                           3        True
#
#        Shift_Hour Day_of_week  isWeekend  isActualMovement  \
# 49378           9         Mon      False              True
# 49768          10         Mon      False              True
# 64148          11         Wed      False              True
# 64651          12         Wed      False              True
# 97544           8         Mon      False              True
# 98209           9         Mon      False              True
#
#        isPackedFruitequalFruit Previous_RoomRow Previous_Column  \
# 49378                    False          UNKNOWN              na
# 49768                    False               FW              na
# 64148                    False          UNKNOWN              na
# 64651                    False               FW              na
# 97544                    False          UNKNOWN              na
# 98209                    False               FW              na
#
#       Previous_Height distance_to_driveway  isAllocated_FW  isToFrm_FW
# 49378              na                   na            True        True
# 49768              na                   na            True        True
# 64148              na                   na            True        True
# 64651              na                   na            True        True
# 97544              na                   na            True        True
# 98209              na                   na            True        True

# %%
process_multiple[process_multiple['Pallet Number']==53188675]
# Out:
#    Pallet Number Transaction Date       LstDailyTo_FW      LstDailyFrm_FW  \
# 0       53188675       2019-07-08 2019-07-08 09:10:18 2019-07-08 10:06:56
# 1       53188675       2019-07-10 2019-07-10 11:15:04 2019-07-10 12:17:14
# 2       53188675       2019-07-15 2019-07-15 08:17:52 2019-07-15 09:51:12
#
#    duration_FW
# 0         56.0
# 1         62.0
# 2         93.0

# %% [markdown]
# ### Find out packaging changes

# %%
trans.columns
# Out:
# Index(['Transaction Date Time', 'Customer Label Code', 'Dry Matter Code',
#        'Fruit', 'Fruit Per Pack', 'Fruit Size Code',
#        'Labelling Indicator Code', 'Location Mission Request Destination',
#        'Marketer Code', 'Material Number', 'New Value', 'Ok Until Date',
#        'Pack Code', 'Pack Date', 'Packed Fruit', 'Packhouse Code',
#        'Pack Label Code', 'Pack Make Code', 'Packs', 'Pallet Number',
#        'Pallet Rework Count', 'Plant Code', 'Previous Value', 'Protocol Code',
#        'Purchase Pool Code', 'Quality Inspection Indicator Code',
#        'Storage Method Code', 'Transaction Date', 'Transaction Sub Type Code',
#        'Trays', 'Username', 'Variety Code', 'Ok_Until_Date_day',
#        'Pack_Date_day', 'isDOINumber', 'Pack Style Code', 'Pack_Base',
#        'Stacking Configuration Code', 'isDayShift', 'Shift_Hour',
#        'Day_of_week', 'isWeekend', 'isActualMovement',
#        'isPackedFruitequalFruit', 'Previous_RoomRow', 'Previous_Column',
#        'Previous_Height', 'distance_to_driveway', 'isAllocated_FW',
#        'isToFrm_FW'],
#       dtype='object')

# %%
list_package=['Pack Style Code', 'Pack_Base', 'Stacking Configuration Code','Customer Label Code','Variety Code','Pack Label Code','Pack Make Code','Labelling Indicator Code','Material Number']
list_package=list_package+['Packed Fruit','Fruit','Packs','Trays','Fruit Per Pack']
# following column will further reduce transaction with no change by 3 ONLY
#list_package=list_package+['Dry Matter Code','Fruit Size Code','Marketer Code','Ok Until Date','Pallet Rework Count','Quality Inspection Indicator Code']

# %%
temp_df_3=trans[['Pallet Number','Transaction Date Time']+list_package]
process_multiple=process_multiple.merge(temp_df_3,
                      left_on=['Pallet Number','LstDailyTo_FW'],
                     right_on=['Pallet Number','Transaction Date Time'],
                      how='left')

# %%
process_multiple=process_multiple.merge(temp_df_3,
                      left_on=['Pallet Number','LstDailyFrm_FW'],
                     right_on=['Pallet Number','Transaction Date Time'],
                      how='left',
                    suffixes=('_To', '_Frm'))

# %%
left_col=[c for c in process_multiple if '_To' in c ]
right_col=[c for c in process_multiple if '_Frm' in c ]
generate_dif_columns(process_multiple,left_col,'_To','_Frm')
# Out:
# There are 15 common columns :
# ['Transaction Date Time', 'Pack Style Code', 'Pack_Base', 'Stacking Configuration Code', 'Customer Label Code', 'Variety Code', 'Pack Label Code', 'Pack Make Code', 'Labelling Indicator Code', 'Material Number', 'Packed Fruit', 'Fruit', 'Packs', 'Trays', 'Fruit Per Pack']
#
# Columns Generated : 15

# %%
print('Row with same transaction time : {} rows'.format(
    len(process_multiple[process_multiple['dif_TransactionDateTime']!=True])))
# Out:
# Row with same transaction time : 0 rows

# %%
x=len(process_multiple[process_multiple['dif_TransactionDateTime']!=True])
if x > 0:
    print('Warning : {} rows with same transaction time'.format(
        len(process_multiple[process_multiple['dif_TransactionDateTime']!=True])))
else:
    drop_columns(process_multiple,['Transaction Date Time_To','Transaction Date Time_Frm'])
# Out:
# Drop 2 columns :
# ['Transaction Date Time_To', 'Transaction Date Time_Frm']

# %%
drop_unilable_column(process_multiple)
# Out:
# Drop 5 Columns with Single Label:
# ['dif_TransactionDateTime', 'dif_PackStyleCode', 'dif_VarietyCode', 'dif_PackedFruit', 'dif_FruitPerPack']

# %%
temp_list=[c for c in process_multiple.columns if 'dif_' in c]
process_multiple['PackageChange']=np.sum(process_multiple[temp_list],axis='columns')
process_multiple['isPackageChange']=process_multiple['PackageChange']>0

# %%
# remove column contain '_To' as no needed
temp_list=[c for c in process_multiple.columns if '_To' in c]
drop_columns(process_multiple,temp_list)
# Out:
# Drop 14 columns :
# ['Pack Style Code_To', 'Pack_Base_To', 'Stacking Configuration Code_To', 'Customer Label Code_To', 'Variety Code_To', 'Pack Label Code_To', 'Pack Make Code_To', 'Labelling Indicator Code_To', 'Material Number_To', 'Packed Fruit_To', 'Fruit_To', 'Packs_To', 'Trays_To', 'Fruit Per Pack_To']

# %%
# change columns name to prepare df for merging with dispatch dataset
temp_list=[c for c in process_multiple.columns if '_Frm' in c]
for idx,x in enumerate(temp_list):
# 197          38.0              P1         E                           N
# 217         175.0              ML         E                           2
# 225         519.0              ML         E                           2
# 226         132.0              ML         E                           2
# 232          75.0              P1         E                           N
# 256          23.0              ML         E                           N
# 259           1.0              ML         E                           N
# 280          18.0              IJ         E                           3
# 306          14.0              P1         E                           N
# 309          23.0              ML         E                           2
# 310           1.0              IT         E                           3
# ...           ...             ...       ...                         ...
# 3287        115.0              MB         E                           N
# 3293         74.0              MB         E                           N
# 3324         62.0              IT         E                           3
# 3346         17.0              MB         E                           1
# 3347         10.0              MB         E                           1
# 3359         67.0              MB         E                           N
# 3382         28.0              MB         E                           N
# 3389         40.0              MB         E                           N
# 3390         38.0              MB         E                           N
# 3393        241.0              MB         E                           1
# 3395        300.0              MB         E                           1
# 3398         59.0              MB         E                           N
# 3400         76.0              MB         E                           N
# 3403         64.0              MB         E                           1
# 3404         91.0              MB         E                           N
# 3405          1.0              MB         E                           1
# 3409          4.0              MB         E                           N
# 3410          3.0              MB         E                           N
# 3411          6.0              MB         E                           N
# 3412         27.0              MB         E                           N
# 3413          8.0              MB         E                           N
# 3414          6.0              MB         E                           N
# 3415         15.0              MB         E                           N
# 3416          8.0              MB         E                           N
# 3418         12.0              MB         E                           N
# 3420          4.0              MB         H                           N
# 3421         15.0              MB         E                           N
# 3423         83.0              MB         E                           N
# 3424         86.0              MB         E                           N
# 3426          1.0              MB         E                           N
#
#      Customer Label Code Variety Code Pack Label Code Pack Make Code  \
# 7                      N           HW               N            KC1
# 9                      Z           GA               T            KC6
# 21                     N           GA               N            KC6
# 31                     N           GA               N            VT6
# 32                     N           GA               T            VTY
# 45                     N           GA               N            VTY
# 53                     N           GA               N            KC3
# 66                     N           GA               N            VT6
# 71                     N           GA               N            VP6
# 84                     N           HW               N            KC4
# 87                     N           GA               N            KC6
# 91                     N           GA               N            KC6
# 103                    N           GA               N            KC6
# 118                    N           GA               N            KC6
# 144                    V           GA               N            KC3
# 157                    N           GA               N            KC6
# 163                    N           GA               N            KC3
# 187                    N           GA               T            KC6
# 192                    N           GA               N            KC6
# 197                    N           GA               N            KC6
# 217                    N           GA               N            KC6
# 225                    N           GA               N            KC6
# 226                    N           GA               N            KC6
# 232                    N           GA               T            KC6
# 256                    N           GA               N            KC6
# 259                    Z           GA               N            KC6
# 280                    N           GA               N            KC3
# 306                    N           GA               N            KC6
# 309                    N           GA               N            KC6
# 310                    N           GA               N            KC6
# ...                  ...          ...             ...            ...
# 3287                   Z           HW               T            KJ1
# 3293                   Z           HW               T            KJ1
# 3324                   N           HW               N            KC1
# 3346                   N           HW               N            KJ1
# 3347                   N           HW               T            KJ1
# 3359                   Z           HW               T            KJ1
# 3382                   N           HW               N            KJ1
# 3389                   Z           HW               T            KJ1
# 3390                   Z           HW               T            KJ1
# 3393                   I           HW               T            KJ1
# 3395                   I           HW               T            KJ1
# 3398                   N           HW               T            KJ1
# 3400                   N           HW               N            KJ1
# 3403                   I           HW               T            KJ1
# 3404                   N           HW               N            KJ1
# 3405                   N           HW               N            KJ1
# 3409                   N           HW               N            KJ1
# 3410                   N           HW               N            KJ1
# 3411                   N           HW               N            KJ1
# 3412                   N           HW               N            KJ1
# 3413                   N           HW               N            KJ1
# 3414                   N           HW               N            KJ1
# 3415                   N           HW               N            KJ1
# 3416                   N           HW               N            KJ1
# 3418                   N           HW               N            KJ1
# 3420                   N           HW               N            KJ1
# 3421                   N           HW               N            KJ1
# 3423                   N           HW               N            NKF
# 3424                   N           HW               N            NKF
# 3426                   N           HW               N            NKF
#
#      Labelling Indicator Code Material Number  Packed Fruit  Fruit  Packs  \
# 7                          GR           61588             0   3024     42
# 9                          JB           61575             0   3293     89
# 21                         GR           61578          6560   7380    180
# 31                         GR           61341          5800   2600    104
# 32                         JB           61600          4400   4400    200
# 45                         JB           61600          4400   4400    200
# 53                         JB           61600          4400   4400    200
# 66                         GR           61347          5800   6400    256
# 71                         GR           61577          6560   6560    160
# 84                         LG           62765          9216  11220    110
# 87                         GR           61349          6960   7680    256
# 91                         LG           62622          9280  10440    180
# 103                        LG           62625          9280   9280    160
# 118                        LG           62622          9280  10440    180
# 144                        JB           61602          4400   4928    224
# 157                        GR           61580          7040   7920    180
# 163                        JB           61602          4400   4928    224
# 187                        JB           61575          5920   5920    160
# 192                        LD           63075          6960   6960    145
# 197                        LD           65657          8700   8700    145
# 217                        GR           61580          7040   7920    180
# 225                        GR           61582          6960   4272     89
# 226                        GR           61582          6960   4272     89
# 232                        LD           62984          7540   7540    145
# 256                        GR           61579          7040   7040    160
# 259                        GR           61583          8320   8320    160
# 280                        JB           61602          4400   4928    224
# 306                        LD           62984          7540   7540    145
# 309                        GR           61584          8320   9360    180
# 310                        GR           61348          6264   6912    256
# ...                       ...             ...           ...    ...    ...
# 3287                       GR           61595          9200   9200    100
# 3293                       LG           62846         11500  11500    100
# 3324                       JB           55775          5632   5632    256
# 3346                       LG           62839         11220  11220    110
# 3347                       GR           61594         10120  10120    110
# 3359                       JB           61587          6500   6500    100
# 3382                       LG           62853         13000  13000    100
# 3389                       JB           61587          6500   6500    100
# 3390                       JB           61587          6500   6500    100
# 3393                       GR           61594         10120  10120    110
# 3395                       GR           61594         10120  10120    110
# 3398                       GR           61591          7800   7800    100
# 3400                       GR           61593          8500   8500    100
# 3403                       GR           61594         10120  10120    110
# 3404                       LG           62845         10200  10200    100
# 3405                       GR           61588          9000   7920    110
# 3409                       GR           61593          8500   8500    100
# 3410                       GR           61595          9200   9200    100
# 3411                       GR           61593          8500   8500    100
# 3412                       GR           61595          9200   9200    100
# 3413                       GR           61593          8500   8500    100
# 3414                       GR           61589          7200   7200    100
# 3415                       GR           61593          8500   8500    100
# 3416                       GR           61593          8500   8500    100
# 3418                       GR           61595          9200   9200    100
# 3420                       GR           62847          8500   8500    100
# 3421                       GR           61595          9200   9200    100
# 3423                       NK           08001          7800   7800    100
# 3424                       NK           08001          7800   7800    100
# 3426                       NK           08007          4030   4030     31
#
#            Trays  Fruit Per Pack  FW_dif_Pack_Base  \
# 7     120.960000              72             False
# 53           False         False              0            False
# 66           False         False              0            False
# 71           False         False              0            False
# 84           False         False              0            False
# 87           False         False              0            False
# 91           False         False              0            False
# 103          False         False              0            False
# 118          False         False              0            False
# 144          False         False              0            False
# 157          False         False              0            False
# 163          False         False              0            False
# 187          False         False              0            False
# 192          False         False              0            False
# 197          False         False              0            False
# 217          False         False              0            False
# 225          False         False              0            False
# 226          False         False              0            False
# 232          False         False              0            False
# 256          False         False              0            False
# 259          False         False              0            False
# 280          False         False              0            False
# 306          False         False              0            False
# 309          False         False              0            False
# 310          False         False              0            False
# ...            ...           ...            ...              ...
# 3287         False         False              0            False
# 3293         False         False              0            False
# 3324         False         False              0            False
# 3346         False         False              0            False
# 3347         False         False              0            False
# 3359         False         False              0            False
# 3382         False         False              0            False
# 3389         False         False              0            False
# 3390         False         False              0            False
# 3393         False         False              0            False
# 3395         False         False              0            False
# 3398         False         False              0            False
# 3400         False         False              0            False
# 3403         False         False              0            False
# 3404         False         False              0            False
# 3405         False         False              0            False
# 3409         False         False              0            False
# 3410         False         False              0            False
# 3411         False         False              0            False
# 3412         False         False              0            False
# 3413         False         False              0            False
# 3414         False         False              0            False
# 3415         False         False              0            False
# 3416         False         False              0            False
# 3418         False         False              0            False
# 3420         False         False              0            False
# 3421         False         False              0            False
# 3423         False         False              0            False
# 3424         False         False              0            False
# 3426         False         False              0            False
#
# [453 rows x 31 columns]

# %% [markdown]
# # Merge

# %%
disp.sample(3)
# Out:
#        Pallet Number Location Room Code Location Row Code Location Column  \
# 6001        55354504                LO2                na              na
# 2394        55004645            UNKNOWN                na              na
# 31203       59754317            UNKNOWN                na              na
#
#       Location Height Location Request Number Storage Source Code  \
# 6001              1.0                      na                  CN
# 2394              0.0                      na                  CN
# 31203             0.0                      na                  CA
#
#       Pack Label Code Pack Indicator Code Clearance Protocol Code  \
# 6001                N                   N                       N
# 2394                N                   N                       N
# 31203               N                   N                       N
#
#       Customer Label Code Dry Matter Code Storing Characteristic Code  \
# 6001                    N               M                           K
# 2394                    Z               M                           G
# 31203                   N               Y                           N
#
#       CCKPassed Failed Quality Inspection Indicator Code Japan Sub Brand Code  \
# 6001                na                                 A                    N
# 2394                na                                 A                    N
# 31203               na                                 A                    N
#
#       Trial Packing Indicator Code Marketer Code  Loadout Priority  \
# 6001                             N           ZIL                20
# 2394                             N           ZIL                 1
# 31203                            N           ZIL                50
#
#       Material Number Material Group Code Brand Code Variety Code  \
# 6001            61555              Zespri          Z           HW
# 2394            61581              Zespri          Z           GA
# 31203           61590              Zespri          Z           HW
#
#        Fruit Class Code Fruit Size Code Pack Category Code  \
# 6001                  1              33               ENIT
# 2394                  1              30               ENML
# 31203                 1              27               E1MB
#
#       Labelling Indicator Code Purchase Pool Code  Pack Code Growing Method  \
# 6001                        GR                  1      10192             CK
# 2394                        GR                 16      10180             CK
# 31203                       GR                  1      10175             CK
#
#        Packs Per Pallet Maturity Indicator Code Ok Until Date  Plant Code  \
# 6001                232                       N    2019-05-19        1103
# 2394                160                       N    2019-05-05        1103
# 31203               110                       N    2019-08-04        1103
#
#        Ignore Psr Pack Type Code  Packed Fruit  Packed Trays Packhouse Code  \
# 6001        False        ENITKC1          7656    232.000000           3TPP
# 2394        False        ENMLKC6          7680    256.000000           3TPP
# 31203       False        E1MBKJ1          8580    317.777778           3TPP
#
#       Pallet Card Reference  Fruit  Order Number  Order Line Number  \
# 6001                2144DAY   7656       5145801                 60
# 2394                     na   7680       5150001                 60
# 31203               3297DAY   8580       5337701                160
#
#               Loadout Date  Shipment Type Code Destination Port Code  \
# 6001   2019-04-07 15:15:00                   1                 CNSHG
# 2394   2019-04-03 07:30:00                   1                 KRPUS
# 31203  2019-07-26 12:30:00                  18                 BEZEE
#
#       Trucking Company Code  Packs  Full Market Holds  \
# 6001                   FOTH    232  True           na
# 2394                   K&ST    160  True           na
# 31203                  MONK    110  True   IL, TH, US
#
#       Stacking Configuration Code Pack Style Code Pack Make Code  \
# 6001                            N              IT            KC1
# 2394                            N              ML            KC6
# 31203                           1              MB            KJ1
#
#            Load Start Date  Envelope Number Container Container Number  \
# 6001   2019-04-08 00:00:00           193186        na               na
# 2394   2019-04-01 00:00:00           193100        na               na
# 31203  2019-07-24 00:00:00           199152    8486.0      BMOU9624648
#
#        isDoi_Number  isInternal_Holds  isTemporary_Seal_Number  \
# 6001          False             False                    False
# 2394          False             False                    False
# 31203         False             False                     True
#
#        isTemperature_Recorder_Number  isLocation_Mission_Request_Destination  \
# 6001                           False                                   False
# 2394                           False                                   False
# 31203                           True                                   False
#
#        isRf_Id_Tag1  isPermanentSeal  Pallet Note  Repack_Date_day  \
# 6001           True            False        False              NaN
# 2394           True            False        False              NaN
# 31203          True            False        False              NaN
#
#        Last_Spqi_Date_day  Doi_Clearance_Date_day  Tkl_Email_Date_day  \
# 6001                  NaN                     NaN                 NaN
# 2394                  NaN                     NaN                 NaN
# 31203                 NaN                     NaN                -4.0
#
#        Load_Start_Date_hour
# 6001                    8.0
# 2394                  -56.0
# 31203                 -61.0

# %%
process_multiple.sample(3)
# Out:
#       Pallet Number Transaction Date       LstDailyTo_FW      LstDailyFrm_FW  \
# 557        57129681       2019-07-10 2019-07-10 16:41:42 2019-07-10 17:24:29
# 3106       59728646       2019-07-15 2019-07-15 08:35:24 2019-07-15 09:15:05
# 200        56991623       2019-07-10 2019-07-10 14:35:36 2019-07-10 16:51:56
#
#       duration_FW Pack Style Code Pack_Base Stacking Configuration Code  \
# 557          42.0              IT         E                           3
# 3106         39.0              IT         E                           3
# 200         136.0              IJ         E                           3
#
#      Customer Label Code Variety Code Pack Label Code Pack Make Code  \
# 557                    N           GA               N            KC6
# 3106                   N           HW               N            KC1
# 200                    V           GA               N            KC3
#
#      Labelling Indicator Code Material Number  Packed Fruit  Fruit  Packs  \
# 557                        GR           61349          6960   7680    256
# 3106                       GR           61556          7656   8448    256
# 200                        JB           61602          4400   4928    224
#
#       Trays  Fruit Per Pack  FW_dif_Pack_Base  \
# 557   256.0              30             False
# 3106  256.0              33             False
# 200   224.0              22             False
#
#       FW_dif_StackingConfigurationCode  FW_dif_CustomerLabelCode  \
# 557                               True                     False
# 3106                              True                     False
# 200                               True                      True
#
#       FW_dif_PackLabelCode  FW_dif_PackMakeCode  \
# 557                  False                False
# 3106                 False                False
# 200                  False                False
#
#       FW_dif_LabellingIndicatorCode  FW_dif_MaterialNumber  FW_dif_Fruit  \
# 557                           False                   True          True
# 3106                          False                   True          True
# 200                           False                   True          True
#
#       FW_dif_Packs  FW_dif_Trays  PackageChange  isPackageChange
# 557           True          True              5             True
# 3106          True          True              5             True
# 200           True          True              6             True

# %%
# append dispatch information to process_multiple
process_multiple=process_multiple.merge(disp,how='left',on='Pallet Number',suffixes=(sffx_transaction, sffx_dispatched))

# %%
left_col=[c for c in process_multiple if sffx_transaction in c ]
generate_dif_columns(process_multiple,left_col,sffx_transaction,sffx_dispatched)
# Out:
# There are 11 common columns :
# ['Pack Style Code', 'Stacking Configuration Code', 'Customer Label Code', 'Variety Code', 'Pack Label Code', 'Pack Make Code', 'Labelling Indicator Code', 'Material Number', 'Packed Fruit', 'Fruit', 'Packs']
#
# Columns Generated : 11

# %%
drop_unilable_column(process_multiple)
# Out:
# Drop 6 Columns with Single Label:
# ['Pack Indicator Code', 'Storing Characteristic Code', 'Maturity Indicator Code', 'isRf_Id_Tag1', 'dif_PackStyleCode', 'dif_VarietyCode']

# %% [markdown]
# ### Check Pallet with Order Number

# %%
# 14 % of row with pallet that has yet allocated to an order number
summary_numerical(process_multiple)
# Out:
# SUMMARY OF 26 NUMERICAL ATTRIBUTES:
#                  Attribute   Count  Missing (%)          Mean      Median  \
# 1   Doi_Clearance_Date_day    17.0    99.504084 -2.223529e+01       -19.0
# 2          Repack_Date_day    88.0    97.432905 -6.920455e+00        -5.0
# 3       Last_Spqi_Date_day  1908.0    44.340723 -1.007914e+01       -10.0
# 4       Tkl_Email_Date_day  2633.0    23.191365 -3.333080e+00        -3.0
# 5         Loadout Priority  2947.0    14.031505  7.601968e+00         6.0
# 6         Fruit Class Code  2947.0    14.031505  1.001357e+00         1.0
# 7                Pack Code  2947.0    14.031505  1.814680e+04     10308.0
# 8         Packs Per Pallet  2947.0    14.031505  1.973688e+02       180.0
# 9               Plant Code  2947.0    14.031505  1.100414e+03      1103.0
# 10      Packed Fruit_Dptch  2947.0    14.031505  7.388275e+03      7040.0
# 11            Packed Trays  2947.0    14.031505  2.458546e+02       232.0
# 12             Fruit_Dptch  2947.0    14.031505  8.031105e+03      7680.0
# 13            Order Number  2947.0    14.031505  5.288118e+06   5311401.0
# 14       Order Line Number  2947.0    14.031505  5.021819e+01        30.0
# 15      Shipment Type Code  2947.0    14.031505  1.379267e+01        18.0
# 16             Packs_Dptch  2947.0    14.031505  1.973417e+02       180.0
# 17         Envelope Number  2947.0    14.031505  1.988541e+05    199132.0
# 18    Load_Start_Date_hour  2947.0    14.031505 -2.498269e+01       -19.0
# 19           Pallet Number  3428.0     0.000000  5.809392e+07  57416765.5
# 20             duration_FW  3428.0     0.000000  9.032235e+01        78.0
# 21          Fruit Per Pack  3428.0     0.000000  4.583460e+01        37.0
# 22       Packed Fruit_Trsc  3428.0     0.000000  7.357670e+03      7040.0
# 23              Fruit_Trsc  3428.0     0.000000  7.594321e+03      7680.0
# 24              Packs_Trsc  3428.0     0.000000  1.871590e+02       180.0
# 25           PackageChange  3428.0     0.000000  3.629230e+00         5.0
# 26                   Trays  3428.0     0.000000  2.523616e+02       256.0
#
#            Min           Max  Skewness    Kurtosis
# 1        -42.0 -5.000000e+00       NaN         NaN
# 2        -38.0 -1.000000e+00       NaN         NaN
# 3        -66.0 -1.000000e+00       NaN         NaN
# 4         -9.0 -1.000000e+00       NaN         NaN
# 5          1.0  5.000000e+01       NaN         NaN
# 6          1.0  2.000000e+00       NaN         NaN
# 7        369.0  7.633200e+04       NaN         NaN
# 8        100.0  2.560000e+02       NaN         NaN
# 9       1000.0  1.103000e+03       NaN         NaN
# 10         0.0  1.430000e+04       NaN         NaN
# 11         0.0  4.210000e+02       NaN         NaN
# 12      3840.0  1.430000e+04       NaN         NaN
# 13     89878.0  5.352101e+06       NaN         NaN
# 14        10.0  2.800000e+02       NaN         NaN
# 15         1.0  1.800000e+01       NaN         NaN
# 16        80.0  2.560000e+02       NaN         NaN
# 17    193002.0  1.993310e+05       NaN         NaN
# 18       -84.0  8.700000e+01       NaN         NaN
# 19  53188675.0  9.001261e+07  6.405558  109.156900
# 20         1.0  6.830000e+02  2.373190   11.379707
# 21        18.0  1.300000e+02  1.415066    1.808545
# 22         0.0  1.430000e+04  0.152023    1.838238
# 23        44.0  1.430000e+04 -0.313839    1.158964
# 24         2.0  2.560000e+02 -0.513831   -0.589917
# 25         0.0  7.000000e+00 -0.708563   -1.049641
# 26         2.0  3.404762e+02 -2.274421    6.686287

# %%
summary_object(process_multiple)
# Out:
# SUMMARY OF 77 NON-NUMERICAL ATTRIBUTES:
#
# 57 Object Columns
# 20 Bool Columns
#                             Attribute Count Unique Missing (%)  \
# 1               Pallet Card Reference  2947    283     14.0315
# 2                        Loadout Date  2947    275     14.0315
# 3                           Container  2947    248     14.0315
# 4                    Container Number  2947    248     14.0315
# 5                        Market Holds  2947    158     14.0315
# 6               Material Number_Dptch  2947    112     14.0315
# 7               Destination Port Code  2947     43     14.0315
# 8                      Pack Type Code  2947     38     14.0315
# 9                     Load Start Date  2947     28     14.0315
# 10            Location Request Number  2947     23     14.0315
# 11                  Location Row Code  2947     22     14.0315
# 12              Trucking Company Code  2947     22     14.0315
# 13                 Pack Category Code  2947     19     14.0315
# 14                    Location Column  2947     14     14.0315
# 15               Pack Make Code_Dptch  2947     14     14.0315
# 16                 Location Room Code  2947     13     14.0315
# 17                    Fruit Size Code  2947     10     14.0315
# 18                      Ok Until Date  2947     10     14.0315
# 19     Labelling Indicator Code_Dptch  2947      9     14.0315
# 20              Pack Style Code_Dptch  2947      9     14.0315
# 21          Customer Label Code_Dptch  2947      8     14.0315
# 22                      Marketer Code  2947      8     14.0315
# 23                         Brand Code  2947      8     14.0315
# 24                 Purchase Pool Code  2947      8     14.0315
# 25            Clearance Protocol Code  2947      6     14.0315
# 26                     Packhouse Code  2947      6     14.0315
# 27  Stacking Configuration Code_Dptch  2947      6     14.0315
# 28                    Location Height  2947      5     14.0315
# 29                    Dry Matter Code  2947      5     14.0315
# 30                Storage Source Code  2947      4     14.0315
# ..                                ...   ...    ...         ...
# 48               Material Number_Trsc  3428    120           0
# 49                   Transaction Date  3428     30           0
# 50                Pack Make Code_Trsc  3428     14           0
# 51               Pack Style Code_Trsc  3428      8           0
# 52      Labelling Indicator Code_Trsc  3428      8           0
# 53           Customer Label Code_Trsc  3428      7           0
# 54   Stacking Configuration Code_Trsc  3428      5           0
# 55                          Pack_Base  3428      3           0
# 56                  Variety Code_Trsc  3428      3           0
# 57               Pack Label Code_Trsc  3428      2           0
# 58                   FW_dif_Pack_Base  3428      2           0
# 59   FW_dif_StackingConfigurationCode  3428      2           0
# 60           FW_dif_CustomerLabelCode  3428      2           0
# 61               FW_dif_PackLabelCode  3428      2           0
# 62                FW_dif_PackMakeCode  3428      2           0
# 63      FW_dif_LabellingIndicatorCode  3428      2           0
# 64              FW_dif_MaterialNumber  3428      2           0
# 65                       FW_dif_Fruit  3428      2           0
# 66                       FW_dif_Packs  3428      2           0
# 67                       FW_dif_Trays  3428      2           0
# 68                    isPackageChange  3428      2           0
# 69      dif_StackingConfigurationCode  3428      2           0
# 70              dif_CustomerLabelCode  3428      2           0
# 71                  dif_PackLabelCode  3428      2           0
# 72                   dif_PackMakeCode  3428      2           0
# 73         dif_LabellingIndicatorCode  3428      2           0
# 74                 dif_MaterialNumber  3428      2           0
# 75                    dif_PackedFruit  3428      2           0
# 76                          dif_Fruit  3428      2           0
# 77                          dif_Packs  3428      2           0
#
#                     Top  Top (%)  \
# 1                    na  11.0852
# 2   2019-07-24 14:30:00   1.2252
# 3                    na  9.10152
# 4                    na  9.10152
# 5                    na  19.1949
# 6                 61349  6.56359
# 7                 CNSHG  21.9078
# 8               E3ITKC6  20.9452
# 9   2019-07-24 00:00:00  9.33489
# 10                   na  82.5846
# 11                   na  84.5099
# 12                 BUKL  15.4026
# 13                 E3IT  31.8261
# 14                   na  84.5099
# 15                  KC6  52.1587
# 16              UNKNOWN  43.4364
# 17                   33  16.9487
# 18           2019-08-04  24.7083
# 19                   GR  52.9755
# 20                   IT  33.2264
# 21                    N  71.8786
# 22                  ZIL  83.8098
# 23                    Z  83.8098
# 24                   16  58.9848
# 25                    N  79.6674
# 26                 3TPP  81.8553
# 27                    3  39.4399
# 28                  0.0  43.4656
# 29                    Y   62.077
# 30                   CN   79.084
# ..                  ...      ...
# 48                61349  6.33022
# 49           2019-07-16  4.95916
# 50                  KC6  59.6849
# 51                   IT  39.6441
# 52                   GR  61.9312
# 53                    N  85.3851
# 54                    3  40.2859
# 55                    E  95.5368
# 56                   GA   68.203
# 57                    N  88.4481
# 58                False  95.2159
# 59                 True  59.8891
# 60                False  86.4936
# 61                False  99.7666
# 62                False  97.3746
# 63                False  95.3617
# 64                 True  65.4609
# 65                 True  70.5951
# 66                 True  70.5951
# 67                 True  70.5951
# 68                 True  86.7853
# 69                False  96.0618
# 70                False  99.1249
# 71                False  99.7958
# 72                False  99.5624
# 73                False  99.9708
# 74                False  94.3407
# 75                False  99.9708
# 76                False  95.1284
# 77                False  95.1284
#
#                                                Bottom Bottom (%)
# 1                                             1167DAY  0.0291715
# 2                                 2019-07-17 09:45:00  0.0291715
# 3                                              8643.0  0.0291715
# 4                                         CAIU5656760  0.0291715
# 5    CN, ID, IL, IN, JP, KR, MX, RE, TH, TW, Z1, Z...  0.0291715
# 6                                               64976  0.0291715
# 7                                               MXZLO  0.0291715
# 8                                             HNMBKJ1  0.0291715
# 9                                 2019-07-05 00:00:00  0.0583431
# 10                                             1883.0  0.0291715
# 11                                                 22  0.0291715
# 12                                               WTHR  0.0291715
# 13                                               WLML  0.0291715
# 14                                                2.0  0.0291715
# 15                                                VP6  0.0291715
# 16                                               MISS  0.0291715
# 17                                                 18   0.904317
# 18                                         2019-08-25  0.0291715
# 19                                                 DB  0.0291715
# 20                                                 MA  0.0875146
# 21                                                  B   0.525088
# 22                                                EPL  0.0291715
# 23                                                  E  0.0291715
# 24                                                  4  0.0291715
# 25                                                  A  0.0291715
# 26                                               3XBB  0.0583431
# 27                                                  L  0.0291715
# 28                                                 na   0.233372
# 29                                                  R    1.13769
# 30                                                 BS    1.89615
# ..                                                ...        ...
# 48                                              63045  0.0291715
# 49                                         2019-07-13  0.0583431
# 50                                                KC8  0.0291715
# 51                                                 MA  0.0875146
# 52                                                 DB  0.0291715
# 53                                                  M   0.525088
# 54                                                  L  0.0291715
# 55                                                  W  0.0291715
# 56                                                 HH  0.0291715
# 57                                                  T    11.5519
# 58                                               True    4.78413
# 59                                              False    40.1109
# 60                                               True    13.5064
# 61                                               True   0.233372
# 62                                               True    2.62544
# 63                                               True    4.63827
# 64                                              False    34.5391
# 65                                              False    29.4049
# 66                                              False    29.4049
# 67                                              False    29.4049
# 68                                              False    13.2147
# 69                                               True    3.93816
# 70                                               True   0.875146
# 71                                               True   0.204201
# 72                                               True   0.437573
# 73                                               True  0.0291715
# 74                                               True    5.65928
# 75                                               True  0.0291715
# 76                                               True    4.87165
# 77                                               True    4.87165
#
# [77 rows x 8 columns]

# %%
process_multiple['Order Number'].fillna('na',inplace=True)

# %%
temp_df=process_multiple
print('There are {} pallets went through {}.'.format(len(temp_df['Pallet Number'].unique()),target_process))
print('Transaction of Ordered Pallet : {}'.format(len(temp_df[temp_df['Order Number']!='na'])))
print('Percentage of Transaction of Ordered Pallet : {:.3f}%'.format(len(temp_df[temp_df['Order Number']!='na'])/len(temp_df)))
print('Total Unique Container order : {} '.format(len(temp_df['Container Number'].unique())-1))
print('Total Unique Envelope Number : {} '.format(len(temp_df['Envelope Number'].unique())))
#print('Chartered order : {} '.format(len(df[df['Container Number']=='na'])))
# Out:
# 19          114.0                   IJ         E
# 26           43.0                   IJ         E
# 30           90.0                   IT         E
# 31           45.0                   IT         E
# 32          124.0                   IJ         E
# 34           57.0                   IJ         E
# 35           28.0                   IJ         E
# 36           97.0                   IJ         E
# 37           82.0                   IJ         E
# 38           81.0                   IJ         E
# 44           92.0                   IJ         E
# 46           72.0                   IT         E
# 47          356.0                   IT         E
# 53           92.0                   IJ         E
# 55           76.0                   IT         E
# 71           21.0                   ML         E
# 79          204.0                   ML         E
# 93           65.0                   IT         E
# 100         155.0                   ML         E
# 103         103.0                   ML         E
# ...           ...                  ...       ...
# 3220        168.0                   MB         E
# 3227        251.0                   MB         E
# 3229        176.0                   MB         E
# 3235        106.0                   IT         E
# 3236          1.0                   IT         E
# 3237         28.0                   IT         E
# 3251         44.0                   IT         E
# 3252        176.0                   ML         H
# 3274         42.0                   MB         E
# 3320         66.0                   ML         E
# 3327        179.0                   MB         E
# 3329         51.0                   MB         E
# 3333        140.0                   MB         E
# 3338         44.0                   MB         E
# 3341         88.0                   MB         E
# 3343         59.0                   MB         E
# 3350         54.0                   MB         E
# 3354        281.0                   MB         E
# 3358         43.0                   MB         E
# 3360         49.0                   MB         E
# 3382         28.0                   MB         E
# 3393        241.0                   MB         E
# 3395        300.0                   MB         E
# 3403         64.0                   MB         E
# 3419         45.0                   MB         E
# 3421         15.0                   MB         E
# 3423         83.0                   MB         E
# 3424         86.0                   MB         E
# 3425        154.0                   MB         E
# 3426          1.0                   MB         E
#
#      Stacking Configuration Code_Trsc Customer Label Code_Trsc  \
# 0                                   N                        N
# 1                                   N                        N
# 5                                   N                        N
# 6                                   N                        N
# 7                                   1                        N
# 8                                   3                        R
# 9                                   N                        Z
# 12                                  N                        N
# 16                                  N                        N
# 17                                  N                        N
# 19                                  3                        N
# 26                                  N                        N
# 30                                  N                        N
# 31                                  N                        N
# 32                                  N                        N
# 34                                  N                        N
# 35                                  N                        N
# 36                                  N                        N
# 37                                  3                        N
# 38                                  3                        N
# 44                                  3                        N
# 46                                  N                        N
# 47                                  3                        N
# 53                                  N                        N
# 55                                  3                        N
# 71                                  N                        N
# 79                                  2                        N
# 93                                  N                        N
# 100                                 N                        N
# 103                                 N                        N
# ...                               ...                      ...
# 3220                                1                        B
# 3227                                1                        B
# 3229                                N                        B
# 3235                                N                        N
# 3236                                N                        N
# 3237                                3                        N
# 3251                                N                        N
# 3252                                2                        Z
# 3274                                1                        N
# 3320                                N                        N
# 3327                                N                        I
# 3329                                1                        I
# 3333                                1                        I
# 3338                                1                        I
# 3341                                1                        I
# 3343                                1                        I
# 3350                                1                        I
# 3354                                N                        Z
# 3358                                1                        I
# 3360                                1                        I
# 3382                                N                        N
# 3393                                1                        I
# 3395                                1                        I
# 3403                                1                        I
# 3419                                N                        N
# 3421                                N                        N
# 3423                                N                        N
# 3424                                N                        N
# 3425                                N                        N
# 3426                                N                        N
#
#      Variety Code_Trsc Pack Label Code_Trsc Pack Make Code_Trsc  \
# 0                   HW                    N                 KC1
# 1                   HW                    N                 KC1
# 5                   HW                    N                 KC3
# 6                   HW                    N                 KC1
# 7                   HW                    N                 KC1
# 8                   HW                    N                 KC1
# 9                   GA                    T                 KC6
# 12                  HW                    T                 KC1
# 16                  HW                    N                 KC1
# 17                  HW                    N                 KC1
# 19                  GA                    N                 KC3
# 26                  GA                    N                 VTY
# 30                  GA                    N                 VT6
# 31                  GA                    N                 VT6
# 32                  GA                    T                 VTY
# 34                  GA                    N                 VTY
# 35                  GA                    N                 VTY
# 36                  GA                    N                 VTY
# 37                  GA                    N                 VTY
# 38                  GA                    N                 VTY
# 44                  GA                    N                 VTY
# 46                  GA                    N                 VT6
# 47                  GA                    N                 VT6
# 53                  GA                    N                 KC3
# 55                  GA                    T                 KC6
# 71                  GA                    N                 VP6
# 79                  GA                    N                 KC6
# 93                  GA                    N                 KC6
# 100                 GA                    N                 KC6
# 103                 GA                    N                 KC6
# ...                ...                  ...                 ...
# 3220                HW                    T                 KC1
# 3227                HW                    N                 KC1
# 3229                HW                    N                 KC1
# 3235                HW                    N                 KC1
# 3236                HW                    N                 KC1
# 3237                HW                    N                 KC1
# 3251                HW                    N                 KC1
# 3252                GA                    N                 KC6
# 3274                HW                    N                 KC1
# 3320                GA                    N                 KC6
# 3327                HW                    T                 KJ1
# 3329                HW                    N                 KJ1
# 3333                HW                    N                 KJ1
# 3338                HW                    N                 KJ1
# 3341                HW                    N                 KJ1
# 3343                HW                    N                 KJ1
# 3350                HW                    N                 KJ1
# 3354                HW                    T                 KJ1
# 3358                HW                    N                 KJ1
# 3360                HW                    N                 KJ1
# 3382                HW                    N                 KJ1
# 3393                HW                    T                 KJ1
# 3395                HW                    T                 KJ1
# 3403                HW                    T                 KJ1
# 3419                HW                    T                 KJ1
# 3421                HW                    N                 KJ1
# 3423                HW                    N                 NKF
# 3424                HW                    N                 NKF
# 3425                HW                    N                 NKF
# 3426                HW                    N                 NKF
#
#      Labelling Indicator Code_Trsc Material Number_Trsc  Packed Fruit_Trsc  \
# 0                               GR                61555                  0
# 1                               GR                61555                  0
# 5                               JB                55974                  0
# 6                               GR                51170                  0
# 7                               GR                61588                  0
# 8                               LG                62809                  0
# 9                               JB                61575                  0
# 12                              GR                61589                  0
# 16                              GR                61591                  0
# 17                              GR                51170                  0
# 19                              JB                61601               3600
# 26                              JB                61600               4400
# 30                              GR                61341               5800
# 31                              GR                61341               5800
# 32                              JB                61600               4400
# 34                              JB                61600               4400
# 35                              JB                61600               4400
# 36                              JB                61600               4400
# 37                              JB                61602               4400
# 38                              JB                61602               4400
# 44                              JB                61602               4400
# 46                              GR                61341               5800
# 47                              GR                61347               5800
# 53                              JB                61600               4400
# 55                              GR                61347               5800
# 71                              GR                61577               6560
# 79                              GR                61582               7680
# 93                              GR                61342               6264
# 100                             LG                62626              10400
# 103                             LG                62625               9280
# ...                            ...                  ...                ...
# 3220                            GR                61592               8500
# 3227                            GR                61592               8500
# 3229                            GR                61593               8500
# 3235                            GR                61555               7656
# 3425        6095          53  156.282051             115             False
# 3426        4030          31   95.952381             130             False
#
#       FW_dif_StackingConfigurationCode  FW_dif_CustomerLabelCode  \
# 0                                False                     False
# 1                                False                     False
# 5                                False                     False
# 6                                False                     False
# 7                                False                     False
# 8                                False                      True
# 9                                False                     False
# 12                               False                     False
# 16                                True                     False
# 17                               False                     False
# 19                                True                     False
# 26                               False                     False
# 30                               False                     False
# 31                               False                     False
# 32                               False                     False
# 34                               False                     False
# 35                               False                     False
# 36                               False                     False
# 37                                True                     False
# 38                                True                     False
# 44                                True                     False
# 46                               False                     False
# 47                                True                     False
# 53                               False                     False
# 55                                True                     False
# 71                               False                     False
# 79                                True                     False
# 93                               False                     False
# 100                              False                     False
# 103                              False                     False
# ...                                ...                       ...
# 3220                              True                      True
# 3227                              True                      True
# 3229                             False                      True
# 3235                             False                     False
# 3236                             False                     False
# 3237                              True                     False
# 3251                             False                     False
# 3252                             False                     False
# 3274                             False                     False
# 3320                             False                     False
# 3327                             False                      True
# 3329                             False                      True
# 3333                             False                      True
# 3338                             False                      True
# 3341                             False                      True
# 3343                             False                      True
# 3350                             False                      True
# 3354                             False                      True
# 3358                             False                      True
# 3360                             False                      True
# 3382                             False                     False
# 3393                             False                     False
# 3395                             False                     False
# 3403                             False                     False
# 3419                             False                     False
# 3421                             False                     False
# 3423                             False                     False
# 3424                             False                     False
# 3425                             False                     False
# 3426                             False                     False
#
#       FW_dif_PackLabelCode  FW_dif_PackMakeCode  \
# 0                    False                False
# 1                    False                False
# 5                    False                False
# 6                    False                False
# 7                    False                False
# 8                    False                False
# 9                    False                False
# 12                   False                False
# 16                   False                False
# 17                   False                False
# 19                   False                False
# 26                   False                False
# 30                   False                False
# 31                   False                False
# 32                   False                False
# 34                   False                False
# 35                   False                False
# 36                   False                False
# 37                   False                False
# 38                   False                False
# 44                   False                False
# 46                   False                False
# 47                   False                False
# 53                   False                False
# 55                   False                 True
# 71                   False                False
# 79                   False                 True
# 93                   False                False
# 100                  False                False
# 103                  False                False
# ...                    ...                  ...
# 3220                 False                False
# 3227                 False                False
# 3229                 False                False
# 3235                 False                False
# 3236                 False                False
# 3237                 False                False
# 3251                 False                False
# 3252                 False                False
# 3274                 False                False
# 3320                 False                False
# 3327                 False                False
# 3329                 False                False
# 3333                 False                False
# 3338                 False                False
# 3341                 False                False
# 3343                 False                False
# 3350                 False                False
# 3354                 False                False
# 3358                 False                False
# 3360                 False                False
# 3382                 False                False
# 3393                 False                False
# 3395                 False                False
# 3403                 False                False
# 3419                 False                False
# 3421                 False                False
# 3423                 False                False
# 3424                 False                False
# 3425                 False                False
# 3426                 False                False
#
#       FW_dif_LabellingIndicatorCode  FW_dif_MaterialNumber  FW_dif_Fruit  \
# 0                             False                  False          True
# 1                             False                  False          True
# 5                             False                  False          True
# 6                             False                  False          True
# 7                             False                  False         False
# 8                             False                  False         False
# 9                             False                  False         False
# 12                            False                  False          True
# 16                            False                   True          True
# 17                            False                  False          True
# 19                            False                   True          True
# 26                            False                  False          True
# 30                            False                  False          True
# 31                            False                  False         False
# 32                            False                  False         False
# 34                            False                  False          True
# 35                            False                  False          True
# 36                            False                  False          True
# 37                            False                   True          True
# 38                            False                   True          True
# 44                            False                   True          True
# 46                            False                  False          True
# 47                            False                   True          True
# 53                            False                  False         False
# 55                            False                   True          True
# 71                            False                  False         False
# 79                            False                   True          True
# 93                            False                  False          True
# 100                           False                  False          True
# 103                           False                  False         False
# ...                             ...                    ...           ...
# 3220                          False                   True          True
# 3227                          False                   True          True
# 3229                          False                  False          True
# 3235                          False                  False          True
# 3236                          False                  False         False
# 3237                          False                   True          True
# 3251                          False                  False          True
# 3252                          False                   True          True
# 3274                          False                  False         False
# 3320                          False                  False          True
# 3327                          False                  False         False
# 3329                          False                  False         False
# 3333                          False                  False         False
# 3338                          False                  False         False
# 3341                          False                  False         False
# 3343                          False                  False         False
# 3350                          False                  False         False
# 3354                          False                  False         False
# 3358                          False                  False         False
# 3360                          False                  False         False
# 3382                          False                  False         False
# 3393                          False                  False         False
# 3395                          False                  False         False
# 3403                          False                  False         False
# 3419                          False                  False          True
# 3421                          False                  False         False
# 3423                          False                  False         False
# 3424                          False                  False         False
# 3425                          False                  False          True
# 3426                          False                  False         False
#
#       FW_dif_Packs  FW_dif_Trays  PackageChange  isPackageChange  \
# 0             True          True              3             True
# 1             True          True              3             True
# 5             True          True              3             True
# 6             True          True              3             True
# 7            False         False              0            False
# 8            False         False              1             True
# 9            False         False              0            False
# 12            True          True              3             True
# 16            True          True              6             True
# 17            True          True              3             True
# 19            True          True              5             True
# 26            True          True              3             True
# 30            True          True              3             True
# 31           False         False              0            False
# 32           False         False              0            False
# 34            True          True              3             True
# 35            True          True              3             True
# 36            True          True              3             True
# 37            True          True              5             True
# 38            True          True              5             True
# 44            True          True              5             True
# 46            True          True              3             True
# 47            True          True              5             True
# 53           False         False              0            False
# 55            True          True              6             True
# 71           False         False              0            False
# 79            True          True              6             True
# 93            True          True              3             True
# 100           True          True              3             True
# 103          False         False              0            False
# ...            ...           ...            ...              ...
# 3220          True          True              6             True
# 3227          True          True              6             True
# 3229          True          True              4             True
# 3235          True          True              3             True
# 3236         False         False              0            False
# 3237          True          True              5             True
# 3251          True          True              3             True
# 3252          True          True              5             True
# 3274         False         False              0            False
# 3320          True          True              3             True
# 3327         False         False              1             True
# 3329         False         False              1             True
# 3333         False         False              1             True
# 3338         False         False              1             True
# 3341         False         False              1             True
# 3343         False         False              1             True
# 3350         False         False              1             True
# 3354         False         False              1             True
# 3358         False         False              1             True
# 3360         False         False              1             True
# 3382         False         False              0            False
# 3393         False         False              0            False
# 3395         False         False              0            False
# 3403         False         False              0            False
# 3419          True          True              3             True
# 3421         False         False              0            False
# 3423         False         False              0            False
# 3424         False         False              0            False
# 3425          True          True              3             True
# 3426         False         False              0            False
#
#      Location Room Code Location Row Code Location Column Location Height  \
# 0               UNKNOWN                na              na             0.0
# 1               UNKNOWN                na              na             0.0
# 5                   NaN               NaN             NaN             NaN
# 6                   NaN               NaN             NaN             NaN
# 7                   NaN               NaN             NaN             NaN
# 8               UNKNOWN                na              na             0.0
# 9               UNKNOWN                na              na             0.0
# 12                  NaN               NaN             NaN             NaN
# 16                  NaN               NaN             NaN             NaN
# 17                  NaN               NaN             NaN             NaN
# 19                  NaN               NaN             NaN             NaN
# 26                  NaN               NaN             NaN             NaN
# 30                  NaN               NaN             NaN             NaN
# 31                  NaN               NaN             NaN             NaN
# 32                CONTR                na              na             1.0
# 34                  NaN               NaN             NaN             NaN
# 35                  NaN               NaN             NaN             NaN
# 36                  NaN               NaN             NaN             NaN
# 37                  NaN               NaN             NaN             NaN
# 38                  NaN               NaN             NaN             NaN
# 44                  NaN               NaN             NaN             NaN
# 46                CONTR                na              na             1.0
# 47                CONTR                na              na             1.0
# 53              UNKNOWN                na              na             0.0
# 55                CONTR                na              na             1.0
# 71                CONTR                na              na             1.0
# 79              UNKNOWN                na              na             0.0
# 93              UNKNOWN                na              na             0.0
# 100             UNKNOWN                na              na             0.0
# 103               CONTR                na              na             1.0
# ...                 ...               ...             ...             ...
# 3220              CONTR                na              na             1.0
# 3227            UNKNOWN                na              na             0.0
# 3229              CONTR                na              na             1.0
# 3235                NaN               NaN             NaN             NaN
# 3236                NaN               NaN             NaN             NaN
# 3237                NaN               NaN             NaN             NaN
# 3251                NaN               NaN             NaN             NaN
# 3252            UNKNOWN                na              na             0.0
# 3274              CONTR                na              na             1.0
# 3320            UNKNOWN                na              na             0.0
# 3327              CONTR                na              na             1.0
# 3329            UNKNOWN                na              na             0.0
# 3333              CONTR                na              na             1.0
# 3338              CONTR                na              na             1.0
# 3341            UNKNOWN                na              na             0.0
# 3343            UNKNOWN                na              na             0.0
# 3350              CONTR                na              na             1.0
# 3354            UNKNOWN                na              na             0.0
# 3358              CONTR                na              na             1.0
# 3360            UNKNOWN                na              na             0.0
# 3382              CONTR                na              na             1.0
# 3393            UNKNOWN                na              na             0.0
# 3395            UNKNOWN                na              na             0.0
# 3403            UNKNOWN                na              na             0.0
# 3419                NaN               NaN             NaN             NaN
# 3421                NaN               NaN             NaN             NaN
# 3423              CONTR                na              na             1.0
# 3424            UNKNOWN                na              na             0.0
# 3425                NaN               NaN             NaN             NaN
# 3426                NaN               NaN             NaN             NaN
#
#      Location Request Number Storage Source Code Pack Label Code_Dptch  \
# 0                         na                  CN                     N
# 1                         na                  CN                     N
# 5                        NaN                 NaN                   NaN
# 6                        NaN                 NaN                   NaN
# 7                        NaN                 NaN                   NaN
# 8                         na                  CN                     N
# 9                         na                  CN                     T
# 12                       NaN                 NaN                   NaN
# 16                       NaN                 NaN                   NaN
# ...
# 3229                     NaN                -3.0                 -15.0
# 3235                     NaN                 NaN                   NaN
# 3236                     NaN                 NaN                   NaN
# 3237                     NaN                 NaN                   NaN
# 3251                     NaN                 NaN                   NaN
# 3252                     NaN                -2.0                 -14.0
# 3274                     NaN                -2.0                  -7.0
# 3320                     NaN                -2.0                 -31.0
# 3327                     NaN                -1.0                 -36.0
# 3329                     NaN                -1.0                 -36.0
# 3333                     NaN                -1.0                 -36.0
# 3338                     NaN                -1.0                 -36.0
# 3341                     NaN                -1.0                 -36.0
# 3343                     NaN                -1.0                 -36.0
# 3350                     NaN                -1.0                 -36.0
# 3354                     NaN                -4.0                 -11.0
# 3358                     NaN                -1.0                 -36.0
# 3360                     NaN                -1.0                 -36.0
# 3382                     NaN                -1.0                 -37.0
# 3393                     NaN                -2.0                 -34.0
# 3395                     NaN                -2.0                 -34.0
# 3403                     NaN                -2.0                 -37.0
# 3419                     NaN                 NaN                   NaN
# 3421                     NaN                 NaN                   NaN
# 3423                   -24.0                 NaN                 -11.0
# 3424                   -24.0                 NaN                 -11.0
# 3425                     NaN                 NaN                   NaN
# 3426                     NaN                 NaN                   NaN
#
#       dif_StackingConfigurationCode  dif_CustomerLabelCode  dif_PackLabelCode  \
# 0                              True                  False              False
# 1                              True                  False              False
# 5                             False                  False              False
# 6                             False                  False              False
# 7                             False                  False              False
# 8                             False                  False              False
# 9                             False                   True              False
# 12                            False                  False              False
# 16                            False                  False              False
# 17                            False                  False              False
# 19                            False                  False              False
# 26                            False                  False              False
# 30                            False                  False              False
# 31                            False                  False              False
# 32                             True                  False              False
# 34                            False                  False              False
# 35                            False                  False              False
# 36                            False                  False              False
# 37                            False                  False              False
# 38                            False                  False              False
# 44                            False                  False              False
# 46                             True                  False              False
# 47                            False                  False              False
# 53                             True                  False              False
# 55                            False                  False               True
# 71                             True                  False              False
# 79                            False                  False              False
# 93                             True                  False              False
# 100                           False                   True              False
# 103                           False                   True              False
# ...                             ...                    ...                ...
# 3220                           True                  False              False
# 3227                           True                  False              False
# 3229                          False                  False              False
# 3235                          False                  False              False
# 3236                          False                  False              False
# 3237                          False                  False              False
# 3251                          False                  False              False
# 3252                          False                   True              False
# 3274                          False                  False              False
# 3320                           True                  False              False
# 3327                          False                  False              False
# 3329                          False                  False              False
# 3333                          False                  False              False
# 3338                          False                  False              False
# 3341                          False                  False              False
# 3343                          False                  False              False
# 3350                          False                  False              False
# 3354                          False                   True              False
# 3358                          False                  False              False
# 3360                          False                  False              False
# 3382                          False                   True              False
# 3393                          False                   True              False
# 3395                          False                   True              False
# 3403                          False                  False              False
# 3419                          False                  False              False
# 3421                          False                  False              False
# 3423                          False                  False              False
# 3424                          False                  False              False
# 3425                          False                  False              False
# 3426                          False                  False              False
#
#       dif_PackMakeCode  dif_LabellingIndicatorCode  dif_MaterialNumber  \
# 0                False                       False                True
# 1                False                       False                True
# 5                False                       False               False
# 6                False                       False               False
# 7                False                       False               False
# 8                False                       False                True
# 9                False                       False               False
# 12               False                       False               False
# 16               False                       False               False
# 17               False                       False               False
# 19               False                       False               False
# 26               False                       False               False
# 30               False                       False               False
# 31               False                       False               False
# 32                True                       False                True
# 34               False                       False               False
# 35               False                       False               False
# 36               False                       False               False
# 37               False                       False               False
# 38               False                       False               False
# 44               False                       False               False
# 46                True                       False                True
# 47                True                       False               False
# 53                True                       False                True
# 55               False                       False               False
# 71                True                       False                True
# 79               False                       False               False
# 93               False                       False                True
# 100              False                       False               False
# 103              False                       False               False
# ...                ...                         ...                 ...
# 3220             False                       False                True
# 3227             False                       False                True
# 3229             False                       False               False
# 3235             False                       False               False
# 3236             False                       False               False
# 3237             False                       False               False
# 3251             False                       False               False
# 3252             False                       False               False
# 3274             False                       False                True
# 3320             False                       False                True
# 3327              True                       False                True
# 3329              True                       False                True
# 3333              True                       False                True
# 3338              True                       False                True
# 3341              True                       False                True
# 3343              True                       False                True
# 3350              True                       False                True
# 3354             False                       False               False
# 3358              True                       False                True
# 3360              True                       False                True
# 3382             False                       False               False
# 3393             False                       False               False
# 3395             False                       False               False
# 3403             False                       False                True
# 3419             False                       False               False
# 3421             False                       False               False
# 3423             False                       False                True
# 3424             False                       False                True
# 3425             False                       False               False
# 3426             False                       False               False
#
#       dif_PackedFruit  dif_Fruit  dif_Packs  pendingProcess  isRTG
# 0               False       True       True               4  False
# 1               False       True       True               4  False
# 5               False      False      False               0  False
# 6               False      False      False               0  False
# 7               False      False      False               0  False
# 8               False      False      False               1  False
# 9               False       True       True               3  False
# 12              False      False      False               0  False
# 16              False      False      False               0  False
# 17              False      False      False               0  False
# 19              False      False      False               0  False
# 26              False      False      False               0  False
# 30              False      False      False               0  False
# 31              False      False      False               0  False
# 32              False       True       True               5  False
# 34              False      False      False               0  False
# 35              False      False      False               0  False
# 36              False      False      False               0  False
# 37              False      False      False               0  False
# 38              False      False      False               0  False
# 44              False      False      False               0  False
# 46              False       True       True               5  False
# 47              False       True       True               3  False
# 53              False       True       True               5  False
# 55              False      False      False               1  False
# 71              False       True       True               5  False
# 79              False       True       True               2  False
# 93              False       True       True               4  False
# 100             False       True       True               3  False
# 103             False      False      False               1  False
# ...               ...        ...        ...             ...    ...
# 3220            False       True       True               4  False
# 3227            False       True       True               4  False
# 3229            False       True       True               2  False
# 3235            False      False      False               0  False
# 3236            False      False      False               0  False
# 3237            False      False      False               0  False
# 3251            False      False      False               0  False
# 3252            False      False      False               1  False
# 3274            False      False      False               1  False
# 3320            False       True       True               4  False
# 3327            False      False      False               2  False
# 3329            False      False      False               2  False
# 3333            False      False      False               2  False
# 3338            False      False      False               2  False
# 3341            False      False      False               2  False
# 3343            False      False      False               2  False
# 3350            False      False      False               2  False
# 3354            False      False      False               1  False
# 3358            False      False      False               2  False
# 3360            False      False      False               2  False
# 3382            False      False      False               1  False
# 3393            False      False      False               1  False
# 3395            False      False      False               1  False
# 3403            False      False      False               1  False
# 3419            False      False      False               0  False
# 3421            False      False      False               0  False
# 3423            False      False      False               1  False
# 3424            False      False      False               1  False
# 3425            False      False      False               0  False
# 3426            False      False      False               0  False
#
# [723 rows x 107 columns]

# %%
plt.figure(figsize=(12,8))
process_multiple['duration_FW'].plot(kind='hist',bins=50)
plt.title('Distribution of Procssing Time',fontsize=20)
plt.xlabel('Duration FW (minutes)')
# Out:
# Text(0.5, 0, 'Duration FW (minutes)')
