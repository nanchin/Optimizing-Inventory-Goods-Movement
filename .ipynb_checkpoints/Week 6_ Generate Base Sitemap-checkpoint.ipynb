# %% [markdown]
# Updates:
#
# - 20 Oct 8pm-10pm : started to code for sitemap generation
# - 21 Oct 1pm-3pm : generate sitemap

# %%
q_time='2019-07-10 07:00:00'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import gc

from scipy.stats import skew,kurtosis
import datetime
import re
import fnmatch

# %%
# %matplotlib inline
# to view all columns
pd.set_option('display.max_columns',500)
plt.style.use('seaborn')

# %%
def summary_object(arg_df):
    
    object_list=[]
    category_list=[]
    bool_list=[]
    unilabel_list=[]
    missing_list=[]
    
    for c in arg_df.columns:
        if arg_df[c].dtypes==object:
            object_list.append(c)
        elif str(arg_df[c].dtypes)=='category':
            category_list.append(c)
        elif arg_df[c].dtypes==bool:
            bool_list.append(c)
    if len(object_list)+len(category_list)+len(bool_list)>0:    
        index_list=['Count','Unique','Missing (%)','Top','Top (%)','Bottom','Bottom (%)']
        df_summary=pd.DataFrame(data=np.zeros((len(index_list),len(object_list))),index=index_list,columns=object_list)

        for col in object_list+category_list+bool_list:
            vc=arg_df[col].value_counts().reset_index()
            df_summary.loc['Count',col]=(arg_df[col].count())
            df_summary.loc['Unique',col]=len(arg_df[col].unique())
            df_summary.loc['Missing (%)',col]=arg_df[col].isna().mean()*100
            df_summary.loc['Top',col]=vc.iloc[0,0]
            df_summary.loc['Top (%)',col]=vc.iloc[0,1]/len(arg_df)*100
            if len(arg_df[col].unique())>2:
                df_summary.loc['Bottom',col]=vc.iloc[-1,0]
                df_summary.loc['Bottom (%)',col]=vc.iloc[-1,1]/len(arg_df)*100
            elif (len(arg_df[col].unique())==2) & (df_summary.loc['Missing (%)',col]==0):
                df_summary.loc['Bottom',col]=vc.iloc[-1,0]
                df_summary.loc['Bottom (%)',col]=vc.iloc[-1,1]/len(arg_df)*100
            else:
                unilabel_list.append(col)
            if df_summary.loc['Missing (%)',col]==100:
                missing_list.append(col)
                
        df_summary=df_summary.T.sort_values(['Missing (%)','Unique'],ascending=False)
        df_summary=df_summary[(df_summary['Unique']>1) & (df_summary['Missing (%)']!=100)]
        df_summary.reset_index(inplace=True)
        df_summary.index=df_summary.index+1
        df_summary.columns=['Attribute']+index_list
        
        print('SUMMARY OF {} NON-NUMERICAL ATTRIBUTES:\n'.format(
            len(object_list)+len(category_list)+len(bool_list)))
        if len(object_list)>0:
            print('{} Object Columns'.format(len(object_list)))
        if len(category_list)>0:
            print('{} Categorical Columns'.format(len(category_list)))
        if len(bool_list)>0:
            print('{} Bool Columns'.format(len(bool_list)))
        if len(unilabel_list)>0:
            print('\n{} Columns with Single Label : \n{}'.format(len(unilabel_list),unilabel_list))
        if len(missing_list)>0:
            print('\n{} Empty Columns: \n{}'.format(len(missing_list),missing_list))   
            
        del arg_df,object_list,vc,index_list,unilabel_list,missing_list
        gc.collect()
        return df_summary
    else:
        print('No Non-Numerical Attributes')
'============================================================='        
def summary_numerical(arg_df):

    target_list=[]
    missing_list=[]
    zero_skew_list=[]
    
    for c in arg_df.columns:
        datatype=arg_df[c].dtypes
        if datatype != object and datatype != bool and str(datatype) != 'category' and str(datatype) !='datetime64[ns]':
            target_list.append(c)
    if len(target_list)>0:
        from scipy.stats import skew,kurtosis
        
        index_list=['Count','Missing (%)','Mean','Median','Min','Max','Skewness','Kurtosis']
        df_summary=pd.DataFrame(data=np.zeros((len(index_list),len(target_list))),
                                index=index_list,columns=target_list)
        for col in target_list:
            df_summary.loc['Count',col]=arg_df[col].count()
            df_summary.loc['Missing (%)',col]=arg_df[col].isna().mean()*100
            if df_summary.loc['Missing (%)',col]!=100:
                df_summary.loc['Mean',col]=arg_df[col].mean()
                df_summary.loc['Median',col]=arg_df[col].median()
                df_summary.loc['Min',col]=arg_df[col].min()
                df_summary.loc['Max',col]=arg_df[col].max()
                df_summary.loc['Skewness',col]=skew(arg_df[col])
                if df_summary.loc['Skewness',col]==0:
                    zero_skew_list.append(col)
                df_summary.loc['Kurtosis',col]=kurtosis(arg_df[col])
            else:
                missing_list.append(col)
                
        df_summary=df_summary.T.sort_values(['Missing (%)','Skewness'],ascending=False)
        df_summary=df_summary[(df_summary['Skewness']!=0) & (df_summary['Missing (%)']!=100)]
        df_summary.reset_index(inplace=True)
        df_summary.index=df_summary.index+1
        df_summary.columns=['Attribute']+index_list
        
        print('SUMMARY OF {} NUMERICAL ATTRIBUTES:'.format(len(target_list)))
        if len(zero_skew_list)>0:
            print('\n{} Columns with Single Value: \n{}'.format(len(zero_skew_list),zero_skew_list))
        if len(missing_list)>0:
            print('\n{} Empty Columns: \n{}'.format(len(missing_list),missing_list))
        del arg_df,target_list,index_list
        gc.collect()

        return df_summary
    else:
        print('No Numerical Attributes')
'==================================================================='        
def drop_unilable_column(arg_df):
    
    target_list=[]
    object_list=[]
    number_list=[]
    for c in arg_df.columns:
        if (arg_df[c].dtypes==object) | (str(arg_df[c].dtypes)=='category') | (arg_df[c].dtypes==bool):
            object_list.append(c)
        elif str(arg_df[c].dtypes)!='datetime64[ns]':
            number_list.append(c)
    if len(object_list)>0:    
        for c in object_list:
            if len(arg_df[c].unique())==1:
                target_list.append(c)
            elif (len(arg_df[c].unique())==2) & (arg_df[c].isna().mean()>0):
                target_list.append(c)
    
    if len(number_list)>0:   
        from scipy.stats import skew
        for c in number_list:
            if skew(arg_df[c])==0:
                target_list.append(c)
                
    if len(target_list)>0:
        arg_df.drop(columns=target_list,axis='columns',inplace=True)
        print('Drop {} Columns with Single Label:\n{}'.format(len(target_list),target_list))
    else: 
        print('No Columns with Single Label/Value')

    del target_list,object_list
'===================================================================' 
def drop_empty_column(arg_df):
    target_list=[]
    for c in arg_df.columns:
        if arg_df[c].count()==0:
            target_list.append(c)
    if len(target_list)>0:
        arg_df.drop(columns=target_list,axis=1,inplace=True)
        print('Delete {} Empty Column : \n{}'.format(len(target_list),target_list))
    else:
        print('No Empty Column')
'==================================================================='        
def drop_columns(arg_df,column_names):
    arg_df.drop(columns=column_names,axis='columns',inplace=True)
    print('Drop {} columns : \n{}'.format(len(column_names),column_names))
'============================================================='        
def extract_room_row(arg_df,col_position):
    '''To return unique Room-Row from standard Room-Row-Column-Height position data'''
    roomrow=[]
    roomrow=arg_df[col_position].apply(lambda x :x.split('-')[0]+'-'+x.split('-')[1] if '-' in x else x)
    roomrow=roomrow.unique().tolist()
    roomrow=pd.DataFrame(roomrow,columns=['Unique_Row']).sort_values(by='Unique_Row')
    return roomrow['Unique_Row'].values
'============================================================='  
def generate_dif_columns(arg_df,left_column,left_sffx,right_sffx):
    common_title=[]
    for idx,c in enumerate(left_column):
        common_title.append(left_column[idx].split(left_sffx)[0])
    print('There are {} common columns : \n{}'.format(len(left_column),common_title))

    for idx,c in enumerate(common_title):
        compare_col=common_title[idx].replace(' ','')
        arg_df['dif_'+compare_col]=(arg_df[c+left_sffx]!=arg_df[c+right_sffx]) & (arg_df[c+right_sffx].notna())
    print('\nColumns Generated : {}'.format(len(common_title)))
'==================================================================='        
def find_time_dif_hour(arg_df,ref_date,proc_date):
    new_date_attribute=[c.replace(' ','_') for c in proc_date]
    for idx,c in enumerate(proc_date):
        arg_df[new_date_attribute[idx]+'_hour']=arg_df[c]-arg_df[ref_date]
        arg_df[new_date_attribute[idx]+'_hour']=arg_df[new_date_attribute[idx]+'_hour'].astype('timedelta64[h]')

# %% [markdown]
# # 1) Import 2 dataset : trans and disp

# %%
path='C:/Users/Nan/Documents/GitHub_Data/'
file_1=path+'p_transaction_2.csv'
file_2=path+'p_dispatched_2.csv'

filename_1=file_1
filename_2=file_2

sffx_transaction='_Trsc'
sffx_dispatched='_Dptch'
target_process='FW'

# %%
filename_1
# Out:
# 'C:/Users/Nan/Documents/GitHub_Data/p_transaction_2.csv'

# %%
trans=pd.read_csv(filename_1)
disp=pd.read_csv(filename_2)
# Out:
# C:\Users\Nan\AppData\Local\conda\conda\envs\env\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
trans.shape
# Out:
# (207259, 48)

# %%
trans.head(2)
# Out:
#   Transaction Date Time Customer Label Code Dry Matter Code  Fruit  \
# 0   2019-07-01 00:00:10                   N               Y  13000
# 1   2019-07-01 00:00:15                   N               Y   9216
#
#    Fruit Per Pack Fruit Size Code Labelling Indicator Code  \
# 0             130              42                       LG
# 1              36              36                       LG
#
#   Location Mission Request Destination Marketer Code Material Number  \
# 0                                   na           ZIL           62853
# 1                                   na           ZIL           62809
#
#     New Value        Ok Until Date  Pack Code            Pack Date  \
# 0  Q02-03-4-1  2019-07-21 00:00:00      41236  2019-06-06 00:00:00
# 1  Q14-15-9-2  2019-07-21 00:00:00      41717  2019-06-05 00:00:00
#
#    Packed Fruit Packhouse Code Pack Label Code Pack Make Code  Packs  \
# 0         13000           3TPP               N            KC1    100
# 1          9216           3TPP               N            KC1    256
#
#    Pallet Number  Pallet Rework Count  Plant Code Previous Value  \
# 0       59717008                    0        1103     Q02-03-3-1
# 1       59708334                    0        1103    Q14-02-10-1
#
#   Protocol Code Purchase Pool Code Quality Inspection Indicator Code  \
# 0             N                 01                                 A
# 1             N                 01                                 A
#
#   Storage Method Code     Transaction Date Transaction Sub Type Code  \
# 0                  CN  2019-07-01 00:00:10                       MLA
# 1                  CN  2019-07-01 00:00:15                       MTA
#
#        Trays Username Variety Code  Ok_Until_Date_day  Pack_Date_day  \
# 0  309.52381    agubs           HW               19.0          -26.0
# 1  256.00000   jaspsi           HW               19.0          -27.0
#
#    isDOINumber Pack Style Code Pack_Base Stacking Configuration Code  \
# 0        False              MB         E                           N
# 1        False              IT         E                           3
#
#    isDayShift  Shift_Hour Day_of_week  isWeekend  isActualMovement  \
# 0       False           0         Sun       True              True
# 1       False           0         Sun       True              True
#
#    isPackedFruitequalFruit Previous_RoomRow Previous_Column Previous_Height  \
# 0                     True           Q02-03               3               1
# 1                     True           Q14-02              10               1
#
#   distance_to_driveway
# 0                   10
# 1                    3

# %%
disp.shape
# Out:
# (32251, 72)

# %%
disp.head(2)
# Out:
#    Pallet Number Location Room Code Location Row Code Location Column  \
# 0       54510208                Q27                 A            11.0
# 1       54510260            UNKNOWN                na              na
#
#   Location Height Location Request Number Storage Source Code Pack Label Code  \
# 0             1.0                      na                  CN               N
# 1             0.0                      na                  CN               N
#
#   Pack Indicator Code Clearance Protocol Code Customer Label Code  \
# 0                   N                       A                   N
# 1                   N                       A                   N
#
#   Dry Matter Code Storing Characteristic Code CCKPassed Failed  \
# 0               Y                           P               na
# 1               Y                           P               na
#
#   Quality Inspection Indicator Code Japan Sub Brand Code  \
# 0                                 A                    N
# 1                                 A                    N
#
#   Trial Packing Indicator Code Marketer Code  Loadout Priority  \
# 0                            N           ZIL                20
# 1                            N           ZIL                20
#
#   Material Number Material Group Code Brand Code Variety Code  \
# 0           61600              Zespri          Z           GA
# 1           61577              Zespri          Z           GA
#
#    Fruit Class Code Fruit Size Code Pack Category Code  \
# 0                 1              22               ENIJ
# 1                 1              25               ENML
#
#   Labelling Indicator Code Purchase Pool Code  Pack Code Growing Method  \
# 0                       JB                 16      10168             CK
# 1                       GR                 16      10182             CK
#
#    Packs Per Pallet Maturity Indicator Code        Ok Until Date  Plant Code  \
# 0               200                       C  2019-05-05 00:00:00        1103
# 1               160                       C  2019-05-05 00:00:00        1103
#
#    Ignore Psr Pack Type Code  Packed Fruit  Packed Trays Packhouse Code  \
# 0       False        ENIJKC3          4400         200.0           3TPP
# 1       False        ENMLKC6          6560         262.4           3TPP
#
#   Pallet Card Reference  Fruit  Order Number  Order Line Number  \
# 0               3121DAY   4400       5146501                 20
# 1               3121DAY   6560       5166002                 20
#
#           Loadout Date  Shipment Type Code Destination Port Code  \
# 0  2019-03-28 13:00:00                   1                 JPTYO
# 1  2019-04-03 16:00:00                  18                 SGSIN
#
#   Trucking Company Code  Packs  Full Market Holds Stacking Configuration Code  \
# 0                  PRHA    200  True   KR, RE, Z7                           N
# 1                  TOLL    160  True   KR, RE, Z7                           N
#
#   Pack Style Code Pack Make Code      Load Start Date  Envelope Number  \
# 0              IJ            KC3  2019-03-27 00:00:00           193017
# 1              ML            KC6  2019-04-02 00:00:00           193074
#
#   Container Container Number  isDoi_Number  isInternal_Holds  \
# 0        na               na         False             False
# 1    7839.0      PCIU6069215         False             False
#
#    isTemporary_Seal_Number  isTemperature_Recorder_Number  \
# 0                    False                          False
# 1                     True                           True
#
#    isLocation_Mission_Request_Destination  isRf_Id_Tag1  isPermanentSeal  \
# 0                                   False          True            False
# 1                                   False          True            False
#
#    Pallet Note Pack_Base  Repack_Date_day  Last_Spqi_Date_day  Pack_Date_day  \
# 0        False         E              NaN                 NaN          -11.0
# 1        False         E              NaN                 NaN          -17.0
#
#    Doi_Clearance_Date_day  Tkl_Email_Date_day  Load_Start_Date_hour
# 0                     NaN                 NaN                 -37.0
# 1                     NaN                 NaN                 -40.0

# %% [markdown]
# ### Data Processing so that common columns have same set of data label
#     -change to string:Fruit Size Code_Trsc
#     -truncate 0 at first position:Purchase Pool Code_Trsc
#     -incorrect calculation as referring to dif,should remain in datetime: date columns(incl Ok_Until_Date_day,Pack_Date_day)

# %%
trans['Fruit Size Code']=trans['Fruit Size Code'].astype('str')
disp['Fruit Size Code']=disp['Fruit Size Code'].astype('str')

# %%
trans['Purchase Pool Code']=trans['Purchase Pool Code'].apply(lambda x:x.split('0')[1] if x[0]=='0' else x)
disp['Purchase Pool Code']=disp['Purchase Pool Code'].apply(lambda x:x.split('0')[1] if x[0]=='0' else x)

# %%
#drop_columns(disp,['Pack_Date_day', 'Ok_Until_Date_day'])
drop_columns(disp,['Pack_Date_day'])
# Out:
# Drop 1 columns :
# ['Pack_Date_day']

# %%
# to prevent OK Until Date with same date but dif time
trans['Ok Until Date']=pd.to_datetime(trans['Ok Until Date'],format='%Y-%m-%d %H:%M:%S')
disp['Ok Until Date']=pd.to_datetime(disp['Ok Until Date'],format='%Y-%m-%d %H:%M:%S')

# %%
trans['Ok Until Date']=trans['Ok Until Date'].dt.date
disp['Ok Until Date']=disp['Ok Until Date'].dt.date

# %%
## 12 Oct : comment out this bcs found out Packed Trays is 0 in disp
# disp.rename(index=str,columns={'Packed Trays':'Trays'},inplace=True)

# %%
trans['Transaction Date Time']=pd.to_datetime(trans['Transaction Date Time'],format='%Y-%m-%d %H:%M:%S')

# %% [markdown]
# ## 2) Preprocess transactional data

# %%
trans.head(10)
# Out:
#   Transaction Date Time Customer Label Code Dry Matter Code  Fruit  \
# 0   2019-07-01 00:00:10                   N               Y  13000
# 1   2019-07-01 00:00:15                   N               Y   9216
# 2   2019-07-01 00:00:29                   N               Y  12650
# 3   2019-07-01 00:00:30                   N               Y   7800
# 4   2019-07-01 00:00:37                   N               Y  10200
# 5   2019-07-01 00:00:39                   N               Y   7540
# 6   2019-07-01 00:00:44                   N               Y  13000
# 7   2019-07-01 00:01:03                   N               Y   6264
# 8   2019-07-01 00:01:10                   N               Y  12650
# 9   2019-07-01 00:01:15                   N               Y   8640
#
#    Fruit Per Pack Fruit Size Code Labelling Indicator Code  \
# 0             130              42                       LG
# 1              36              36                       LG
# 2             115              39                       LG
# 3              78              27                       GR
# 4             102              36                       LG
# 5              52              33                       GR
# 6             130              42                       LG
# 7              27              27                       GR
# 8             115              39                       LG
# 9              48              30                       GR
#
#   Location Mission Request Destination Marketer Code Material Number  \
# 0                                   na           ZIL           62853
# 1                                   na           ZIL           62809
# 2                                   na           ZIL           65735
# 3                                   na           ZIL           61591
# 4                                   na           ZIL           62845
# 5                                 SPQI           ZIL           61554
# 6                                   na           ZIL           62853
# 7                                   na           ZIL           51182
# 8                                   na           ZIL           65735
# 9                                   na           ZIL           61541
#
#      New Value Ok Until Date  Pack Code            Pack Date  Packed Fruit  \
# 0   Q02-03-4-1    2019-07-21      41236  2019-06-06 00:00:00         13000
# 1   Q14-15-9-2    2019-07-21      41717  2019-06-05 00:00:00          9216
# 2  Q14-02-10-1    2019-07-14      76332  2019-06-01 00:00:00         12650
# 3   Q26-01-4-2    2019-07-07      10175  2019-05-26 00:00:00          7800
# 4   Q01-03-8-2    2019-07-21      41724  2019-06-05 00:00:00         10200
# 5      UNKNOWN    2019-07-07      10193  2019-05-25 00:00:00          7540
# 6   Q02-16-6-2    2019-07-21      41236  2019-06-06 00:00:00         13000
# 7   Q02-03-3-2    2019-07-21      12494  2019-06-06 00:00:00          6264
# 8      UNKNOWN    2019-07-14      76332  2019-06-01 00:00:00         12650
# 9   Q03-16-7-1    2019-07-07      10202  2019-05-24 00:00:00          8640
#
#   Packhouse Code Pack Label Code Pack Make Code  Packs  Pallet Number  \
# 0           3TPP               N            KC1    100       59717008
# 1           3TPP               N            KC1    256       59708334
# 2           3TPP               N            KCT    110       59699489
# 3           3TPP               N            KC1    100       59672352
# 4           3TPP               N            KC1    100       59708617
# 5           3TPP               N            KC1    145       59669482
# 6           3TPP               N            KC1    100       59717008
# 7           3TPP               N            KC1    232       59718630
# 8           3TPP               N            KCT    110       59699489
# 9           3TPP               T            KC1    180       59444423
#
#    Pallet Rework Count  Plant Code Previous Value Protocol Code  \
# 0                    0        1103     Q02-03-3-1             N
# 1                    0        1103    Q14-02-10-1             N
# 2                    0        1103     Q14-02-7-1             N
# 3                    0        1103    Q27-02-12-1             N
# 4                    2        1103     Q01-02-5-2             N
# 5                    0        1103           ALLO             N
# 6                    0        1103     Q02-03-4-1             N
# 7                    0        1103     Q02-03-2-2             N
# 8                    0        1103    Q14-02-10-1             N
# 9                    0        1103        UNKNOWN             N
#
#   Purchase Pool Code Quality Inspection Indicator Code Storage Method Code  \
# 0                  1                                 A                  CN
# 1                  1                                 A                  CN
# 2                  1                                 A                  CN
# 3                  1                                 A                  CN
# 4                  1                                 A                  CN
# 5                  1                                 A                  CN
# 6                  1                                 A                  CN
# 7                  1                                 A                  CN
# 8                  1                                 A                  CN
# 9                  1                                 A                  CN
#
#       Transaction Date Transaction Sub Type Code       Trays Username  \
# 0  2019-07-01 00:00:10                       MLA  309.523810    agubs
# 1  2019-07-01 00:00:15                       MTA  256.000000   jaspsi
# 2  2019-07-01 00:00:29                       MLA  324.358974   jaspsi
# 3  2019-07-01 00:00:30                       MTA  288.888889   mansot
# 4  2019-07-01 00:00:37                       MTA  283.333333    yasms
# 5  2019-07-01 00:00:39                       MLA  228.484848    teaio
# 6  2019-07-01 00:00:44                       MTA  309.523810    agubs
# 7  2019-07-01 00:01:03                       MLA  232.000000    agubs
# 8  2019-07-01 00:01:10                       MTA  324.358974   jaspsi
# 9  2019-07-01 00:01:15                       MTA  288.000000    palgr
#
#   Variety Code  Ok_Until_Date_day  Pack_Date_day  isDOINumber Pack Style Code  \
# 0           HW               19.0          -26.0        False              MB
# 1           HW               19.0          -27.0        False              IT
# 2           HW               12.0          -31.0        False              BM
# 3           HW                5.0          -37.0        False              MB
# 4           HW               19.0          -27.0        False              MB
# 5           HW                5.0          -38.0        False              P1
# 6           HW               19.0          -26.0        False              MB
# 7           HW               19.0          -26.0        False              IT
# 8           HW               12.0          -31.0        False              BM
# 9           HW                5.0          -39.0        False              M2
#
#   Pack_Base Stacking Configuration Code  isDayShift  Shift_Hour Day_of_week  \
# 0         E                           N       False           0         Sun
# 1         E                           3       False           0         Sun
# 2         E                           1       False           0         Sun
# 3         E                           N       False           0         Sun
# 4         E                           N       False           0         Sun
# 5         E                           N       False           0         Sun
# 6         E                           N       False           0         Sun
# 7         E                           N       False           0         Sun
# 8         E                           1       False           0         Sun
# 9         E                           2       False           0         Sun
#
#    isWeekend  isActualMovement  isPackedFruitequalFruit Previous_RoomRow  \
# 0       True              True                     True           Q02-03
# 1       True              True                     True           Q14-02
# 2       True              True                     True           Q14-02
# 3       True              True                     True           Q27-02
# 4       True              True                     True           Q01-02
# 5       True              True                     True             ALLO
# 6       True              True                     True           Q02-03
# 7       True              True                     True           Q02-03
# 8       True              True                     True           Q14-02
# 9       True              True                     True          UNKNOWN
#
#   Previous_Column Previous_Height distance_to_driveway
# 0               3               1                   10
# 1              10               1                    3
# 2               7               1                    6
# 3              12               1                    1
# 4               5               2                    8
# 5              na              na                   na
# 6               4               1                    9
# 7               2               2                   11
# 8              10               1                    3
# 9              na              na                   na

# %% [markdown]
# ### Add Query Time
# df=trans.copy()
# df['query_Time']=q_time
# list_time=[c for c in list(df.columns) if 'Time' in c]
# list_time
# for c in list_time:
#     df[c]=pd.to_datetime(df[c],format='%Y-%m-%d %H:%M:%S')
# trans_prev=df.loc[df['Transaction Date Time']<df['query_Time']]
# trans_prev.shape
# trans_prev.head()

# %%
temp_df=trans.groupby('Previous Value')['Transaction Date Time','Pallet Number'].first()

# %%
temp_df_2=trans.groupby('New Value')['Transaction Date Time','Pallet Number'].first()

# %%
temp_df.reset_index(inplace=True)
temp_df_2.reset_index(inplace=True)

# %%
df_merge=temp_df.merge(temp_df_2,how='outer',left_on='Previous Value',right_on='New Value',suffixes=('_From', '_To'))
df_merge.sample(5)
# Out:
#       Previous Value Transaction Date Time_From  Pallet Number_From  \
# 7490      Q12-20-1-1        2019-07-21 23:55:57          57421297.0
# 16991     Q30-23-3-1        2019-07-08 02:08:44          59640832.0
# 19818    ZT03-20-5-1        2019-07-19 10:41:21          57399572.0
# 14852    Q27-09-11-2        2019-07-02 16:12:47          56603380.0
# 975       Q01-17-1-1        2019-07-09 14:03:11          59700185.0
#
#          New Value Transaction Date Time_To  Pallet Number_To
# 7490    Q12-20-1-1      2019-07-21 23:53:54        57421297.0
# 16991   Q30-23-3-1      2019-07-08 02:25:52        59642560.0
# 19818          NaN                      NaT               NaN
# 14852  Q27-09-11-2      2019-07-02 02:12:15        56603380.0
# 975     Q01-17-1-1      2019-07-09 20:42:25        57435782.0

# %%
# Exclude row with Transaction Date Time_To happened before Transaction Date Time_From
df=df_merge.loc[(df_merge['Transaction Date Time_From']<df_merge['Transaction Date Time_To']) |
             df_merge['Transaction Date Time_To'].isna(),:]

# %%
df.shape
# Out:
# (14359, 6)

# %% [markdown]
# ### Check Duplicates

# %%
df[df['Pallet Number_From'].duplicated()]
# Out:
#         Previous Value Transaction Date Time_From  Pallet Number_From  \
# 578          P04-A-3-1        2019-07-13 20:48:50          57349683.0
# 1025        Q01-19-1-1        2019-07-03 15:41:50          59699984.0
# 1393       Q02-09-12-1        2019-07-03 01:51:00          59435094.0
# 1505        Q02-13-6-2        2019-07-02 22:48:32          59685406.0
# 1544       Q02-15-13-2        2019-07-02 22:48:52          59685406.0
# 2144       Q03-15-13-2        2019-07-29 11:15:27          59663350.0
# 2391         Q03-A-8-1        2019-07-01 00:01:22          59699489.0
# 2694        Q04-17-3-2        2019-07-02 15:17:48          59694958.0
# 2701        Q04-17-7-2        2019-07-02 14:46:03          59712515.0
# 3190       Q05-14-10-1        2019-07-01 12:13:32          56999445.0
# 3325        Q05-19-2-1        2019-07-03 16:40:58          59674950.0
# 3468         Q05-A-1-1        2019-07-03 10:08:21          57409011.0
# 3737       Q06-11-12-2        2019-07-03 09:29:09          57008481.0
# 4251        Q07-07-2-1        2019-07-01 11:39:19          56996789.0
# 4392       Q07-13-12-1        2019-07-01 08:32:23          57410833.0
# 4704        Q08-02-7-1        2019-07-08 02:37:44          57429880.0
# 4919       Q08-12-10-2        2019-07-01 15:15:18          58522924.0
# 5775        Q09-21-9-2        2019-07-06 17:52:56          57125966.0
# 6060       Q10-09-12-2        2019-07-18 23:31:55          57002878.0
# 6354        Q10-21-6-2        2019-07-01 23:08:16          57378188.0
# 6618        Q11-08-2-1        2019-07-15 01:03:12          57390401.0
# 6642       Q11-09-13-1        2019-07-04 12:25:05          90006382.0
# 6686       Q11-11-10-2        2019-07-04 20:18:16          57121722.0
# 6827        Q11-17-4-1        2019-07-03 04:49:27          90006382.0
# 7040        Q12-02-1-2        2019-07-01 04:30:52          57389344.0
# 7112        Q12-04-8-2        2019-07-01 23:01:56          58510785.0
# 7207        Q12-08-5-1        2019-07-01 22:55:38          57440472.0
# 7322       Q12-13-11-2        2019-07-10 16:31:36          56991470.0
# 7877        Q14-02-7-1        2019-07-01 00:00:29          59699489.0
# 8503        Q15-17-5-1        2019-07-01 01:43:57          57359330.0
# ...                ...                        ...                 ...
# 13926       Q25-19-3-1        2019-07-07 22:16:30          56999155.0
# 14154      Q26-04-12-2        2019-07-01 03:13:47          59693210.0
# 14653      Q27-01-13-1        2019-07-23 09:31:59          59444102.0
# 14704      Q27-03-13-1        2019-07-06 14:32:10          57000935.0
# 14730      Q27-04-13-1        2019-07-04 08:29:09          59675292.0
# 14876      Q27-10-11-1        2019-07-03 17:16:02          56997335.0
# 14890       Q27-10-6-2        2019-07-03 17:41:53          57403484.0
# 15170      Q27-22-10-1        2019-07-01 11:42:58          57402340.0
# 15184       Q27-22-5-2        2019-07-01 22:45:20          57400988.0
# 15204       Q27-23-2-2        2019-07-01 23:01:56          56603120.0
# 15250        Q27-A-3-1        2019-07-04 16:08:22          57409097.0
# 15474      Q28-10-10-2        2019-07-04 23:03:01          59688407.0
# 15574       Q28-14-4-1        2019-07-02 04:25:11          59331136.0
# 15607       Q28-16-1-2        2019-07-05 17:24:18          59318199.0
# 15608      Q28-16-10-1        2019-07-01 19:27:52          59335868.0
# 15744      Q28-22-13-2        2019-07-17 03:14:06          59624580.0
# 15758       Q28-22-9-2        2019-07-07 02:19:17          59327641.0
# 15806        Q28-A-8-1        2019-07-05 15:17:24          59632349.0
# 15829       Q29-01-7-1        2019-07-01 10:37:47          59169265.0
# 15987       Q29-07-9-2        2019-07-05 09:53:41          58508423.0
# 16019      Q29-09-11-2        2019-07-01 21:00:50          58510891.0
# 16062       Q29-10-8-2        2019-07-01 22:03:04          57403828.0
# 16075       Q29-11-2-2        2019-07-04 20:05:23          57421549.0
# 16427        Q29-A-6-1        2019-07-01 14:33:01          57420832.0
# 16988      Q30-23-13-1        2019-07-17 09:47:13          59616561.0
# 17056  UNKNOWN-02-11-0        2019-07-03 20:40:33          59439153.0
# 17059    UNKNOWN-A-7-1        2019-07-04 07:23:35          57411519.0
# 17751      ZE02-16-1-2        2019-07-17 13:57:55          57002830.0
# 18250      ZE05-09-2-1        2019-07-06 16:12:55          57130052.0
# 18313      ZE05-20-1-2        2019-07-18 11:44:01          57006319.0
#
#          New Value Transaction Date Time_To  Pallet Number_To
# 578            NaN                      NaT               NaN
# 1025    Q01-19-1-1      2019-07-03 19:48:23        59170858.0
# 1393   Q02-09-12-1      2019-07-11 01:38:45        59442320.0
# 1505    Q02-13-6-2      2019-07-03 22:15:36        59682962.0
# 1544           NaN                      NaT               NaN
# 2144           NaN                      NaT               NaN
# 2391     Q03-A-8-1      2019-07-05 13:33:55        57121722.0
# 2694    Q04-17-3-2      2019-07-03 08:03:54        90017685.0
# 2701    Q04-17-7-2      2019-07-12 09:15:24        59436022.0
# 3190   Q05-14-10-1      2019-07-05 20:42:33        59668287.0
# 3325    Q05-19-2-1      2019-07-04 16:22:41        59684959.0
# 3468     Q05-A-1-1      2019-07-03 11:11:25        59170537.0
# 3737   Q06-11-12-2      2019-07-03 11:56:14        57008481.0
# 4251    Q07-07-2-1      2019-07-03 08:42:06        59704145.0
# 4392   Q07-13-12-1      2019-07-01 14:52:14        58510945.0
# 4704    Q08-02-7-1      2019-07-08 02:37:46        57429880.0
# 4919   Q08-12-10-2      2019-07-04 03:10:49        57438295.0
# 5775    Q09-21-9-2      2019-07-08 09:45:56        57419270.0
# 6060   Q10-09-12-2      2019-07-28 17:58:52        57377099.0
# 6354    Q10-21-6-2      2019-07-02 07:20:59        57390791.0
# 6618    Q11-08-2-1      2019-07-15 01:03:13        57390401.0
# 6642           NaN                      NaT               NaN
# 6686           NaN                      NaT               NaN
# 6827    Q11-17-4-1      2019-07-03 04:50:35        57439322.0
# 7040    Q12-02-1-2      2019-07-01 04:30:54        57389344.0
# 7112    Q12-04-8-2      2019-07-01 23:05:40        58512055.0
# 7207    Q12-08-5-1      2019-07-01 23:46:07        58512130.0
# 7322   Q12-13-11-2      2019-07-10 20:23:11        57435188.0
# 7877    Q14-02-7-1      2019-07-01 16:26:31        59710870.0
# 8503    Q15-17-5-1      2019-07-01 08:21:48        57434938.0
# ...            ...                      ...               ...
# 13926   Q25-19-3-1      2019-07-08 03:37:47        57349836.0
# 14154  Q26-04-12-2      2019-07-03 01:57:35        59681774.0
# 14653  Q27-01-13-1      2019-07-24 08:34:10        57383021.0
# 14704  Q27-03-13-1      2019-07-06 14:34:12        57420191.0
# 14730  Q27-04-13-1      2019-07-06 14:32:10        57000935.0
# 14876  Q27-10-11-1      2019-07-03 23:55:58        57368226.0
# 14890   Q27-10-6-2      2019-07-04 08:19:24        59679429.0
# 15170  Q27-22-10-1      2019-07-01 11:46:53        56998462.0
# 15184   Q27-22-5-2      2019-07-01 23:00:06        57414794.0
# 15204   Q27-23-2-2      2019-07-02 08:22:44        59443440.0
# 15250    Q27-A-3-1      2019-07-09 12:32:56        59428546.0
# 15474  Q28-10-10-2      2019-07-06 04:35:37        59703575.0
# 15574   Q28-14-4-1      2019-07-04 04:32:52        59686700.0
# 15607   Q28-16-1-2      2019-07-05 22:47:34        59616073.0
# 15608  Q28-16-10-1      2019-07-02 02:08:43        59617063.0
# 15744          NaN                      NaT               NaN
# 15758   Q28-22-9-2      2019-07-07 02:30:34        59613478.0
# 15806    Q28-A-8-1      2019-07-05 16:51:31        59621282.0
# 15829   Q29-01-7-1      2019-07-01 22:47:58        57423659.0
# 15987   Q29-07-9-2      2019-07-05 09:53:42        58508423.0
# 16019  Q29-09-11-2      2019-07-02 20:15:24        57124433.0
# 16062   Q29-10-8-2      2019-07-01 22:23:33        57137143.0
# 16075   Q29-11-2-2      2019-07-04 20:10:58        57001376.0
# 16427    Q29-A-6-1      2019-07-03 07:31:32        57369902.0
# 16988  Q30-23-13-1      2019-07-21 01:06:36        59642218.0
# 17056          NaN                      NaT               NaN
# 17059          NaN                      NaT               NaN
# 17751          NaN                      NaT               NaN
# 18250          NaN                      NaT               NaN
# 18313          NaN                      NaT               NaN
#
# [84 rows x 6 columns]

# %%
df_pallet_first_trsn=trans[['Pallet Number','Transaction Date Time']].groupby('Pallet Number')['Transaction Date Time'].min()

# %%
df_pallet_first_trsn=df_pallet_first_trsn.to_frame().reset_index()

# %%
df_pallet_first_trsn.head()
# Out:
#    Pallet Number Transaction Date Time
# 0       53179215   2019-07-02 09:12:52
# 1       53179598   2019-07-03 09:05:03
# 2       53180556   2019-07-01 01:11:34
# 3       53181362   2019-07-03 09:05:40
# 4       53184912   2019-07-01 11:35:09

# %%
temp=df.shape
df=df.merge(df_pallet_first_trsn,how='inner',
         left_on=['Transaction Date Time_From','Pallet Number_From'],
        right_on=['Transaction Date Time','Pallet Number'])
print('Total Row Rectified : {}'.format(temp[0]-df.shape[0]))
# Out:
# Total Row Rectified : 95

# %%
df.sample(10)
# Out:
#       Previous Value Transaction Date Time_From  Pallet Number_From  \
# 2481      Q07-13-9-1        2019-07-01 09:14:01          57372841.0
# 13492    ZT02-57-4-2        2019-07-19 17:12:12          57399909.0
# 3366      Q11-01-3-2        2019-07-06 03:06:52          57395949.0
# 1643      Q04-03-3-1        2019-07-02 08:16:39          80501080.0
# 10647     Q30-04-8-2        2019-07-05 01:54:05          59726352.0
# 11614    ZD05-09-3-2        2019-07-10 11:02:36          57370366.0
# 689       Q01-15-7-1        2019-07-03 23:36:32          59699939.0
# 6580      Q20-21-8-1        2019-07-06 22:52:42          59723306.0
# 13704    ZT03-16-4-1        2019-07-02 09:54:21          57378621.0
# 4538      Q14-22-6-2        2019-07-23 14:10:26          59722828.0
#
#         New Value Transaction Date Time_To  Pallet Number_To  Pallet Number  \
# 2481   Q07-13-9-1      2019-07-01 16:39:14        57433580.0       57372841
# 13492         NaN                      NaT               NaN       57399909
# 3366   Q11-01-3-2      2019-07-10 22:47:14        57394676.0       57395949
# 1643   Q04-03-3-1      2019-07-02 12:14:34        59444546.0       80501080
# 10647  Q30-04-8-2      2019-07-05 01:54:52        59728295.0       59726352
# 11614         NaN                      NaT               NaN       57370366
# 689    Q01-15-7-1      2019-07-03 23:56:10        59701922.0       59699939
# 6580   Q20-21-8-1      2019-07-06 22:56:38        59430754.0       59723306
# 13704         NaN                      NaT               NaN       57378621
# 4538          NaN                      NaT               NaN       59722828
#
#       Transaction Date Time
# 2481    2019-07-01 09:14:01
# 13492   2019-07-19 17:12:12
# 3366    2019-07-06 03:06:52
# 1643    2019-07-02 08:16:39
# 10647   2019-07-05 01:54:05
# 11614   2019-07-10 11:02:36
# 689     2019-07-03 23:36:32
# 6580    2019-07-06 22:52:42
# 13704   2019-07-02 09:54:21
# 4538    2019-07-23 14:10:26

# %%
df=df[['Previous Value','Pallet Number_From','Transaction Date Time_From']]
df.rename(index=str,columns={'Previous Value':'Location'},inplace=True)

# %%
df['isOccupied']=1

# %% [markdown]
# ### Counter check with Complete set of position

# %%
temp_list=trans['Previous Value'].unique()
temp_list_2=trans['New Value'].unique()

# %%
len(temp_list)
# Out:
# 20331

# %%
temp_list=np.append(temp_list,temp_list_2)

# %%
unique_position=set(temp_list)

# %%
print('Total Unique Position : {}'.format(len(unique_position)))
# Out:
# Total Unique Position : 20380

# %%
unique_position=list(unique_position)

# %%
unique_position_hyphen=list(c for c in unique_position if '-' in c)

# %%
df_Location=pd.DataFrame(columns=['Location'],data=unique_position_hyphen)

# %%
df=df.merge(df_Location,how='outer',on='Location')

# %%
df['isOccupied'].fillna(0,inplace=True)
df['Pallet Number_From'].fillna(0,inplace=True)

# %% [markdown]
# ### Filter Out Location with Hyphen

# %%
df=df.loc[df['Location'].str.contains('-'),:]
df.shape
# Out:
# (20342, 4)

# %% [markdown]
# ### Derive Room Code

# %%
df['Location_List']=df['Location'].str.split('-')

# %%
df['Room']=df['Location_List'].apply(lambda x:x[0])
df['Row']=df['Location_List'].apply(lambda x:x[1])
df['Column']=df['Location_List'].apply(lambda x:x[2])
df['Height']=df['Location_List'].apply(lambda x:x[3])

# %%
drop_columns(df,['Location_List'])
# Out:
# Drop 1 columns :
# ['Location_List']

# %%
df.sample(5)
# Out:
#           Location  Pallet Number_From Transaction Date Time_From  isOccupied  \
# 12027  ZE04-10-4-1          57422621.0        2019-07-17 11:59:49         1.0
# 20260    Q23-A-3-1                 0.0                        NaT         0.0
# 15104   Q28-16-1-1                 0.0                        NaT         0.0
# 1504    Q03-16-3-2          59675056.0        2019-07-04 14:30:49         1.0
# 8738    Q25-17-2-2          57417924.0        2019-07-18 03:29:38         1.0
#
#        Room Row Column Height
# 12027  ZE04  10      4      1
# 20260   Q23   A      3      1
# 15104   Q28  16      1      1
# 1504    Q03  16      3      2
# 8738    Q25  17      2      2

# %%
df['Room'].value_counts(dropna=False).sort_index()
# Out:
# P01        133
# P02        109
# P03        114
# P04        207
# Q01        605
# Q02        607
# Q03        602
# Q04        475
# Q05        620
# Q06        615
# Q07        570
# Q08        601
# Q09        604
# Q10        576
# Q11        576
# Q12        609
# Q13        240
# Q14        237
# Q15        495
# Q16        555
# Q17        522
# Q18        507
# Q19        518
# Q20        485
# Q21        621
# Q22        567
# Q23        557
# Q24        552
# Q25        611
# Q26        571
# Q27        612
# Q28        552
# Q29        622
# Q30        614
# Q51          4
# Q52          4
# UNKNOWN      4
# ZD02       118
# ZD03       148
# ZD04       159
# ZD05       166
# ZE02       260
# ZE03        69
# ZE04       223
# ZE05       286
# ZE06       182
# ZE07       145
# ZT01        91
# ZT02       690
# ZT03       732
# Name: Room, dtype: int64

# %%
df=df.sort_values(by=['Room','Row','Column','Height']).reset_index(drop=True)

# %%
df.rename(index=str,columns={'Pallet Number_From':'Pallet Number',
                            'Transaction Date Time_From':'Transaction Date Time'},inplace=True)

# %%
df.head()
# Out:
#      Location  Pallet Number Transaction Date Time  isOccupied Room Row  \
# 0  P01-01-7-2     57428906.0   2019-07-20 20:18:30         1.0  P01  01
# 1  P01-02-7-1            0.0                   NaT         0.0  P01  02
# 2  P01-02-7-2            0.0                   NaT         0.0  P01  02
# 3  P01-02-8-2            0.0                   NaT         0.0  P01  02
# 4  P01-03-5-1     58506139.0   2019-07-26 19:53:49         1.0  P01  03
#
#   Column Height
# 0      7      2
# 1      7      1
# 2      7      2
# 3      8      2
# 4      5      1

# %% [markdown]
# ### Summary

# %%
d_empty=len(df[df['isOccupied']==0])
d_occupied=len(df[df['isOccupied']==1])
#d_empty=len(df[df['isEmpty']==0])
#d_occupied=len(df[df['isEmpty']==1])

# %%
print('Total Pallet Position : {}'.format(len(df['Location'])))
print('Occupied Position: {:} '.format(d_occupied))
print('Occupancy Rate : {:.3f} %'.format(d_occupied/(d_empty+d_occupied)*100))
# Out:
# Total Pallet Position : 20342
# Occupied Position: 14259
# Occupancy Rate : 70.096 %

# %%
df.groupby('Room')['isOccupied'].sum()
# Out:
# Room
# P01         96.0
# P02         79.0
# P03         87.0
# P04        148.0
# Q01        481.0
# Q02        447.0
# Q03        285.0
# Q04        163.0
# Q05        261.0
# Q06        366.0
# Q07        141.0
# Q08        129.0
# Q09        335.0
# Q10        339.0
# Q11        396.0
# Q12        360.0
# Q13        222.0
# Q14        225.0
# Q15        394.0
# Q16        242.0
# Q17        291.0
# Q18        421.0
# Q19        365.0
# Q20        347.0
# Q21        466.0
# Q22        407.0
# Q23        443.0
# Q24        465.0
# Q25        487.0
# Q26        466.0
# Q27        324.0
# Q28        443.0
# Q29        447.0
# Q30        486.0
# Q51          0.0
# Q52          1.0
# UNKNOWN      0.0
# ZD02       118.0
# ZD03       148.0
# ZD04       159.0
# ZD05       166.0
# ZE02       260.0
# ZE03        69.0
# ZE04       223.0
# ZE05       286.0
# ZE06       182.0
# ZE07       145.0
# ZT01        91.0
# ZT02       625.0
# ZT03       732.0
# Name: isOccupied, dtype: float64

# %%
df['isOccupied'].value_counts()
# Out:
# 1.0    14259
# 0.0     6083
# Name: isOccupied, dtype: int64

# %% [markdown]
# ### Export

# %%
df.to_csv('Sitemap_July2019.csv',index=False)
